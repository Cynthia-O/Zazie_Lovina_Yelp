# %% [markdown]
# ## Sentiment Analysis for SF Restaurant Zazie - Yelp-Discarded Reviews (292 on 20190309 4:45 pm)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') #janet V has two reviews - that's a problem, one short on authors
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en')
# df1 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

# %%
df2.iloc[1,3]
# Out:
# <p lang="en">Overrated!</p>

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=10')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df2 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})
df2.head()

for i in range(len(df2)):
    df2.author[i] = re.sub('<span class="user-display-name" ','',str(df2.author[i]))
    df2.author[i] = re.sub('</span>','',str(df2.author[i]))
    df2.date[i] = re.sub('<span class="rating-qualifier">','',str(df2.date[i]))
    df2.date[i] = re.sub('</span>','',str(df2.date[i]))
    df2.stars[i] = re.sub('<img alt="','',str(df2.stars[i]))
    df2.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df2.stars[i]))
    df2.review_body[i] = re.sub('<p lang="en">','',str(df2.review_body[i]))
    df2.review_body[i] = re.sub('</p>','',str(df2.review_body[i]))

print(df2.shape)
df2
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="IPbvDk7Jc9Ocp29pd6A9nQ">Ger...
# 1   data-hovercard-id="f3Lad7zNsPnvcyYWg3Tkkw">Kri...
# 2   data-hovercard-id="b5ivKffoYO2_gmc0MPnozA">Nic...
# 3   data-hovercard-id="QXBcpOROr3SdhaCiTztOkw">Mir...
# 4   data-hovercard-id="aS1UHHJ4hV-q2FCAOabswg">Rac...
# 5   data-hovercard-id="lFviuaiGd-gJPUtFSlmHrQ">Emi...
# 6   data-hovercard-id="tYZGtkKuvtJG4_FhwFDm7Q">joh...
# 7   data-hovercard-id="2OiheC6jQveQ-A1BD1LjEw">Tho...
# 8   data-hovercard-id="MGM7Bux46-Xq2AOWTCEM-A">Ver...
# 9   data-hovercard-id="pPZOZfC8ZGFUzoVY2CDYJQ">Pat M.
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=20')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
df3 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df3)):
    df3.author[i] = re.sub('<span class="user-display-name" ','',str(df3.author[i]))
    df3.author[i] = re.sub('</span>','',str(df3.author[i]))
    df3.date[i] = re.sub('<span class="rating-qualifier">','',str(df3.date[i]))
    df3.date[i] = re.sub('</span>','',str(df3.date[i]))
    df3.stars[i] = re.sub('<img alt="','',str(df3.stars[i]))
    df3.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df3.stars[i]))
    df3.review_body[i] = re.sub('<p lang="en">','',str(df3.review_body[i]))
    df3.review_body[i] = re.sub('</p>','',str(df3.review_body[i]))

print(df3.shape)
df3
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="w9Y3bkrmxc9gLq9N5zBPEQ">Jes...
# 1   data-hovercard-id="-Pnk1pMvA1KI5YZj1mCcpg">Kat...
# 2   data-hovercard-id="HJiFseeLs8R3VrrELSGVsQ">Leg...
# 3   data-hovercard-id="TXrK6M4kJ_pYzEaKeIeYfA">Cha...
# 4   data-hovercard-id="u67iO3BupFnWjOnlVp-iyg">Joh...
# 5   data-hovercard-id="D4NMkMB6OxZWJPzYnR7CtA">Vin...
# 6   data-hovercard-id="F8JHY5ZnpLdoSUyUaIc4Lg">Cro...
# 7   data-hovercard-id="CNHQkv-U7wVDAfIrMO7Bxg">Ani...
# 8   data-hovercard-id="l9jxxnraB0uL8CdnIEm_OA">Nic...
# 9   data-hovercard-id="gc23exlNj3cpAxWhl-P53A">Aim...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=30')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df4 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df4)):
    df4.author[i] = re.sub('<span class="user-display-name" ','',str(df4.author[i]))
    df4.author[i] = re.sub('</span>','',str(df4.author[i]))
    df4.date[i] = re.sub('<span class="rating-qualifier">','',str(df4.date[i]))
    df4.date[i] = re.sub('</span>','',str(df4.date[i]))
    df4.stars[i] = re.sub('<img alt="','',str(df4.stars[i]))
    df4.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df4.stars[i]))
    df4.review_body[i] = re.sub('<p lang="en">','',str(df4.review_body[i]))
    df4.review_body[i] = re.sub('</p>','',str(df4.review_body[i]))

print(df4.shape)
df4
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="UGjzRmWIUqVSQ2sNo1gyOQ">Jin...
# 1   data-hovercard-id="CcJdVlbPSm9Kyk96JN-mxQ">Tho...
# 2   data-hovercard-id="ZKFySk_kEIdKCOKwxy_iog">Suw...
# 3   data-hovercard-id="ypVFrmoOdcfu67aXYCdHDg">Kim...
# 4   data-hovercard-id="LPhVXOO82xLFabZjX8TixA">Chr...
# 5   data-hovercard-id="H5Eeg8E297LqI81CKW3NXQ">Ann...
# 6   data-hovercard-id="NEAUqiyDi2UQrHfLnPQRvA">She...
# 7   data-hovercard-id="z3Shq00AWbc-N019oRZSZA">Sul...
# 8   data-hovercard-id="qH4uQQ9ZKrYEs_NlzbfvIg">She...
# 9   data-hovercard-id="akFqMo81BY2h3pWvduTwIw">Gar...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=40')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df5 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df5)):
    df5.author[i] = re.sub('<span class="user-display-name" ','',str(df5.author[i]))
    df5.author[i] = re.sub('</span>','',str(df5.author[i]))
    df5.date[i] = re.sub('<span class="rating-qualifier">','',str(df5.date[i]))
    df5.date[i] = re.sub('</span>','',str(df5.date[i]))
    df5.stars[i] = re.sub('<img alt="','',str(df5.stars[i]))
    df5.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df5.stars[i]))
    df5.review_body[i] = re.sub('<p lang="en">','',str(df5.review_body[i]))
    df5.review_body[i] = re.sub('</p>','',str(df5.review_body[i]))

print(df5.shape)
df5
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="D7z2-FuY5zpil7KeCoExNg">And...
# 1     data-hovercard-id="qWpzF007n3q2fhtmY2FtSA">m l.
# 2   data-hovercard-id="zUoW1MaV9w9ZxcQKHOr5cA">Pet...
# 3   data-hovercard-id="WmeVaOuzE7euuSty6lglcA">Adr...
# 4   data-hovercard-id="UrHuVmvCxSX7stAEif3V8Q">ayn...
# 5   data-hovercard-id="-05_uARKy4_gdPbbXYnsIg">ste...
# 6   data-hovercard-id="h5LSxvXlMUfOUEGBiM52QQ">typ...
# 7   data-hovercard-id="PRq1VX5hTx9WRyMSTf9roA">Min...
# 8   data-hovercard-id="-_LmE6oEw9FbYHAnMafKSA">Ant...
# 9   data-hovercard-id="-t7to0hWpIynHeM2cJbEUw">Emi...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=50')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df6 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df6)):
    df6.author[i] = re.sub('<span class="user-display-name" ','',str(df6.author[i]))
    df6.author[i] = re.sub('</span>','',str(df6.author[i]))
    df6.date[i] = re.sub('<span class="rating-qualifier">','',str(df6.date[i]))
    df6.date[i] = re.sub('</span>','',str(df6.date[i]))
    df6.stars[i] = re.sub('<img alt="','',str(df6.stars[i]))
    df6.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df6.stars[i]))
    df6.review_body[i] = re.sub('<p lang="en">','',str(df6.review_body[i]))
    df6.review_body[i] = re.sub('</p>','',str(df6.review_body[i]))

print(df6.shape)
df6
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="8FBYBdUAPxq777a5ac0eFQ">Rut...
# 1   data-hovercard-id="EruDnvA2H-Kp-ayNljgC5g">Rob...
# 2   data-hovercard-id="1sF6eRMtbPOwJMOkVsClVQ">Jan H.
# 3   data-hovercard-id="Nu_ggoBdNi-kYlq2uFCHpQ">Lyn...
# 4   data-hovercard-id="THZP1XsI9fHTH3SDZNW4sA">Sut...
# 5   data-hovercard-id="FL4B4IuR-dEwUfc5XJphNQ">Slo...
# 6   data-hovercard-id="_KPee9RfFJvQouG2XNju_A">Zai...
# 7   data-hovercard-id="FGZgrdc1xxFwVMqsq1lR0A">Svy...
# 8   data-hovercard-id="HljgPDGWo51-3F1D-iagVg">Joc...
# 9   data-hovercard-id="hFga_0kG7cz4WpK-bS5CRQ">Tuc...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=60')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df7 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df7)):
    df7.author[i] = re.sub('<span class="user-display-name" ','',str(df7.author[i]))
    df7.author[i] = re.sub('</span>','',str(df7.author[i]))
    df7.date[i] = re.sub('<span class="rating-qualifier">','',str(df7.date[i]))
    df7.date[i] = re.sub('</span>','',str(df7.date[i]))
    df7.stars[i] = re.sub('<img alt="','',str(df7.stars[i]))
    df7.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df7.stars[i]))
    df7.review_body[i] = re.sub('<p lang="en">','',str(df7.review_body[i]))
    df7.review_body[i] = re.sub('</p>','',str(df7.review_body[i]))

print(df7.shape)
df7
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="0HKzoUNU44ob4lPUfQr-Tw">Cam...
# 1   data-hovercard-id="Td-WAEoqkXynkV7zN5pdtg">Mar...
# 2   data-hovercard-id="92Mw7UKdvFPTpQP4GUN87w">Jor...
# 3   data-hovercard-id="lRXjJ9wqOmYQrEHm_vXSfQ">Ash...
# 4    data-hovercard-id="jvBkfJz2wrXxiui0aq9z6Q">Mj A.
# 5   data-hovercard-id="kOrGjKw8hDmFPZkWCy2omw">Meg...
# 6   data-hovercard-id="fuD9U7UefP7JaQV6HjYiYw">Amy S.
# 7   data-hovercard-id="4NHwtC0VNBMDP_YGo4y31A">Lou...
# 8   data-hovercard-id="QCZlyzL5AIfdfsst_mcKCA">Mic...
# 9   data-hovercard-id="KqjgKxKEXD-T5fKbfcHYZQ">Gua...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=70')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df8 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df8)):
    df8.author[i] = re.sub('<span class="user-display-name" ','',str(df8.author[i]))
    df8.author[i] = re.sub('</span>','',str(df8.author[i]))
    df8.date[i] = re.sub('<span class="rating-qualifier">','',str(df8.date[i]))
    df8.date[i] = re.sub('</span>','',str(df8.date[i]))
    df8.stars[i] = re.sub('<img alt="','',str(df8.stars[i]))
    df8.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df8.stars[i]))
    df8.review_body[i] = re.sub('<p lang="en">','',str(df8.review_body[i]))
    df8.review_body[i] = re.sub('</p>','',str(df8.review_body[i]))

print(df8.shape)
df8
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="57fzIyUveh30XW7MCldmmg">Bet...
# 1   data-hovercard-id="5MxWOnwaAjvWbBHZUEuOOw">Ken...
# 2   data-hovercard-id="2pNYPclZyBOPNL3PTjCCvw">Err...
# 3   data-hovercard-id="M46vINC7LgyJSqit-OSPqQ">She...
# 4   data-hovercard-id="1YAQbEk6dictrh2RTze5PQ">Joh...
# 5   data-hovercard-id="HLsOV1uv2e0wIMEI1Xdy6Q">Ken...
# 6   data-hovercard-id="qVACDpSPTgUNKgB-T_lI3g">Jas...
# 7   data-hovercard-id="APPdVTuAi2Q26Uzk8bCeoQ">Mis...
# 8   data-hovercard-id="h6pqwHvQRkz-70n2MXiSQA">Car...
# 9   data-hovercard-id="c659D-DEkRApzZQqojAyGA">Cri...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=80')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df9 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df9)):
    df9.author[i] = re.sub('<span class="user-display-name" ','',str(df9.author[i]))
    df9.author[i] = re.sub('</span>','',str(df9.author[i]))
    df9.date[i] = re.sub('<span class="rating-qualifier">','',str(df9.date[i]))
    df9.date[i] = re.sub('</span>','',str(df9.date[i]))
    df9.stars[i] = re.sub('<img alt="','',str(df9.stars[i]))
    df9.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df9.stars[i]))
    df9.review_body[i] = re.sub('<p lang="en">','',str(df9.review_body[i]))
    df9.review_body[i] = re.sub('</p>','',str(df9.review_body[i]))

print(df9.shape)
df9
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="QKfMc2MXgGhfDbuv1OAu3A">Sha...
# 1   data-hovercard-id="U5QQ_ewezofcqkRkVVDM8w">Fra...
# 2   data-hovercard-id="0tZU_LtLnoS1XFjiZXXasw">Joa...
# 3   data-hovercard-id="ampcZV30P8oVEiOpDZ_O6w">Cry...
# 4   data-hovercard-id="MZk4wBeGM2tCEVlnaLMyzQ">Ste...
# 5   data-hovercard-id="agKZEdmgkzkOG0zU2oWK0w">Jim G.
# 6   data-hovercard-id="GppHgEgEKbSvP8hhCwqRXQ">Nan...
# 7   data-hovercard-id="HUlmAMCLPpteLX-xLIMtow">Bon...
# 8   data-hovercard-id="8ZRiH5DPgscTM4XUgnmxag">Dia...
# 9    data-hovercard-id="mF3JTBefAzSMPb9MB6jzyQ">Yo M.
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=80')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df10 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df10)):
    df10.author[i] = re.sub('<span class="user-display-name" ','',str(df10.author[i]))
    df10.author[i] = re.sub('</span>','',str(df10.author[i]))
    df10.date[i] = re.sub('<span class="rating-qualifier">','',str(df10.date[i]))
    df10.date[i] = re.sub('</span>','',str(df10.date[i]))
    df10.stars[i] = re.sub('<img alt="','',str(df10.stars[i]))
    df10.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df10.stars[i]))
    df10.review_body[i] = re.sub('<p lang="en">','',str(df10.review_body[i]))
    df10.review_body[i] = re.sub('</p>','',str(df10.review_body[i]))

print(df10.shape)
df10
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="QKfMc2MXgGhfDbuv1OAu3A">Sha...
# 1   data-hovercard-id="U5QQ_ewezofcqkRkVVDM8w">Fra...
# 2   data-hovercard-id="0tZU_LtLnoS1XFjiZXXasw">Joa...
# 3   data-hovercard-id="ampcZV30P8oVEiOpDZ_O6w">Cry...
# 4   data-hovercard-id="MZk4wBeGM2tCEVlnaLMyzQ">Ste...
# 5   data-hovercard-id="agKZEdmgkzkOG0zU2oWK0w">Jim G.
# 6   data-hovercard-id="GppHgEgEKbSvP8hhCwqRXQ">Nan...
# 7   data-hovercard-id="HUlmAMCLPpteLX-xLIMtow">Bon...
# 8   data-hovercard-id="8ZRiH5DPgscTM4XUgnmxag">Dia...
# 9    data-hovercard-id="mF3JTBefAzSMPb9MB6jzyQ">Yo M.
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=90')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df11 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df11)):
    df11.author[i] = re.sub('<span class="user-display-name" ','',str(df11.author[i]))
    df11.author[i] = re.sub('</span>','',str(df11.author[i]))
    df11.date[i] = re.sub('<span class="rating-qualifier">','',str(df11.date[i]))
    df11.date[i] = re.sub('</span>','',str(df11.date[i]))
    df11.stars[i] = re.sub('<img alt="','',str(df11.stars[i]))
    df11.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df11.stars[i]))
    df11.review_body[i] = re.sub('<p lang="en">','',str(df11.review_body[i]))
    df11.review_body[i] = re.sub('</p>','',str(df11.review_body[i]))

print(df11.shape)
df11
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="uYrvtj_733st2zJRaaE-3A">Ani...
# 1   data-hovercard-id="SIPpDU7OZ9zt_IN_01KJCw">Eri...
# 2   data-hovercard-id="F1j9P5dsjqxudSmDzVbwTg">Rob W.
# 3   data-hovercard-id="DTsamlCcIEq2Fltpa3uajQ">Jim S.
# 4   data-hovercard-id="y0fZluccG30j84SAqxMpUQ">Jon...
# 5   data-hovercard-id="xcB7EYO566lWjB2M1Ko_YQ">Edw...
# 6   data-hovercard-id="A3EfiqNTZXuB_KsVvkEprw">Mar...
# 7     data-hovercard-id="W39bC-2OaMQHMtmkVuDkbA">K K.
# 8   data-hovercard-id="bJGBkiWtPItZeQU-6PO8mQ">Rol...
# 9   data-hovercard-id="5Dl3itT76l6MazXYfaza7g">Sar...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=100')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df12 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df12)):
    df12.author[i] = re.sub('<span class="user-display-name" ','',str(df12.author[i]))
    df12.author[i] = re.sub('</span>','',str(df12.author[i]))
    df12.date[i] = re.sub('<span class="rating-qualifier">','',str(df12.date[i]))
    df12.date[i] = re.sub('</span>','',str(df12.date[i]))
    df12.stars[i] = re.sub('<img alt="','',str(df12.stars[i]))
    df12.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df12.stars[i]))
    df12.review_body[i] = re.sub('<p lang="en">','',str(df12.review_body[i]))
    df12.review_body[i] = re.sub('</p>','',str(df12.review_body[i]))

print(df12.shape)
df12
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="rSiT8uILLZiILwlr-TiEDQ">Mar...
# 1   data-hovercard-id="K5MZzAvmgWNaYP5HxgOp1A">Dia...
# 2   data-hovercard-id="XM9czJdhSQYVpn7bBAQRSQ">Meg...
# 3   data-hovercard-id="E1pI2FeLJ2KHYOb11DD-lQ">Chr...
# 4    data-hovercard-id="5IvFt3z56mptMjmwC2YfeA">Ha K.
# 5   data-hovercard-id="lIN557tBIaWFeAefxQx3PQ">Emi...
# 6   data-hovercard-id="8QaH527DMb7jwwLkt9M6rg">Lia...
# 7   data-hovercard-id="LlHPwiSslb8jfOKc-EmE3Q">Jen...
# 8   data-hovercard-id="QrQnU-5Kn-ioWSxkL3uAyQ">Len G.
# 9   data-hovercard-id="sW3iNVTtYLbf3cwskfS_yQ">Cin...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=110')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df13 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df13)):
    df13.author[i] = re.sub('<span class="user-display-name" ','',str(df13.author[i]))
    df13.author[i] = re.sub('</span>','',str(df13.author[i]))
    df13.date[i] = re.sub('<span class="rating-qualifier">','',str(df13.date[i]))
    df13.date[i] = re.sub('</span>','',str(df13.date[i]))
    df13.stars[i] = re.sub('<img alt="','',str(df13.stars[i]))
    df13.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df13.stars[i]))
    df13.review_body[i] = re.sub('<p lang="en">','',str(df13.review_body[i]))
    df13.review_body[i] = re.sub('</p>','',str(df13.review_body[i]))

print(df13.shape)
df13
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="yKVlVo-yZXHG8XLUb02l6Q">Jor...
# 1   data-hovercard-id="8LHSwzLSZruJYf2sWSQ_6w">Poo...
# 2   data-hovercard-id="7SWkLwYhplVvCKFi3gJ2Eg">Mit...
# 3   data-hovercard-id="AJMT_eaZvZ7RPxsSiIN9IA">Deb...
# 4   data-hovercard-id="VK3Glpr629kUXErUciIx4A">Jam...
# 5   data-hovercard-id="UxFdgBToqdg005jKnR4z9w">Bri...
# 6   data-hovercard-id="3n2SJBXRdnIjTTX0rAjkdQ">Mar...
# 7   data-hovercard-id="975mzo-0mRSlkCBRhFMr3A">Geo...
# 8   data-hovercard-id="gmwdAjK9S1IB09Z_cNqkwQ">Dav...
# 9   data-hovercard-id="6GuPSKCVScP01TnR07TxBQ">NAT...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=120')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df14 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df14)):
    df14.author[i] = re.sub('<span class="user-display-name" ','',str(df14.author[i]))
    df14.author[i] = re.sub('</span>','',str(df14.author[i]))
    df14.date[i] = re.sub('<span class="rating-qualifier">','',str(df14.date[i]))
    df14.date[i] = re.sub('</span>','',str(df14.date[i]))
    df14.stars[i] = re.sub('<img alt="','',str(df14.stars[i]))
    df14.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df14.stars[i]))
    df14.review_body[i] = re.sub('<p lang="en">','',str(df14.review_body[i]))
    df14.review_body[i] = re.sub('</p>','',str(df14.review_body[i]))

print(df14.shape)
df14
# Out:
# (20, 4)
#                                                author  \
# 0     data-hovercard-id="JhBi3L-H_tr9NMslDIMu8g">D C.
# 1   data-hovercard-id="mpGhwso4IC4Aivp12xHuaw">Hay...
# 2   data-hovercard-id="9AwhXBAsFzorD_haERQ9_g">Mis...
# 3   data-hovercard-id="wH7RzDK4-Jfl80nsXWk8JQ">Chr...
# 4   data-hovercard-id="ae-tze8EKFS_ouOD7MRZrw">Len...
# 5   data-hovercard-id="zy6C_nt8ZyOtAjcFzEKHVg">Jul...
# 6   data-hovercard-id="u7aZsE6JYxBzILKXmbli0w">Joa...
# 7   data-hovercard-id="ZJD3vyo-D4oHOaM9zV-nVQ">Vic...
# 8   data-hovercard-id="03ao0Bo_CGdZ3TQiu59dTA">Sim K.
# 9   data-hovercard-id="uCMuatMZoEzWzicSC6FdWg">Mis...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=130')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') #another duplicate author problem
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
# df15 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=140')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df16 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df16)):
    df16.author[i] = re.sub('<span class="user-display-name" ','',str(df16.author[i]))
    df16.author[i] = re.sub('</span>','',str(df16.author[i]))
    df16.date[i] = re.sub('<span class="rating-qualifier">','',str(df16.date[i]))
    df16.date[i] = re.sub('</span>','',str(df16.date[i]))
    df16.stars[i] = re.sub('<img alt="','',str(df16.stars[i]))
    df16.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df16.stars[i]))
    df16.review_body[i] = re.sub('<p lang="en">','',str(df16.review_body[i]))
    df16.review_body[i] = re.sub('</p>','',str(df16.review_body[i]))

print(df16.shape)
df16
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="5ZglrNt9JQRyAKJQCkgCxA">Dre...
# 1   data-hovercard-id="-YZzp8R6rTptchdgPJqTtQ">Dav...
# 2   data-hovercard-id="P6MlWTkK_HtzWuoJwTBTBw">Mon...
# 3   data-hovercard-id="lWAQ0O5Ec5xna148_QoJhA">dew...
# 4   data-hovercard-id="8NLyGstSiCE4PqAf5AqaZg">sha...
# 5   data-hovercard-id="NeJ_gbqniaydszPgIK_fKQ">Jef...
# 6   data-hovercard-id="MChIW2Ob1fHb1wHNnt-RHw">Yum...
# 7   data-hovercard-id="ZoCZBR4SN2KWUHxOrm0VvQ">Dav...
# 8   data-hovercard-id="tgXO8s3qgCt6WOyyObWv3A">Mir...
# 9   data-hovercard-id="b7W2qPcdX6dye1wN38OGCw">Gre...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=150')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df17 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df17)):
    df17.author[i] = re.sub('<span class="user-display-name" ','',str(df17.author[i]))
    df17.author[i] = re.sub('</span>','',str(df17.author[i]))
    df17.date[i] = re.sub('<span class="rating-qualifier">','',str(df17.date[i]))
    df17.date[i] = re.sub('</span>','',str(df17.date[i]))
    df17.stars[i] = re.sub('<img alt="','',str(df17.stars[i]))
    df17.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df17.stars[i]))
    df17.review_body[i] = re.sub('<p lang="en">','',str(df17.review_body[i]))
    df17.review_body[i] = re.sub('</p>','',str(df17.review_body[i]))

print(df17.shape)
df17
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="tc-57CfOLPvAGiqU_2AHEw">Rob...
# 1   data-hovercard-id="qhbHCAW1RzSnIozJx7D75g">Kat...
# 2   data-hovercard-id="8yQqWUJIfB_MmXV_cHFllA">Kam...
# 3   data-hovercard-id="01BSFCQ5wVSVHvkvZ2Rv0w">Jih...
# 4   data-hovercard-id="DFw6u7PIMAPTzQRlW1SYSw">Bar...
# 5   data-hovercard-id="Ot3GQfcP8yXJn33K6aucpg">Car...
# 6   data-hovercard-id="yerCVp8PFtcLwt4RTXAD-w">Fid...
# 7   data-hovercard-id="68NcHl9crT8-w5P-a3LIwg">Kei...
# 8   data-hovercard-id="aMFiuwPsmJS4Zn1jGuQc_w">Mik...
# 9   data-hovercard-id="BVF4dz8df-qhSVhkUs7AXw">Emm...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=160')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df18 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df18)):
    df18.author[i] = re.sub('<span class="user-display-name" ','',str(df18.author[i]))
    df18.author[i] = re.sub('</span>','',str(df18.author[i]))
    df18.date[i] = re.sub('<span class="rating-qualifier">','',str(df18.date[i]))
    df18.date[i] = re.sub('</span>','',str(df18.date[i]))
    df18.stars[i] = re.sub('<img alt="','',str(df18.stars[i]))
    df18.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df18.stars[i]))
    df18.review_body[i] = re.sub('<p lang="en">','',str(df18.review_body[i]))
    df18.review_body[i] = re.sub('</p>','',str(df18.review_body[i]))

print(df18.shape)
df18
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="I5pB0mfvXR6ju0THxNwjdQ">Nik...
# 1   data-hovercard-id="zDAPFKysJ9osBuloaUVhiQ">Zay...
# 2   data-hovercard-id="v6YRtNu9Z3rGSgy_MJdhjA">Han...
# 3   data-hovercard-id="u-oxTNeEJmSjhc-uDTmTxQ">Ken...
# 4   data-hovercard-id="W3AfospPBZA52KPGSnIBvg">Emm...
# 5    data-hovercard-id="qfcv354-ZmOjqhF5WKTQEA">Ty R.
# 6   data-hovercard-id="nUkeQpVTgkrnU3_IOPq5cQ">Pai...
# 7   data-hovercard-id="_luv8DHtB8jjX8JXOCFRjw">Ath...
# 8   data-hovercard-id="yMoKe9EASvXtPKkFR10Jhg">Amb...
# 9   data-hovercard-id="YMSyizNqEojQmfc0jymhzw">Viv...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=170')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df19 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df19)):
    df19.author[i] = re.sub('<span class="user-display-name" ','',str(df19.author[i]))
    df19.author[i] = re.sub('</span>','',str(df19.author[i]))
    df19.date[i] = re.sub('<span class="rating-qualifier">','',str(df19.date[i]))
    df19.date[i] = re.sub('</span>','',str(df19.date[i]))
    df19.stars[i] = re.sub('<img alt="','',str(df19.stars[i]))
    df19.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df19.stars[i]))
    df19.review_body[i] = re.sub('<p lang="en">','',str(df19.review_body[i]))
    df19.review_body[i] = re.sub('</p>','',str(df19.review_body[i]))

print(df19.shape)
df19
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="Z2_S5NEgBpLR_MFpIDQTuQ">Mee...
# 1   data-hovercard-id="TB-_kan5IJpLgJrC8DCUaQ">Geo...
# 2   data-hovercard-id="8-3NrFTF2FTnrCH_tTJ56w">Ter...
# 3   data-hovercard-id="7mi2C73t8gRRjGoGRYRVMA">Joh...
# 4   data-hovercard-id="lvhNF3xzUiSjBzMWsLkvhA">MIK...
# 5     data-hovercard-id="q4dkPeZpjfLIW3Jrsql_vA">J H.
# 6   data-hovercard-id="1MKGFUYo656ZSGnn4tdLJQ">Mar...
# 7   data-hovercard-id="6gW7yPgMXYEwzr87aD1dpQ">Mic...
# 8   data-hovercard-id="J4iiK8mDwMbGwIoUFom_QA">Mar...
# 9   data-hovercard-id="Pt9ObMZ10ZwUtENu8uHpyQ">Sig...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=180')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df20 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df20)):
    df20.author[i] = re.sub('<span class="user-display-name" ','',str(df20.author[i]))
    df20.author[i] = re.sub('</span>','',str(df20.author[i]))
    df20.date[i] = re.sub('<span class="rating-qualifier">','',str(df20.date[i]))
    df20.date[i] = re.sub('</span>','',str(df20.date[i]))
    df20.stars[i] = re.sub('<img alt="','',str(df20.stars[i]))
    df20.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df20.stars[i]))
    df20.review_body[i] = re.sub('<p lang="en">','',str(df20.review_body[i]))
    df20.review_body[i] = re.sub('</p>','',str(df20.review_body[i]))

print(df20.shape)
df20
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="s7o9ZKSQ2lEYfCWccJ3CzQ">Mic...
# 1   data-hovercard-id="v7kri-CFuWeT0RbrKeIiBg">Ser...
# 2   data-hovercard-id="a04-jbrks0JlViZOaMWBDg">Ric...
# 3   data-hovercard-id="gVMEcnz-QZSMsLCoFWoLqQ">Sco...
# 4   data-hovercard-id="u4EtX1WhdiFjCxYaIABOqw">Rac...
# 5   data-hovercard-id="U2G8ES4wpmN-bzfPg8PqUA">Jai...
# 6   data-hovercard-id="FZpgo5-YxGhlYVPKuxsSuw">Lin...
# 7   data-hovercard-id="rlg2Z3mXc30AFJnExdHqog">Evg...
# 8   data-hovercard-id="ClLm3lC1OQAI_PFfT0f4gg">Mur...
# 9     data-hovercard-id="fspb4MzHyffMV9sZY58A3w">I R.
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=190')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df21 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df21)):
    df21.author[i] = re.sub('<span class="user-display-name" ','',str(df21.author[i]))
    df21.author[i] = re.sub('</span>','',str(df21.author[i]))
    df21.date[i] = re.sub('<span class="rating-qualifier">','',str(df21.date[i]))
    df21.date[i] = re.sub('</span>','',str(df21.date[i]))
    df21.stars[i] = re.sub('<img alt="','',str(df21.stars[i]))
    df21.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df21.stars[i]))
    df21.review_body[i] = re.sub('<p lang="en">','',str(df21.review_body[i]))
    df21.review_body[i] = re.sub('</p>','',str(df21.review_body[i]))

print(df21.shape)
df21
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="mdIcYEfJJE4YTFAqxtvfdQ">Ara...
# 1   data-hovercard-id="N6LKixU0Xzj2P9Fy4-DBOQ">Joe...
# 2   data-hovercard-id="3DZ0ufJWb26j74sOjs2N3Q">Ann...
# 3   data-hovercard-id="Dgb9VkI_BhP0vz5XgHt45A">Ang...
# 4   data-hovercard-id="365CCLjvqPTyy-H0GUqq1w">Vir...
# 5   data-hovercard-id="1neVYsZiZVtjjdjJGRlcuA">Mel...
# 6   data-hovercard-id="_md3B667MLLIiZV_1dgBfQ">Edi...
# 7   data-hovercard-id="7_sbX_E_2ZSoIKE6_5XDaw">Mie Z.
# 8   data-hovercard-id="uUYOl4GfBiL0HjoXrecowQ">Cec...
# 9   data-hovercard-id="U8SQ9ReH9tvnISivpO11rQ">Pam...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=200')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df22 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df22)):
    df22.author[i] = re.sub('<span class="user-display-name" ','',str(df22.author[i]))
    df22.author[i] = re.sub('</span>','',str(df22.author[i]))
    df22.date[i] = re.sub('<span class="rating-qualifier">','',str(df22.date[i]))
    df22.date[i] = re.sub('</span>','',str(df22.date[i]))
    df22.stars[i] = re.sub('<img alt="','',str(df22.stars[i]))
    df22.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df22.stars[i]))
    df22.review_body[i] = re.sub('<p lang="en">','',str(df22.review_body[i]))
    df22.review_body[i] = re.sub('</p>','',str(df22.review_body[i]))

print(df22.shape)
df22
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="eN23EKxITM97l8IN4PC9wg">Car...
# 1   data-hovercard-id="Wqp_g3iRZxu5_SFRNdgsDQ">Chr...
# 2   data-hovercard-id="IZMmXb3HHnOaJvmMjPhxNg">Big S.
# 3   data-hovercard-id="ei-QQ2gzdn5hpSyKaX_ALA">Sam B.
# 4   data-hovercard-id="rSBXpyuKgZEtL10v_dOJVA">May...
# 5   data-hovercard-id="GArjdkCdYIQMWcAKVMTmxA">Cha...
# 6   data-hovercard-id="ftAu1HTj6SfTci1CWFVXLg">Jor...
# 7   data-hovercard-id="rWGEIj0VX7ZwotGMEoB8Zg">Tem...
# 8   data-hovercard-id="fWZ64imwr3YA3SVyhHxWMQ">Chr...
# 9   data-hovercard-id="3N3Jh_wIwVxkAvQXWSbddQ">Nik...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=210')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df23 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df23)):
    df23.author[i] = re.sub('<span class="user-display-name" ','',str(df23.author[i]))
    df23.author[i] = re.sub('</span>','',str(df23.author[i]))
    df23.date[i] = re.sub('<span class="rating-qualifier">','',str(df23.date[i]))
    df23.date[i] = re.sub('</span>','',str(df23.date[i]))
    df23.stars[i] = re.sub('<img alt="','',str(df23.stars[i]))
    df23.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df23.stars[i]))
    df23.review_body[i] = re.sub('<p lang="en">','',str(df23.review_body[i]))
    df23.review_body[i] = re.sub('</p>','',str(df23.review_body[i]))

print(df23.shape)
df23
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="czesibaKSJJFkWuBGCy1_A">Isa...
# 1   data-hovercard-id="aMyaC5XE-afYMwU3s2k8-Q">Nin...
# 2   data-hovercard-id="AZvXHiYglg83ggZP9H3otA">Viv...
# 3   data-hovercard-id="vGSsHrsHhdzRGGZJhVbMFA">Zha...
# 4   data-hovercard-id="MN6xvBp-r8IL387lijzX9Q">Dia...
# 5   data-hovercard-id="Lcffn863JUpVcKee12BQtg">How...
# 6   data-hovercard-id="NDX0JFXIlBsa2aZT9LMFIw">Dev...
# 7   data-hovercard-id="pxI4GW2BwwhCzpXtKJPMxw">Jan M.
# 8   data-hovercard-id="wuN9UPbJSO6GYsfs2prWzQ">Bob U.
# 9   data-hovercard-id="M-O4BebnSTdAVph8tcJy4A">Col...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=220')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') #another duplicate author problem
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
# df24 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=230')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df25 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df25)):
    df25.author[i] = re.sub('<span class="user-display-name" ','',str(df25.author[i]))
    df25.author[i] = re.sub('</span>','',str(df25.author[i]))
    df25.date[i] = re.sub('<span class="rating-qualifier">','',str(df25.date[i]))
    df25.date[i] = re.sub('</span>','',str(df25.date[i]))
    df25.stars[i] = re.sub('<img alt="','',str(df25.stars[i]))
    df25.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df25.stars[i]))
    df25.review_body[i] = re.sub('<p lang="en">','',str(df25.review_body[i]))
    df25.review_body[i] = re.sub('</p>','',str(df25.review_body[i]))

print(df25.shape)
df25
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="lSBPnl4-l838sfRBp3XoTg">Bar...
# 1   data-hovercard-id="HzRa6mclBPMWUFBjDo8_pw">Gin...
# 2    data-hovercard-id="PHeSyH3HCqNNBEhNZVJpGA">JP i.
# 3   data-hovercard-id="-ygVAPl7-d1U5XdJlC_mcg">Kat...
# 4   data-hovercard-id="tec2ZnSeewniefk1XLguhQ">Ale...
# 5   data-hovercard-id="_lCW7YgilE02iYyWw1R6ng">Gre...
# 6   data-hovercard-id="E_NaVaKtLTV2ciBTSt5hRw">Ang...
# 7   data-hovercard-id="ctZQAopSv6jb1tZh_1aRJQ">Jer...
# 8   data-hovercard-id="JdvwsdM-p_tMX8ywDZeyBA">Eva H.
# 9   data-hovercard-id="WtIR06-5Bt-xz-T00oyF4g">eri...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=240')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df26 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df26)):
    df26.author[i] = re.sub('<span class="user-display-name" ','',str(df26.author[i]))
    df26.author[i] = re.sub('</span>','',str(df26.author[i]))
    df26.date[i] = re.sub('<span class="rating-qualifier">','',str(df26.date[i]))
    df26.date[i] = re.sub('</span>','',str(df26.date[i]))
    df26.stars[i] = re.sub('<img alt="','',str(df26.stars[i]))
    df26.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df26.stars[i]))
    df26.review_body[i] = re.sub('<p lang="en">','',str(df26.review_body[i]))
    df26.review_body[i] = re.sub('</p>','',str(df26.review_body[i]))

print(df26.shape)
df26
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="ql5Md-6t2Mk2Bln8LTvS4w">Jus...
# 1   data-hovercard-id="p2_ZGAzVO3G7oKzwirZ9mA">Cou...
# 2   data-hovercard-id="Mn4lNKVX7p1KBgivfgndUQ">Ell...
# 3   data-hovercard-id="jR8hYzfBFP3RyqxGy1cu0A">Ser...
# 4   data-hovercard-id="z21sIHcK-u8fdhFduO7JvA">Sim...
# 5   data-hovercard-id="css-Vip4lcuboqCvZ6PreA">Ste...
# 6   data-hovercard-id="UjPFFl7QsAZXxltdGXbyow">Kei...
# 7   data-hovercard-id="vd5Y_ht7dNXlC1kosq4-jw">Jen...
# 8   data-hovercard-id="IcJzzwYFsesdTZpMKYKrPg">Jen...
# 9   data-hovercard-id="nIIQt47JR5Q2raEXXFUYWA">Aar...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=250')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df27 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df27)):
    df27.author[i] = re.sub('<span class="user-display-name" ','',str(df27.author[i]))
    df27.author[i] = re.sub('</span>','',str(df27.author[i]))
    df27.date[i] = re.sub('<span class="rating-qualifier">','',str(df27.date[i]))
    df27.date[i] = re.sub('</span>','',str(df27.date[i]))
    df27.stars[i] = re.sub('<img alt="','',str(df27.stars[i]))
    df27.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df27.stars[i]))
    df27.review_body[i] = re.sub('<p lang="en">','',str(df27.review_body[i]))
    df27.review_body[i] = re.sub('</p>','',str(df27.review_body[i]))

print(df27.shape)
df27
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="765qMjvGtzKM_-oANsLlXA">Don...
# 1   data-hovercard-id="w0ombpkxcTaMJvdnB2YD-w">V.L...
# 2   data-hovercard-id="NaxOejItRH8_JL4dAPdvhg">Meg B.
# 3     data-hovercard-id="fT7k8mB4TaniHjOwZbMO3g">Y L.
# 4     data-hovercard-id="mv0wRNcllXp0K9BPiF7bQA">s K.
# 5     data-hovercard-id="OwPIQE0o7lMKFCuNo50J8A">V B.
# 6   data-hovercard-id="qcNEwsCwXs9zQvikkQWwHQ">Lea...
# 7     data-hovercard-id="jzNtDLRHe-VX2Xg7OnhLfA">A C.
# 8   data-hovercard-id="se3wnBCiB8s-ehuLP2BYeQ">Yer...
# 9   data-hovercard-id="DZikpJ1gGmDrum1uVNIlaA">Rya...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=260')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') #another duplicate author problem
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
# df28 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=260')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') #another duplicate author problem
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
# df29 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=270')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df30 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df30)):
    df30.author[i] = re.sub('<span class="user-display-name" ','',str(df30.author[i]))
    df30.author[i] = re.sub('</span>','',str(df30.author[i]))
    df30.date[i] = re.sub('<span class="rating-qualifier">','',str(df30.date[i]))
    df30.date[i] = re.sub('</span>','',str(df30.date[i]))
    df30.stars[i] = re.sub('<img alt="','',str(df30.stars[i]))
    df30.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df30.stars[i]))
    df30.review_body[i] = re.sub('<p lang="en">','',str(df30.review_body[i]))
    df30.review_body[i] = re.sub('</p>','',str(df30.review_body[i]))

print(df30.shape)
df30
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="ADzRPNXwCQcvuSe6RXs5Vg">Alv...
# 1   data-hovercard-id="8LEpomNsPVxB8b1mqhDmgg">Cup...
# 2   data-hovercard-id="P3EIKRrgy7FTVZD_iPrGrg">Ali...
# 3   data-hovercard-id="M6t5LL__ylHpJyCg3QC1OA">Jim...
# 4   data-hovercard-id="S5nuHi1EVD0kAzefqq37Bg">Kay...
# 5   data-hovercard-id="ufLDC0PSZH40g9Ei-Ng2xA">Car...
# 6   data-hovercard-id="0udhmPp7oDN7fceM7rorLw">DML L.
# 7   data-hovercard-id="r0CBiqEFxSaEvT6PeAi5cw">Fra...
# 8   data-hovercard-id="1bcp9zyOlWucATmjuAiqKw">Rus...
# 9   data-hovercard-id="5JcKbZSozCzIvBaP9u_4Nw">Hea...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=280')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df31 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df31)):
    df31.author[i] = re.sub('<span class="user-display-name" ','',str(df31.author[i]))
    df31.author[i] = re.sub('</span>','',str(df31.author[i]))
    df31.date[i] = re.sub('<span class="rating-qualifier">','',str(df31.date[i]))
    df31.date[i] = re.sub('</span>','',str(df31.date[i]))
    df31.stars[i] = re.sub('<img alt="','',str(df31.stars[i]))
    df31.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df31.stars[i]))
    df31.review_body[i] = re.sub('<p lang="en">','',str(df31.review_body[i]))
    df31.review_body[i] = re.sub('</p>','',str(df31.review_body[i]))

print(df31.shape)
df31
# Out:
# (20, 4)
#                                                author  \
# 0   data-hovercard-id="p73Q8GrUs6bK8DWCPmqo-A">Ste...
# 1   data-hovercard-id="6lpf21UGy0-0sTZtCeWXoA">Son...
# 2   data-hovercard-id="Z1Ed40pknMCqPgmDXh8v7A">Amy N.
# 3   data-hovercard-id="L2TCbc0GWZKB9zRBxoY17A">Mar...
# 4   data-hovercard-id="uAP1O45S76_0ctyVF_H5pQ">Kur...
# 5   data-hovercard-id="RM9ioYFFlXdTPh3rab-KqA">Liz E.
# 6   data-hovercard-id="7PPWz3on4yRU79WIKziW2Q">Sar...
# 7   data-hovercard-id="KkPvJebN8MFxnpQcxSkRqw">Jes...
# 8   data-hovercard-id="vntq6vjH-kdLX5akk8ggHQ">mea...
# 9   data-hovercard-id="bjrTr5cLehJF4m65acVitg">Jus...
# 10  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 11  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 12  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 13  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 14  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 15  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=290')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df32 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df32)):
    df32.author[i] = re.sub('<span class="user-display-name" ','',str(df32.author[i]))
    df32.author[i] = re.sub('</span>','',str(df32.author[i]))
    df32.date[i] = re.sub('<span class="rating-qualifier">','',str(df32.date[i]))
    df32.date[i] = re.sub('</span>','',str(df32.date[i]))
    df32.stars[i] = re.sub('<img alt="','',str(df32.stars[i]))
    df32.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df32.stars[i]))
    df32.review_body[i] = re.sub('<p lang="en">','',str(df32.review_body[i]))
    df32.review_body[i] = re.sub('</p>','',str(df32.review_body[i]))

print(df32.shape)
df32
# Out:
# (12, 4)
#                                                author  \
# 0     data-hovercard-id="7ZAmRwctMaFnJZdV8CPl8Q">P J.
# 1   data-hovercard-id="YTiohCcFjd6ECCsZPQ3DOQ">Amy W.
# 2   data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 3   data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 4   data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 5   data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 6   data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 7   data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 8   data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 9   data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 10  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 11  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                          date stars  \
# 0   \n        12/6/2005\n       5.0
# 1    \n        9/8/2005\n       5.0
# 2    \n        6/4/2016\n       1.0
# 3   \n        5/30/2016\n       1.0
# 4   \n        11/9/2015\n       1.0
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=300')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df33 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df33)):
    df33.author[i] = re.sub('<span class="user-display-name" ','',str(df33.author[i]))
    df33.author[i] = re.sub('</span>','',str(df33.author[i]))
    df33.date[i] = re.sub('<span class="rating-qualifier">','',str(df33.date[i]))
    df33.date[i] = re.sub('</span>','',str(df33.date[i]))
    df33.stars[i] = re.sub('<img alt="','',str(df33.stars[i]))
    df33.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df33.stars[i]))
    df33.review_body[i] = re.sub('<p lang="en">','',str(df33.review_body[i]))
    df33.review_body[i] = re.sub('</p>','',str(df33.review_body[i]))

print(df33.shape)
df33
# Out:
# (10, 4)
#                                               author  \
# 0  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6  data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7  data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                         date stars  \
# 0   \n        6/4/2016\n       1.0
# 1  \n        5/30/2016\n       1.0
# 2  \n        11/9/2015\n       1.0
# 3  \n        11/8/2015\n       1.0
# 4  \n        11/6/2015\n       1.0
# 5  \n        11/5/2015\n       1.0
# 6  \n        11/5/2015\n       1.0
# 7   \n        9/1/2014\n       1.0
# 8   \n        4/3/2012\n       1.0
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=310')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df34 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df34)):
    df34.author[i] = re.sub('<span class="user-display-name" ','',str(df34.author[i]))
    df34.author[i] = re.sub('</span>','',str(df34.author[i]))
    df34.date[i] = re.sub('<span class="rating-qualifier">','',str(df34.date[i]))
    df34.date[i] = re.sub('</span>','',str(df34.date[i]))
    df34.stars[i] = re.sub('<img alt="','',str(df34.stars[i]))
    df34.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df34.stars[i]))
    df34.review_body[i] = re.sub('<p lang="en">','',str(df34.review_body[i]))
    df34.review_body[i] = re.sub('</p>','',str(df34.review_body[i]))

print(df34.shape)
df34
# Out:
# (10, 4)
#                                               author  \
# 0  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6  data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7  data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                         date stars  \
# 0   \n        6/4/2016\n       1.0
# 1  \n        5/30/2016\n       1.0
# 2  \n        11/9/2015\n       1.0
# 3  \n        11/8/2015\n       1.0
# 4  \n        11/6/2015\n       1.0
# 5  \n        11/5/2015\n       1.0
# 6  \n        11/5/2015\n       1.0
# 7   \n        9/1/2014\n       1.0
# 8   \n        4/3/2012\n       1.0
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=320')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df35 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df35)):
    df35.author[i] = re.sub('<span class="user-display-name" ','',str(df35.author[i]))
    df35.author[i] = re.sub('</span>','',str(df35.author[i]))
    df35.date[i] = re.sub('<span class="rating-qualifier">','',str(df35.date[i]))
    df35.date[i] = re.sub('</span>','',str(df35.date[i]))
    df35.stars[i] = re.sub('<img alt="','',str(df35.stars[i]))
    df35.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df35.stars[i]))
    df35.review_body[i] = re.sub('<p lang="en">','',str(df35.review_body[i]))
    df35.review_body[i] = re.sub('</p>','',str(df35.review_body[i]))

print(df35.shape)
df35
# Out:
# (10, 4)
#                                               author  \
# 0  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6  data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7  data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                         date stars  \
# 0   \n        6/4/2016\n       1.0
# 1  \n        5/30/2016\n       1.0
# 2  \n        11/9/2015\n       1.0
# 3  \n        11/8/2015\n       1.0
# 4  \n        11/6/2015\n       1.0
# 5  \n        11/5/2015\n       1.0
# 6  \n        11/5/2015\n       1.0
# 7   \n        9/1/2014\n       1.0
# 8   \n        4/3/2012\n       1.0
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=330')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df36 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df36)):
    df36.author[i] = re.sub('<span class="user-display-name" ','',str(df36.author[i]))
    df36.author[i] = re.sub('</span>','',str(df36.author[i]))
    df36.date[i] = re.sub('<span class="rating-qualifier">','',str(df36.date[i]))
    df36.date[i] = re.sub('</span>','',str(df36.date[i]))
    df36.stars[i] = re.sub('<img alt="','',str(df36.stars[i]))
    df36.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df36.stars[i]))
    df36.review_body[i] = re.sub('<p lang="en">','',str(df36.review_body[i]))
    df36.review_body[i] = re.sub('</p>','',str(df36.review_body[i]))

print(df36.shape)
df36
# Out:
# (10, 4)
#                                               author  \
# 0  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6  data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7  data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                         date stars  \
# 0   \n        6/4/2016\n       1.0
# 1  \n        5/30/2016\n       1.0
# 2  \n        11/9/2015\n       1.0
# 3  \n        11/8/2015\n       1.0
# 4  \n        11/6/2015\n       1.0
# 5  \n        11/5/2015\n       1.0
# 6  \n        11/5/2015\n       1.0
# 7   \n        9/1/2014\n       1.0
# 8   \n        4/3/2012\n       1.0
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=340')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df37 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df37)):
    df37.author[i] = re.sub('<span class="user-display-name" ','',str(df37.author[i]))
    df37.author[i] = re.sub('</span>','',str(df37.author[i]))
    df37.date[i] = re.sub('<span class="rating-qualifier">','',str(df37.date[i]))
    df37.date[i] = re.sub('</span>','',str(df37.date[i]))
    df37.stars[i] = re.sub('<img alt="','',str(df37.stars[i]))
    df37.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df37.stars[i]))
    df37.review_body[i] = re.sub('<p lang="en">','',str(df37.review_body[i]))
    df37.review_body[i] = re.sub('</p>','',str(df37.review_body[i]))

print(df37.shape)
df37
# Out:
# (10, 4)
#                                               author  \
# 0  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6  data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7  data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                         date stars  \
# 0   \n        6/4/2016\n       1.0
# 1  \n        5/30/2016\n       1.0
# 2  \n        11/9/2015\n       1.0
# 3  \n        11/8/2015\n       1.0
# 4  \n        11/6/2015\n       1.0
# 5  \n        11/5/2015\n       1.0
# 6  \n        11/5/2015\n       1.0
# 7   \n        9/1/2014\n       1.0
# 8   \n        4/3/2012\n       1.0
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=350')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df38 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df38)):
    df38.author[i] = re.sub('<span class="user-display-name" ','',str(df38.author[i]))
    df38.author[i] = re.sub('</span>','',str(df38.author[i]))
    df38.date[i] = re.sub('<span class="rating-qualifier">','',str(df38.date[i]))
    df38.date[i] = re.sub('</span>','',str(df38.date[i]))
    df38.stars[i] = re.sub('<img alt="','',str(df38.stars[i]))
    df38.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df38.stars[i]))
    df38.review_body[i] = re.sub('<p lang="en">','',str(df38.review_body[i]))
    df38.review_body[i] = re.sub('</p>','',str(df38.review_body[i]))

print(df38.shape)
df38
# Out:
# (10, 4)
#                                               author  \
# 0  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6  data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7  data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                         date stars  \
# 0   \n        6/4/2016\n       1.0
# 1  \n        5/30/2016\n       1.0
# 2  \n        11/9/2015\n       1.0
# 3  \n        11/8/2015\n       1.0
# 4  \n        11/6/2015\n       1.0
# 5  \n        11/5/2015\n       1.0
# 6  \n        11/5/2015\n       1.0
# 7   \n        9/1/2014\n       1.0
# 8   \n        4/3/2012\n       1.0
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=360')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df39 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df39)):
    df39.author[i] = re.sub('<span class="user-display-name" ','',str(df39.author[i]))
    df39.author[i] = re.sub('</span>','',str(df39.author[i]))
    df39.date[i] = re.sub('<span class="rating-qualifier">','',str(df39.date[i]))
    df39.date[i] = re.sub('</span>','',str(df39.date[i]))
    df39.stars[i] = re.sub('<img alt="','',str(df39.stars[i]))
    df39.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df39.stars[i]))
    df39.review_body[i] = re.sub('<p lang="en">','',str(df39.review_body[i]))
    df39.review_body[i] = re.sub('</p>','',str(df39.review_body[i]))

print(df39.shape)
df39
# Out:
# (10, 4)
#                                               author  \
# 0  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6  data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7  data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                         date stars  \
# 0   \n        6/4/2016\n       1.0
# 1  \n        5/30/2016\n       1.0
# 2  \n        11/9/2015\n       1.0
# 3  \n        11/8/2015\n       1.0
# 4  \n        11/6/2015\n       1.0
# 5  \n        11/5/2015\n       1.0
# 6  \n        11/5/2015\n       1.0
# 7   \n        9/1/2014\n       1.0
# 8   \n        4/3/2012\n       1.0
# ...

# %%
r = requests.get('https://www.yelp.com/not_recommended_reviews/zazie-san-francisco?not_recommended_start=370')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(class_ = 'user-display-name') 
date = soup.find_all(class_ = 'rating-qualifier')
stars = soup.find_all(width = '84')
review_body = soup.find_all(lang = 'en') #use only review_body[1:]
df40 = pd.DataFrame({'author':author,'date':date,'stars':stars,'review_body':review_body[1:]})

for i in range(len(df40)):
    df40.author[i] = re.sub('<span class="user-display-name" ','',str(df40.author[i]))
    df40.author[i] = re.sub('</span>','',str(df40.author[i]))
    df40.date[i] = re.sub('<span class="rating-qualifier">','',str(df40.date[i]))
    df40.date[i] = re.sub('</span>','',str(df40.date[i]))
    df40.stars[i] = re.sub('<img alt="','',str(df40.stars[i]))
    df40.stars[i] = re.sub(' star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>','',str(df40.stars[i]))
    df40.review_body[i] = re.sub('<p lang="en">','',str(df40.review_body[i]))
    df40.review_body[i] = re.sub('</p>','',str(df40.review_body[i]))

print(df40.shape)
df40
# Out:
# (10, 4)
#                                               author  \
# 0  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1  data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2  data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3  data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4  data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5  data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6  data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7  data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8  data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9  data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
#
#                         date stars  \
# 0   \n        6/4/2016\n       1.0
# 1  \n        5/30/2016\n       1.0
# 2  \n        11/9/2015\n       1.0
# 3  \n        11/8/2015\n       1.0
# 4  \n        11/6/2015\n       1.0
# 5  \n        11/5/2015\n       1.0
# 6  \n        11/5/2015\n       1.0
# 7   \n        9/1/2014\n       1.0
# 8   \n        4/3/2012\n       1.0
# ...

# %%
dfs = [df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df16,
       df17,df18,df19,df20,df21,df22,df23,df25,df26,df27,df30,df31,
       df32,df33,df34,df35,df36,df37,df38,df39,df40] #no df1, df15, df24, df28, or df29

DF = df40
for i in dfs:
    DF = DF.append(i, ignore_index=True)
    
print(DF.shape)
DF
# Out:
# (622, 4)
#                                                 author  \
# 0    data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 1    data-hovercard-id="6X2LpytOOFKN21lDLCmkPw">Bel...
# 2    data-hovercard-id="ZPP6RqeqUF7a-DF7u7ycJw">Lem...
# 3    data-hovercard-id="3GJlz2aAfe9nF6IWz-iEYg">Ale...
# 4    data-hovercard-id="zT546Ie-8llJhW2BazfDtg">And...
# 5    data-hovercard-id="47u_vSO99daeKLFLf6I6VQ">Nin...
# 6    data-hovercard-id="Yp8L5_paBztA7Mjx52sIKA">Gri...
# 7    data-hovercard-id="e9GVsuAhWG0M4wFtj9dCGg">Tha...
# 8    data-hovercard-id="U5XF-4nxobr_frJw-gdhNA">Cat...
# 9    data-hovercard-id="Cd1flZUdCzTpKQpB-kE4Jg">Car...
# 10   data-hovercard-id="IPbvDk7Jc9Ocp29pd6A9nQ">Ger...
# 11   data-hovercard-id="f3Lad7zNsPnvcyYWg3Tkkw">Kri...
# 12   data-hovercard-id="b5ivKffoYO2_gmc0MPnozA">Nic...
# 13   data-hovercard-id="QXBcpOROr3SdhaCiTztOkw">Mir...
# 14   data-hovercard-id="aS1UHHJ4hV-q2FCAOabswg">Rac...
# 15   data-hovercard-id="lFviuaiGd-gJPUtFSlmHrQ">Emi...
# ...

# %%
DF = DF.drop_duplicates()
DF.shape #whoa, almost 2/3 were duplicate rows
# Out:
# (262, 4)

# %%
DF.to_csv('/home/cynthiaorourke/Desktop/Yelp_Zazie/reviews_excluded.csv')
