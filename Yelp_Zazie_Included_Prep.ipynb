# %% [markdown]
# ## Sentiment Analysis for SF Restaurant Zazie - Included Reviews (4156 on 20190309 4:45 pm)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
from __future__ import division, unicode_literals 
import codecs

f=codecs.open('/home/cynthiaorourke/Desktop/Yelp_Zazie/Included/page_one.html', 'r', 'utf-8')
document= BeautifulSoup(f.read()).get_text()
print (document)
# Out:
# <!DOCTYPE HTML><!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]--><!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]--><!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]--><!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="no-js" lang="en"> <!--<![endif]--> <head> <script>            (function() {                var main = null;                var main=function(){window.onerror=function(k,a,c,i,f){var j=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true"||navigator.userAgent==="selenium");var h=f&&(f.name==="ServerSideRenderingError"||f.name==="CSRFallbackError");if(j&&!h){document.body.innerHTML="<
# ...

# %%
soup = BeautifulSoup(document, 'html.parser')

# print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <!--<![endif]-->
#  <head>
#   <script>
# ...

# %%
# Import `requests`
import requests

# Make the request and check object type
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=980')
html = r.text
soup = BeautifulSoup(html, "html5lib")
# Out:
# requests.models.Response

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df1 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df1)):
    df1.author[i] = re.sub('<meta content="','',str(df1.author[i]))
    df1.author[i] = re.sub('" itemprop="author"/>','',str(df1.author[i]))
    df1.date[i] = re.sub('<meta content="','',str(df1.date[i]))
    df1.date[i] = re.sub('" itemprop="datePublished"/>','',str(df1.date[i]))
    df1.stars[i] = re.sub('<meta content="','',str(df1.stars[i]))
    df1.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df1.stars[i]))
    df1.review_body[i] = re.sub('<p itemprop="description">','',str(df1.review_body[i]))
    df1.review_body[i] = re.sub('</p>','',str(df1.review_body[i]))

print(df1.shape)
df1.head()
# Out:
# (20, 4)
#       author        date stars  \
# 0     Bob U.  2019-03-04   5.0
# 1   Carol H.  2019-03-08   4.0
# 2   Jamie P.  2019-03-02   4.0
# 3  Eileen W.  2019-02-24   5.0
# 4   Donna T.  2019-02-14   5.0
#
#                                          review_body
# 0  love this Cole Valley spot for brunch. close e...
# 1  Discovered this neighborhood bistro in Cole Va...
# 2  My coworkers and I decided to pay a visit duri...
# 3  I can't believe I haven't reviewed this place ...
# 4  One of the most delightful brunch joints you'l...

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=20')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df2 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df2)):
    df2.author[i] = re.sub('<meta content="','',str(df2.author[i]))
    df2.author[i] = re.sub('" itemprop="author"/>','',str(df2.author[i]))
    df2.date[i] = re.sub('<meta content="','',str(df2.date[i]))
    df2.date[i] = re.sub('" itemprop="datePublished"/>','',str(df2.date[i]))
    df2.stars[i] = re.sub('<meta content="','',str(df2.stars[i]))
    df2.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df2.stars[i]))
    df2.review_body[i] = re.sub('<p itemprop="description">','',str(df2.review_body[i]))
    df2.review_body[i] = re.sub('</p>','',str(df2.review_body[i]))

print(df2.shape)
df2.head()
# Out:
# (20, 4)
#        author        date stars  \
# 0   Marina C.  2018-11-22   5.0
# 1  Chelsey C.  2019-02-07   5.0
# 2    Laksh M.  2018-11-20   4.0
# 3  Jocelyn K.  2018-10-28   3.0
# 4    Maria S.  2018-11-18   4.0
#
#                                          review_body
# 0  Love this place for brunch. Have been here 2-3...
# 1  Zazie was the perfect, hearty breakfast meal w...
# 2  After everyone talking about this place I had ...
# 3  Not bad for a brunch place. And it's a no tipp...
# 4  Review 700!  Who better to review for this mil...

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=40')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df3 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df3)):
    df3.author[i] = re.sub('<meta content="','',str(df3.author[i]))
    df3.author[i] = re.sub('" itemprop="author"/>','',str(df3.author[i]))
    df3.date[i] = re.sub('<meta content="','',str(df3.date[i]))
    df3.date[i] = re.sub('" itemprop="datePublished"/>','',str(df3.date[i]))
    df3.stars[i] = re.sub('<meta content="','',str(df3.stars[i]))
    df3.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df3.stars[i]))
    df3.review_body[i] = re.sub('<p itemprop="description">','',str(df3.review_body[i]))
    df3.review_body[i] = re.sub('</p>','',str(df3.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=60')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df4 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df4)):
    df4.author[i] = re.sub('<meta content="','',str(df4.author[i]))
    df4.author[i] = re.sub('" itemprop="author"/>','',str(df4.author[i]))
    df4.date[i] = re.sub('<meta content="','',str(df4.date[i]))
    df4.date[i] = re.sub('" itemprop="datePublished"/>','',str(df4.date[i]))
    df4.stars[i] = re.sub('<meta content="','',str(df4.stars[i]))
    df4.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df4.stars[i]))
    df4.review_body[i] = re.sub('<p itemprop="description">','',str(df4.review_body[i]))
    df4.review_body[i] = re.sub('</p>','',str(df4.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=80')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df5 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df5)):
    df5.author[i] = re.sub('<meta content="','',str(df5.author[i]))
    df5.author[i] = re.sub('" itemprop="author"/>','',str(df5.author[i]))
    df5.date[i] = re.sub('<meta content="','',str(df5.date[i]))
    df5.date[i] = re.sub('" itemprop="datePublished"/>','',str(df5.date[i]))
    df5.stars[i] = re.sub('<meta content="','',str(df5.stars[i]))
    df5.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df5.stars[i]))
    df5.review_body[i] = re.sub('<p itemprop="description">','',str(df5.review_body[i]))
    df5.review_body[i] = re.sub('</p>','',str(df5.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=100')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df6 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df6)):
    df6.author[i] = re.sub('<meta content="','',str(df6.author[i]))
    df6.author[i] = re.sub('" itemprop="author"/>','',str(df6.author[i]))
    df6.date[i] = re.sub('<meta content="','',str(df6.date[i]))
    df6.date[i] = re.sub('" itemprop="datePublished"/>','',str(df6.date[i]))
    df6.stars[i] = re.sub('<meta content="','',str(df6.stars[i]))
    df6.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df6.stars[i]))
    df6.review_body[i] = re.sub('<p itemprop="description">','',str(df6.review_body[i]))
    df6.review_body[i] = re.sub('</p>','',str(df6.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=120')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df7 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df7)):
    df7.author[i] = re.sub('<meta content="','',str(df7.author[i]))
    df7.author[i] = re.sub('" itemprop="author"/>','',str(df7.author[i]))
    df7.date[i] = re.sub('<meta content="','',str(df7.date[i]))
    df7.date[i] = re.sub('" itemprop="datePublished"/>','',str(df7.date[i]))
    df7.stars[i] = re.sub('<meta content="','',str(df7.stars[i]))
    df7.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df7.stars[i]))
    df7.review_body[i] = re.sub('<p itemprop="description">','',str(df7.review_body[i]))
    df7.review_body[i] = re.sub('</p>','',str(df7.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=140')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df8 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df8)):
    df8.author[i] = re.sub('<meta content="','',str(df8.author[i]))
    df8.author[i] = re.sub('" itemprop="author"/>','',str(df8.author[i]))
    df8.date[i] = re.sub('<meta content="','',str(df8.date[i]))
    df8.date[i] = re.sub('" itemprop="datePublished"/>','',str(df8.date[i]))
    df8.stars[i] = re.sub('<meta content="','',str(df8.stars[i]))
    df8.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df8.stars[i]))
    df8.review_body[i] = re.sub('<p itemprop="description">','',str(df8.review_body[i]))
    df8.review_body[i] = re.sub('</p>','',str(df8.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=160')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df9 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df9)):
    df9.author[i] = re.sub('<meta content="','',str(df9.author[i]))
    df9.author[i] = re.sub('" itemprop="author"/>','',str(df9.author[i]))
    df9.date[i] = re.sub('<meta content="','',str(df9.date[i]))
    df9.date[i] = re.sub('" itemprop="datePublished"/>','',str(df9.date[i]))
    df9.stars[i] = re.sub('<meta content="','',str(df9.stars[i]))
    df9.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df9.stars[i]))
    df9.review_body[i] = re.sub('<p itemprop="description">','',str(df9.review_body[i]))
    df9.review_body[i] = re.sub('</p>','',str(df9.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=180')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df10 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df10)):
    df10.author[i] = re.sub('<meta content="','',str(df10.author[i]))
    df10.author[i] = re.sub('" itemprop="author"/>','',str(df10.author[i]))
    df10.date[i] = re.sub('<meta content="','',str(df10.date[i]))
    df10.date[i] = re.sub('" itemprop="datePublished"/>','',str(df10.date[i]))
    df10.stars[i] = re.sub('<meta content="','',str(df10.stars[i]))
    df10.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df10.stars[i]))
    df10.review_body[i] = re.sub('<p itemprop="description">','',str(df10.review_body[i]))
    df10.review_body[i] = re.sub('</p>','',str(df10.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=200')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df11 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df11)):
    df11.author[i] = re.sub('<meta content="','',str(df11.author[i]))
    df11.author[i] = re.sub('" itemprop="author"/>','',str(df11.author[i]))
    df11.date[i] = re.sub('<meta content="','',str(df11.date[i]))
    df11.date[i] = re.sub('" itemprop="datePublished"/>','',str(df11.date[i]))
    df11.stars[i] = re.sub('<meta content="','',str(df11.stars[i]))
    df11.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df11.stars[i]))
    df11.review_body[i] = re.sub('<p itemprop="description">','',str(df11.review_body[i]))
    df11.review_body[i] = re.sub('</p>','',str(df11.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=220')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df12 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df12)):
    df12.author[i] = re.sub('<meta content="','',str(df12.author[i]))
    df12.author[i] = re.sub('" itemprop="author"/>','',str(df12.author[i]))
    df12.date[i] = re.sub('<meta content="','',str(df12.date[i]))
    df12.date[i] = re.sub('" itemprop="datePublished"/>','',str(df12.date[i]))
    df12.stars[i] = re.sub('<meta content="','',str(df12.stars[i]))
    df12.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df12.stars[i]))
    df12.review_body[i] = re.sub('<p itemprop="description">','',str(df12.review_body[i]))
    df12.review_body[i] = re.sub('</p>','',str(df12.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=240')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df13 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df13)):
    df13.author[i] = re.sub('<meta content="','',str(df13.author[i]))
    df13.author[i] = re.sub('" itemprop="author"/>','',str(df13.author[i]))
    df13.date[i] = re.sub('<meta content="','',str(df13.date[i]))
    df13.date[i] = re.sub('" itemprop="datePublished"/>','',str(df13.date[i]))
    df13.stars[i] = re.sub('<meta content="','',str(df13.stars[i]))
    df13.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df13.stars[i]))
    df13.review_body[i] = re.sub('<p itemprop="description">','',str(df13.review_body[i]))
    df13.review_body[i] = re.sub('</p>','',str(df13.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=260')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df14 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df14)):
    df14.author[i] = re.sub('<meta content="','',str(df14.author[i]))
    df14.author[i] = re.sub('" itemprop="author"/>','',str(df14.author[i]))
    df14.date[i] = re.sub('<meta content="','',str(df14.date[i]))
    df14.date[i] = re.sub('" itemprop="datePublished"/>','',str(df14.date[i]))
    df14.stars[i] = re.sub('<meta content="','',str(df14.stars[i]))
    df14.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df14.stars[i]))
    df14.review_body[i] = re.sub('<p itemprop="description">','',str(df14.review_body[i]))
    df14.review_body[i] = re.sub('</p>','',str(df14.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=280')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df15 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df15)):
    df15.author[i] = re.sub('<meta content="','',str(df15.author[i]))
    df15.author[i] = re.sub('" itemprop="author"/>','',str(df15.author[i]))
    df15.date[i] = re.sub('<meta content="','',str(df15.date[i]))
    df15.date[i] = re.sub('" itemprop="datePublished"/>','',str(df15.date[i]))
    df15.stars[i] = re.sub('<meta content="','',str(df15.stars[i]))
    df15.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df15.stars[i]))
    df15.review_body[i] = re.sub('<p itemprop="description">','',str(df15.review_body[i]))
    df15.review_body[i] = re.sub('</p>','',str(df15.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=300')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df16 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df16)):
    df16.author[i] = re.sub('<meta content="','',str(df16.author[i]))
    df16.author[i] = re.sub('" itemprop="author"/>','',str(df16.author[i]))
    df16.date[i] = re.sub('<meta content="','',str(df16.date[i]))
    df16.date[i] = re.sub('" itemprop="datePublished"/>','',str(df16.date[i]))
    df16.stars[i] = re.sub('<meta content="','',str(df16.stars[i]))
    df16.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df16.stars[i]))
    df16.review_body[i] = re.sub('<p itemprop="description">','',str(df16.review_body[i]))
    df16.review_body[i] = re.sub('</p>','',str(df16.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=320')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df17 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df17)):
    df17.author[i] = re.sub('<meta content="','',str(df17.author[i]))
    df17.author[i] = re.sub('" itemprop="author"/>','',str(df17.author[i]))
    df17.date[i] = re.sub('<meta content="','',str(df17.date[i]))
    df17.date[i] = re.sub('" itemprop="datePublished"/>','',str(df17.date[i]))
    df17.stars[i] = re.sub('<meta content="','',str(df17.stars[i]))
    df17.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df17.stars[i]))
    df17.review_body[i] = re.sub('<p itemprop="description">','',str(df17.review_body[i]))
    df17.review_body[i] = re.sub('</p>','',str(df17.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=340')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df18 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df18)):
    df18.author[i] = re.sub('<meta content="','',str(df18.author[i]))
    df18.author[i] = re.sub('" itemprop="author"/>','',str(df18.author[i]))
    df18.date[i] = re.sub('<meta content="','',str(df18.date[i]))
    df18.date[i] = re.sub('" itemprop="datePublished"/>','',str(df18.date[i]))
    df18.stars[i] = re.sub('<meta content="','',str(df18.stars[i]))
    df18.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df18.stars[i]))
    df18.review_body[i] = re.sub('<p itemprop="description">','',str(df18.review_body[i]))
    df18.review_body[i] = re.sub('</p>','',str(df18.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=360')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df19 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df19)):
    df19.author[i] = re.sub('<meta content="','',str(df19.author[i]))
    df19.author[i] = re.sub('" itemprop="author"/>','',str(df19.author[i]))
    df19.date[i] = re.sub('<meta content="','',str(df19.date[i]))
    df19.date[i] = re.sub('" itemprop="datePublished"/>','',str(df19.date[i]))
    df19.stars[i] = re.sub('<meta content="','',str(df19.stars[i]))
    df19.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df19.stars[i]))
    df19.review_body[i] = re.sub('<p itemprop="description">','',str(df19.review_body[i]))
    df19.review_body[i] = re.sub('</p>','',str(df19.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=380')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df20 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df20)):
    df20.author[i] = re.sub('<meta content="','',str(df20.author[i]))
    df20.author[i] = re.sub('" itemprop="author"/>','',str(df20.author[i]))
    df20.date[i] = re.sub('<meta content="','',str(df20.date[i]))
    df20.date[i] = re.sub('" itemprop="datePublished"/>','',str(df20.date[i]))
    df20.stars[i] = re.sub('<meta content="','',str(df20.stars[i]))
    df20.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df20.stars[i]))
    df20.review_body[i] = re.sub('<p itemprop="description">','',str(df20.review_body[i]))
    df20.review_body[i] = re.sub('</p>','',str(df20.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=400')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df21 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df21)):
    df21.author[i] = re.sub('<meta content="','',str(df21.author[i]))
    df21.author[i] = re.sub('" itemprop="author"/>','',str(df21.author[i]))
    df21.date[i] = re.sub('<meta content="','',str(df21.date[i]))
    df21.date[i] = re.sub('" itemprop="datePublished"/>','',str(df21.date[i]))
    df21.stars[i] = re.sub('<meta content="','',str(df21.stars[i]))
    df21.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df21.stars[i]))
    df21.review_body[i] = re.sub('<p itemprop="description">','',str(df21.review_body[i]))
    df21.review_body[i] = re.sub('</p>','',str(df21.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=420')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df22 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df22)):
    df22.author[i] = re.sub('<meta content="','',str(df22.author[i]))
    df22.author[i] = re.sub('" itemprop="author"/>','',str(df22.author[i]))
    df22.date[i] = re.sub('<meta content="','',str(df22.date[i]))
    df22.date[i] = re.sub('" itemprop="datePublished"/>','',str(df22.date[i]))
    df22.stars[i] = re.sub('<meta content="','',str(df22.stars[i]))
    df22.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df22.stars[i]))
    df22.review_body[i] = re.sub('<p itemprop="description">','',str(df22.review_body[i]))
    df22.review_body[i] = re.sub('</p>','',str(df22.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=440')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df23 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df23)):
    df23.author[i] = re.sub('<meta content="','',str(df23.author[i]))
    df23.author[i] = re.sub('" itemprop="author"/>','',str(df23.author[i]))
    df23.date[i] = re.sub('<meta content="','',str(df23.date[i]))
    df23.date[i] = re.sub('" itemprop="datePublished"/>','',str(df23.date[i]))
    df23.stars[i] = re.sub('<meta content="','',str(df23.stars[i]))
    df23.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df23.stars[i]))
    df23.review_body[i] = re.sub('<p itemprop="description">','',str(df23.review_body[i]))
    df23.review_body[i] = re.sub('</p>','',str(df23.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=460')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df24 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df24)):
    df24.author[i] = re.sub('<meta content="','',str(df24.author[i]))
    df24.author[i] = re.sub('" itemprop="author"/>','',str(df24.author[i]))
    df24.date[i] = re.sub('<meta content="','',str(df24.date[i]))
    df24.date[i] = re.sub('" itemprop="datePublished"/>','',str(df24.date[i]))
    df24.stars[i] = re.sub('<meta content="','',str(df24.stars[i]))
    df24.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df24.stars[i]))
    df24.review_body[i] = re.sub('<p itemprop="description">','',str(df24.review_body[i]))
    df24.review_body[i] = re.sub('</p>','',str(df24.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=480')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df25 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df25)):
    df25.author[i] = re.sub('<meta content="','',str(df25.author[i]))
    df25.author[i] = re.sub('" itemprop="author"/>','',str(df25.author[i]))
    df25.date[i] = re.sub('<meta content="','',str(df25.date[i]))
    df25.date[i] = re.sub('" itemprop="datePublished"/>','',str(df25.date[i]))
    df25.stars[i] = re.sub('<meta content="','',str(df25.stars[i]))
    df25.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df25.stars[i]))
    df25.review_body[i] = re.sub('<p itemprop="description">','',str(df25.review_body[i]))
    df25.review_body[i] = re.sub('</p>','',str(df25.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=500')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df26 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df26)):
    df26.author[i] = re.sub('<meta content="','',str(df26.author[i]))
    df26.author[i] = re.sub('" itemprop="author"/>','',str(df26.author[i]))
    df26.date[i] = re.sub('<meta content="','',str(df26.date[i]))
    df26.date[i] = re.sub('" itemprop="datePublished"/>','',str(df26.date[i]))
    df26.stars[i] = re.sub('<meta content="','',str(df26.stars[i]))
    df26.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df26.stars[i]))
    df26.review_body[i] = re.sub('<p itemprop="description">','',str(df26.review_body[i]))
    df26.review_body[i] = re.sub('</p>','',str(df26.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=520')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df27 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df27)):
    df27.author[i] = re.sub('<meta content="','',str(df27.author[i]))
    df27.author[i] = re.sub('" itemprop="author"/>','',str(df27.author[i]))
    df27.date[i] = re.sub('<meta content="','',str(df27.date[i]))
    df27.date[i] = re.sub('" itemprop="datePublished"/>','',str(df27.date[i]))
    df27.stars[i] = re.sub('<meta content="','',str(df27.stars[i]))
    df27.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df27.stars[i]))
    df27.review_body[i] = re.sub('<p itemprop="description">','',str(df27.review_body[i]))
    df27.review_body[i] = re.sub('</p>','',str(df27.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=540')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df28 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df28)):
    df28.author[i] = re.sub('<meta content="','',str(df28.author[i]))
    df28.author[i] = re.sub('" itemprop="author"/>','',str(df28.author[i]))
    df28.date[i] = re.sub('<meta content="','',str(df28.date[i]))
    df28.date[i] = re.sub('" itemprop="datePublished"/>','',str(df28.date[i]))
    df28.stars[i] = re.sub('<meta content="','',str(df28.stars[i]))
    df28.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df28.stars[i]))
    df28.review_body[i] = re.sub('<p itemprop="description">','',str(df28.review_body[i]))
    df28.review_body[i] = re.sub('</p>','',str(df28.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=560')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df29 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df29)):
    df29.author[i] = re.sub('<meta content="','',str(df29.author[i]))
    df29.author[i] = re.sub('" itemprop="author"/>','',str(df29.author[i]))
    df29.date[i] = re.sub('<meta content="','',str(df29.date[i]))
    df29.date[i] = re.sub('" itemprop="datePublished"/>','',str(df29.date[i]))
    df29.stars[i] = re.sub('<meta content="','',str(df29.stars[i]))
    df29.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df29.stars[i]))
    df29.review_body[i] = re.sub('<p itemprop="description">','',str(df29.review_body[i]))
    df29.review_body[i] = re.sub('</p>','',str(df29.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=580')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df30 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df30)):
    df30.author[i] = re.sub('<meta content="','',str(df30.author[i]))
    df30.author[i] = re.sub('" itemprop="author"/>','',str(df30.author[i]))
    df30.date[i] = re.sub('<meta content="','',str(df30.date[i]))
    df30.date[i] = re.sub('" itemprop="datePublished"/>','',str(df30.date[i]))
    df30.stars[i] = re.sub('<meta content="','',str(df30.stars[i]))
    df30.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df30.stars[i]))
    df30.review_body[i] = re.sub('<p itemprop="description">','',str(df30.review_body[i]))
    df30.review_body[i] = re.sub('</p>','',str(df30.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=600')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df31 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df31)):
    df31.author[i] = re.sub('<meta content="','',str(df31.author[i]))
    df31.author[i] = re.sub('" itemprop="author"/>','',str(df31.author[i]))
    df31.date[i] = re.sub('<meta content="','',str(df31.date[i]))
    df31.date[i] = re.sub('" itemprop="datePublished"/>','',str(df31.date[i]))
    df31.stars[i] = re.sub('<meta content="','',str(df31.stars[i]))
    df31.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df31.stars[i]))
    df31.review_body[i] = re.sub('<p itemprop="description">','',str(df31.review_body[i]))
    df31.review_body[i] = re.sub('</p>','',str(df31.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=620')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df32 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df32)):
    df32.author[i] = re.sub('<meta content="','',str(df32.author[i]))
    df32.author[i] = re.sub('" itemprop="author"/>','',str(df32.author[i]))
    df32.date[i] = re.sub('<meta content="','',str(df32.date[i]))
    df32.date[i] = re.sub('" itemprop="datePublished"/>','',str(df32.date[i]))
    df32.stars[i] = re.sub('<meta content="','',str(df32.stars[i]))
    df32.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df32.stars[i]))
    df32.review_body[i] = re.sub('<p itemprop="description">','',str(df32.review_body[i]))
    df32.review_body[i] = re.sub('</p>','',str(df32.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=640')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df33 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df33)):
    df33.author[i] = re.sub('<meta content="','',str(df33.author[i]))
    df33.author[i] = re.sub('" itemprop="author"/>','',str(df33.author[i]))
    df33.date[i] = re.sub('<meta content="','',str(df33.date[i]))
    df33.date[i] = re.sub('" itemprop="datePublished"/>','',str(df33.date[i]))
    df33.stars[i] = re.sub('<meta content="','',str(df33.stars[i]))
    df33.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df33.stars[i]))
    df33.review_body[i] = re.sub('<p itemprop="description">','',str(df33.review_body[i]))
    df33.review_body[i] = re.sub('</p>','',str(df33.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=660')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df34 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df34)):
    df34.author[i] = re.sub('<meta content="','',str(df34.author[i]))
    df34.author[i] = re.sub('" itemprop="author"/>','',str(df34.author[i]))
    df34.date[i] = re.sub('<meta content="','',str(df34.date[i]))
    df34.date[i] = re.sub('" itemprop="datePublished"/>','',str(df34.date[i]))
    df34.stars[i] = re.sub('<meta content="','',str(df34.stars[i]))
    df34.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df34.stars[i]))
    df34.review_body[i] = re.sub('<p itemprop="description">','',str(df34.review_body[i]))
    df34.review_body[i] = re.sub('</p>','',str(df34.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=680')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df35 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df35)):
    df35.author[i] = re.sub('<meta content="','',str(df35.author[i]))
    df35.author[i] = re.sub('" itemprop="author"/>','',str(df35.author[i]))
    df35.date[i] = re.sub('<meta content="','',str(df35.date[i]))
    df35.date[i] = re.sub('" itemprop="datePublished"/>','',str(df35.date[i]))
    df35.stars[i] = re.sub('<meta content="','',str(df35.stars[i]))
    df35.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df35.stars[i]))
    df35.review_body[i] = re.sub('<p itemprop="description">','',str(df35.review_body[i]))
    df35.review_body[i] = re.sub('</p>','',str(df35.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=700')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df36 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df36)):
    df36.author[i] = re.sub('<meta content="','',str(df36.author[i]))
    df36.author[i] = re.sub('" itemprop="author"/>','',str(df36.author[i]))
    df36.date[i] = re.sub('<meta content="','',str(df36.date[i]))
    df36.date[i] = re.sub('" itemprop="datePublished"/>','',str(df36.date[i]))
    df36.stars[i] = re.sub('<meta content="','',str(df36.stars[i]))
    df36.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df36.stars[i]))
    df36.review_body[i] = re.sub('<p itemprop="description">','',str(df36.review_body[i]))
    df36.review_body[i] = re.sub('</p>','',str(df36.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=720')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df37 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df37)):
    df37.author[i] = re.sub('<meta content="','',str(df37.author[i]))
    df37.author[i] = re.sub('" itemprop="author"/>','',str(df37.author[i]))
    df37.date[i] = re.sub('<meta content="','',str(df37.date[i]))
    df37.date[i] = re.sub('" itemprop="datePublished"/>','',str(df37.date[i]))
    df37.stars[i] = re.sub('<meta content="','',str(df37.stars[i]))
    df37.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df37.stars[i]))
    df37.review_body[i] = re.sub('<p itemprop="description">','',str(df37.review_body[i]))
    df37.review_body[i] = re.sub('</p>','',str(df37.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=740')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df38 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df38)):
    df38.author[i] = re.sub('<meta content="','',str(df38.author[i]))
    df38.author[i] = re.sub('" itemprop="author"/>','',str(df38.author[i]))
    df38.date[i] = re.sub('<meta content="','',str(df38.date[i]))
    df38.date[i] = re.sub('" itemprop="datePublished"/>','',str(df38.date[i]))
    df38.stars[i] = re.sub('<meta content="','',str(df38.stars[i]))
    df38.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df38.stars[i]))
    df38.review_body[i] = re.sub('<p itemprop="description">','',str(df38.review_body[i]))
    df38.review_body[i] = re.sub('</p>','',str(df38.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=760')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df39 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df39)):
    df39.author[i] = re.sub('<meta content="','',str(df39.author[i]))
    df39.author[i] = re.sub('" itemprop="author"/>','',str(df39.author[i]))
    df39.date[i] = re.sub('<meta content="','',str(df39.date[i]))
    df39.date[i] = re.sub('" itemprop="datePublished"/>','',str(df39.date[i]))
    df39.stars[i] = re.sub('<meta content="','',str(df39.stars[i]))
    df39.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df39.stars[i]))
    df39.review_body[i] = re.sub('<p itemprop="description">','',str(df39.review_body[i]))
    df39.review_body[i] = re.sub('</p>','',str(df39.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=780')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df40 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df40)):
    df40.author[i] = re.sub('<meta content="','',str(df40.author[i]))
    df40.author[i] = re.sub('" itemprop="author"/>','',str(df40.author[i]))
    df40.date[i] = re.sub('<meta content="','',str(df40.date[i]))
    df40.date[i] = re.sub('" itemprop="datePublished"/>','',str(df40.date[i]))
    df40.stars[i] = re.sub('<meta content="','',str(df40.stars[i]))
    df40.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df40.stars[i]))
    df40.review_body[i] = re.sub('<p itemprop="description">','',str(df40.review_body[i]))
    df40.review_body[i] = re.sub('</p>','',str(df40.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=800')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df41 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df41)):
    df41.author[i] = re.sub('<meta content="','',str(df41.author[i]))
    df41.author[i] = re.sub('" itemprop="author"/>','',str(df41.author[i]))
    df41.date[i] = re.sub('<meta content="','',str(df41.date[i]))
    df41.date[i] = re.sub('" itemprop="datePublished"/>','',str(df41.date[i]))
    df41.stars[i] = re.sub('<meta content="','',str(df41.stars[i]))
    df41.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df41.stars[i]))
    df41.review_body[i] = re.sub('<p itemprop="description">','',str(df41.review_body[i]))
    df41.review_body[i] = re.sub('</p>','',str(df41.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=820')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df42 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df42)):
    df42.author[i] = re.sub('<meta content="','',str(df42.author[i]))
    df42.author[i] = re.sub('" itemprop="author"/>','',str(df42.author[i]))
    df42.date[i] = re.sub('<meta content="','',str(df42.date[i]))
    df42.date[i] = re.sub('" itemprop="datePublished"/>','',str(df42.date[i]))
    df42.stars[i] = re.sub('<meta content="','',str(df42.stars[i]))
    df42.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df42.stars[i]))
    df42.review_body[i] = re.sub('<p itemprop="description">','',str(df42.review_body[i]))
    df42.review_body[i] = re.sub('</p>','',str(df42.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=840')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df43 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df43)):
    df43.author[i] = re.sub('<meta content="','',str(df43.author[i]))
    df43.author[i] = re.sub('" itemprop="author"/>','',str(df43.author[i]))
    df43.date[i] = re.sub('<meta content="','',str(df43.date[i]))
    df43.date[i] = re.sub('" itemprop="datePublished"/>','',str(df43.date[i]))
    df43.stars[i] = re.sub('<meta content="','',str(df43.stars[i]))
    df43.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df43.stars[i]))
    df43.review_body[i] = re.sub('<p itemprop="description">','',str(df43.review_body[i]))
    df43.review_body[i] = re.sub('</p>','',str(df43.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=860')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df44 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df44)):
    df44.author[i] = re.sub('<meta content="','',str(df44.author[i]))
    df44.author[i] = re.sub('" itemprop="author"/>','',str(df44.author[i]))
    df44.date[i] = re.sub('<meta content="','',str(df44.date[i]))
    df44.date[i] = re.sub('" itemprop="datePublished"/>','',str(df44.date[i]))
    df44.stars[i] = re.sub('<meta content="','',str(df44.stars[i]))
    df44.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df44.stars[i]))
    df44.review_body[i] = re.sub('<p itemprop="description">','',str(df44.review_body[i]))
    df44.review_body[i] = re.sub('</p>','',str(df44.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=880')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df45 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df45)):
    df45.author[i] = re.sub('<meta content="','',str(df45.author[i]))
    df45.author[i] = re.sub('" itemprop="author"/>','',str(df45.author[i]))
    df45.date[i] = re.sub('<meta content="','',str(df45.date[i]))
    df45.date[i] = re.sub('" itemprop="datePublished"/>','',str(df45.date[i]))
    df45.stars[i] = re.sub('<meta content="','',str(df45.stars[i]))
    df45.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df45.stars[i]))
    df45.review_body[i] = re.sub('<p itemprop="description">','',str(df45.review_body[i]))
    df45.review_body[i] = re.sub('</p>','',str(df45.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=900')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df46 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df46)):
    df46.author[i] = re.sub('<meta content="','',str(df46.author[i]))
    df46.author[i] = re.sub('" itemprop="author"/>','',str(df46.author[i]))
    df46.date[i] = re.sub('<meta content="','',str(df46.date[i]))
    df46.date[i] = re.sub('" itemprop="datePublished"/>','',str(df46.date[i]))
    df46.stars[i] = re.sub('<meta content="','',str(df46.stars[i]))
    df46.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df46.stars[i]))
    df46.review_body[i] = re.sub('<p itemprop="description">','',str(df46.review_body[i]))
    df46.review_body[i] = re.sub('</p>','',str(df46.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=920')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df47 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df47)):
    df47.author[i] = re.sub('<meta content="','',str(df47.author[i]))
    df47.author[i] = re.sub('" itemprop="author"/>','',str(df47.author[i]))
    df47.date[i] = re.sub('<meta content="','',str(df47.date[i]))
    df47.date[i] = re.sub('" itemprop="datePublished"/>','',str(df47.date[i]))
    df47.stars[i] = re.sub('<meta content="','',str(df47.stars[i]))
    df47.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df47.stars[i]))
    df47.review_body[i] = re.sub('<p itemprop="description">','',str(df47.review_body[i]))
    df47.review_body[i] = re.sub('</p>','',str(df47.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=940')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df48 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df48)):
    df48.author[i] = re.sub('<meta content="','',str(df48.author[i]))
    df48.author[i] = re.sub('" itemprop="author"/>','',str(df48.author[i]))
    df48.date[i] = re.sub('<meta content="','',str(df48.date[i]))
    df48.date[i] = re.sub('" itemprop="datePublished"/>','',str(df48.date[i]))
    df48.stars[i] = re.sub('<meta content="','',str(df48.stars[i]))
    df48.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df48.stars[i]))
    df48.review_body[i] = re.sub('<p itemprop="description">','',str(df48.review_body[i]))
    df48.review_body[i] = re.sub('</p>','',str(df48.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=960')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df49 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df49)):
    df49.author[i] = re.sub('<meta content="','',str(df49.author[i]))
    df49.author[i] = re.sub('" itemprop="author"/>','',str(df49.author[i]))
    df49.date[i] = re.sub('<meta content="','',str(df49.date[i]))
    df49.date[i] = re.sub('" itemprop="datePublished"/>','',str(df49.date[i]))
    df49.stars[i] = re.sub('<meta content="','',str(df49.stars[i]))
    df49.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df49.stars[i]))
    df49.review_body[i] = re.sub('<p itemprop="description">','',str(df49.review_body[i]))
    df49.review_body[i] = re.sub('</p>','',str(df49.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=980')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df50 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df50)):
    df50.author[i] = re.sub('<meta content="','',str(df50.author[i]))
    df50.author[i] = re.sub('" itemprop="author"/>','',str(df50.author[i]))
    df50.date[i] = re.sub('<meta content="','',str(df50.date[i]))
    df50.date[i] = re.sub('" itemprop="datePublished"/>','',str(df50.date[i]))
    df50.stars[i] = re.sub('<meta content="','',str(df50.stars[i]))
    df50.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df50.stars[i]))
    df50.review_body[i] = re.sub('<p itemprop="description">','',str(df50.review_body[i]))
    df50.review_body[i] = re.sub('</p>','',str(df50.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1000')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df51 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df51)):
    df51.author[i] = re.sub('<meta content="','',str(df51.author[i]))
    df51.author[i] = re.sub('" itemprop="author"/>','',str(df51.author[i]))
    df51.date[i] = re.sub('<meta content="','',str(df51.date[i]))
    df51.date[i] = re.sub('" itemprop="datePublished"/>','',str(df51.date[i]))
    df51.stars[i] = re.sub('<meta content="','',str(df51.stars[i]))
    df51.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df51.stars[i]))
    df51.review_body[i] = re.sub('<p itemprop="description">','',str(df51.review_body[i]))
    df51.review_body[i] = re.sub('</p>','',str(df51.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1020')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df52 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df52)):
    df52.author[i] = re.sub('<meta content="','',str(df52.author[i]))
    df52.author[i] = re.sub('" itemprop="author"/>','',str(df52.author[i]))
    df52.date[i] = re.sub('<meta content="','',str(df52.date[i]))
    df52.date[i] = re.sub('" itemprop="datePublished"/>','',str(df52.date[i]))
    df52.stars[i] = re.sub('<meta content="','',str(df52.stars[i]))
    df52.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df52.stars[i]))
    df52.review_body[i] = re.sub('<p itemprop="description">','',str(df52.review_body[i]))
    df52.review_body[i] = re.sub('</p>','',str(df52.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1040')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df53 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df53)):
    df53.author[i] = re.sub('<meta content="','',str(df53.author[i]))
    df53.author[i] = re.sub('" itemprop="author"/>','',str(df53.author[i]))
    df53.date[i] = re.sub('<meta content="','',str(df53.date[i]))
    df53.date[i] = re.sub('" itemprop="datePublished"/>','',str(df53.date[i]))
    df53.stars[i] = re.sub('<meta content="','',str(df53.stars[i]))
    df53.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df53.stars[i]))
    df53.review_body[i] = re.sub('<p itemprop="description">','',str(df53.review_body[i]))
    df53.review_body[i] = re.sub('</p>','',str(df53.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1060')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df54 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df54)):
    df54.author[i] = re.sub('<meta content="','',str(df54.author[i]))
    df54.author[i] = re.sub('" itemprop="author"/>','',str(df54.author[i]))
    df54.date[i] = re.sub('<meta content="','',str(df54.date[i]))
    df54.date[i] = re.sub('" itemprop="datePublished"/>','',str(df54.date[i]))
    df54.stars[i] = re.sub('<meta content="','',str(df54.stars[i]))
    df54.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df54.stars[i]))
    df54.review_body[i] = re.sub('<p itemprop="description">','',str(df54.review_body[i]))
    df54.review_body[i] = re.sub('</p>','',str(df54.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1080')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df55 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df55)):
    df55.author[i] = re.sub('<meta content="','',str(df55.author[i]))
    df55.author[i] = re.sub('" itemprop="author"/>','',str(df55.author[i]))
    df55.date[i] = re.sub('<meta content="','',str(df55.date[i]))
    df55.date[i] = re.sub('" itemprop="datePublished"/>','',str(df55.date[i]))
    df55.stars[i] = re.sub('<meta content="','',str(df55.stars[i]))
    df55.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df55.stars[i]))
    df55.review_body[i] = re.sub('<p itemprop="description">','',str(df55.review_body[i]))
    df55.review_body[i] = re.sub('</p>','',str(df55.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1100')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df56 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df56)):
    df56.author[i] = re.sub('<meta content="','',str(df56.author[i]))
    df56.author[i] = re.sub('" itemprop="author"/>','',str(df56.author[i]))
    df56.date[i] = re.sub('<meta content="','',str(df56.date[i]))
    df56.date[i] = re.sub('" itemprop="datePublished"/>','',str(df56.date[i]))
    df56.stars[i] = re.sub('<meta content="','',str(df56.stars[i]))
    df56.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df56.stars[i]))
    df56.review_body[i] = re.sub('<p itemprop="description">','',str(df56.review_body[i]))
    df56.review_body[i] = re.sub('</p>','',str(df56.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1120')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df57 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df57)):
    df57.author[i] = re.sub('<meta content="','',str(df57.author[i]))
    df57.author[i] = re.sub('" itemprop="author"/>','',str(df57.author[i]))
    df57.date[i] = re.sub('<meta content="','',str(df57.date[i]))
    df57.date[i] = re.sub('" itemprop="datePublished"/>','',str(df57.date[i]))
    df57.stars[i] = re.sub('<meta content="','',str(df57.stars[i]))
    df57.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df57.stars[i]))
    df57.review_body[i] = re.sub('<p itemprop="description">','',str(df57.review_body[i]))
    df57.review_body[i] = re.sub('</p>','',str(df57.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1140')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df58 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df58)):
    df58.author[i] = re.sub('<meta content="','',str(df58.author[i]))
    df58.author[i] = re.sub('" itemprop="author"/>','',str(df58.author[i]))
    df58.date[i] = re.sub('<meta content="','',str(df58.date[i]))
    df58.date[i] = re.sub('" itemprop="datePublished"/>','',str(df58.date[i]))
    df58.stars[i] = re.sub('<meta content="','',str(df58.stars[i]))
    df58.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df58.stars[i]))
    df58.review_body[i] = re.sub('<p itemprop="description">','',str(df58.review_body[i]))
    df58.review_body[i] = re.sub('</p>','',str(df58.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1160')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df59 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df59)):
    df59.author[i] = re.sub('<meta content="','',str(df59.author[i]))
    df59.author[i] = re.sub('" itemprop="author"/>','',str(df59.author[i]))
    df59.date[i] = re.sub('<meta content="','',str(df59.date[i]))
    df59.date[i] = re.sub('" itemprop="datePublished"/>','',str(df59.date[i]))
    df59.stars[i] = re.sub('<meta content="','',str(df59.stars[i]))
    df59.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df59.stars[i]))
    df59.review_body[i] = re.sub('<p itemprop="description">','',str(df59.review_body[i]))
    df59.review_body[i] = re.sub('</p>','',str(df59.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1180')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df60 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df60)):
    df60.author[i] = re.sub('<meta content="','',str(df60.author[i]))
    df60.author[i] = re.sub('" itemprop="author"/>','',str(df60.author[i]))
    df60.date[i] = re.sub('<meta content="','',str(df60.date[i]))
    df60.date[i] = re.sub('" itemprop="datePublished"/>','',str(df60.date[i]))
    df60.stars[i] = re.sub('<meta content="','',str(df60.stars[i]))
    df60.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df60.stars[i]))
    df60.review_body[i] = re.sub('<p itemprop="description">','',str(df60.review_body[i]))
    df60.review_body[i] = re.sub('</p>','',str(df60.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1200')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df61 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df61)):
    df61.author[i] = re.sub('<meta content="','',str(df61.author[i]))
    df61.author[i] = re.sub('" itemprop="author"/>','',str(df61.author[i]))
    df61.date[i] = re.sub('<meta content="','',str(df61.date[i]))
    df61.date[i] = re.sub('" itemprop="datePublished"/>','',str(df61.date[i]))
    df61.stars[i] = re.sub('<meta content="','',str(df61.stars[i]))
    df61.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df61.stars[i]))
    df61.review_body[i] = re.sub('<p itemprop="description">','',str(df61.review_body[i]))
    df61.review_body[i] = re.sub('</p>','',str(df61.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1220')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df62 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df62)):
    df62.author[i] = re.sub('<meta content="','',str(df62.author[i]))
    df62.author[i] = re.sub('" itemprop="author"/>','',str(df62.author[i]))
    df62.date[i] = re.sub('<meta content="','',str(df62.date[i]))
    df62.date[i] = re.sub('" itemprop="datePublished"/>','',str(df62.date[i]))
    df62.stars[i] = re.sub('<meta content="','',str(df62.stars[i]))
    df62.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df62.stars[i]))
    df62.review_body[i] = re.sub('<p itemprop="description">','',str(df62.review_body[i]))
    df62.review_body[i] = re.sub('</p>','',str(df62.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1240')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df63 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df63)):
    df63.author[i] = re.sub('<meta content="','',str(df63.author[i]))
    df63.author[i] = re.sub('" itemprop="author"/>','',str(df63.author[i]))
    df63.date[i] = re.sub('<meta content="','',str(df63.date[i]))
    df63.date[i] = re.sub('" itemprop="datePublished"/>','',str(df63.date[i]))
    df63.stars[i] = re.sub('<meta content="','',str(df63.stars[i]))
    df63.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df63.stars[i]))
    df63.review_body[i] = re.sub('<p itemprop="description">','',str(df63.review_body[i]))
    df63.review_body[i] = re.sub('</p>','',str(df63.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1260')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df64 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df64)):
    df64.author[i] = re.sub('<meta content="','',str(df64.author[i]))
    df64.author[i] = re.sub('" itemprop="author"/>','',str(df64.author[i]))
    df64.date[i] = re.sub('<meta content="','',str(df64.date[i]))
    df64.date[i] = re.sub('" itemprop="datePublished"/>','',str(df64.date[i]))
    df64.stars[i] = re.sub('<meta content="','',str(df64.stars[i]))
    df64.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df64.stars[i]))
    df64.review_body[i] = re.sub('<p itemprop="description">','',str(df64.review_body[i]))
    df64.review_body[i] = re.sub('</p>','',str(df64.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1280')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df65 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df65)):
    df65.author[i] = re.sub('<meta content="','',str(df65.author[i]))
    df65.author[i] = re.sub('" itemprop="author"/>','',str(df65.author[i]))
    df65.date[i] = re.sub('<meta content="','',str(df65.date[i]))
    df65.date[i] = re.sub('" itemprop="datePublished"/>','',str(df65.date[i]))
    df65.stars[i] = re.sub('<meta content="','',str(df65.stars[i]))
    df65.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df65.stars[i]))
    df65.review_body[i] = re.sub('<p itemprop="description">','',str(df65.review_body[i]))
    df65.review_body[i] = re.sub('</p>','',str(df65.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1300')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df66 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df66)):
    df66.author[i] = re.sub('<meta content="','',str(df66.author[i]))
    df66.author[i] = re.sub('" itemprop="author"/>','',str(df66.author[i]))
    df66.date[i] = re.sub('<meta content="','',str(df66.date[i]))
    df66.date[i] = re.sub('" itemprop="datePublished"/>','',str(df66.date[i]))
    df66.stars[i] = re.sub('<meta content="','',str(df66.stars[i]))
    df66.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df66.stars[i]))
    df66.review_body[i] = re.sub('<p itemprop="description">','',str(df66.review_body[i]))
    df66.review_body[i] = re.sub('</p>','',str(df66.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1320')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df67 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df67)):
    df67.author[i] = re.sub('<meta content="','',str(df67.author[i]))
    df67.author[i] = re.sub('" itemprop="author"/>','',str(df67.author[i]))
    df67.date[i] = re.sub('<meta content="','',str(df67.date[i]))
    df67.date[i] = re.sub('" itemprop="datePublished"/>','',str(df67.date[i]))
    df67.stars[i] = re.sub('<meta content="','',str(df67.stars[i]))
    df67.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df67.stars[i]))
    df67.review_body[i] = re.sub('<p itemprop="description">','',str(df67.review_body[i]))
    df67.review_body[i] = re.sub('</p>','',str(df67.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1340')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df68 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df68)):
    df68.author[i] = re.sub('<meta content="','',str(df68.author[i]))
    df68.author[i] = re.sub('" itemprop="author"/>','',str(df68.author[i]))
    df68.date[i] = re.sub('<meta content="','',str(df68.date[i]))
    df68.date[i] = re.sub('" itemprop="datePublished"/>','',str(df68.date[i]))
    df68.stars[i] = re.sub('<meta content="','',str(df68.stars[i]))
    df68.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df68.stars[i]))
    df68.review_body[i] = re.sub('<p itemprop="description">','',str(df68.review_body[i]))
    df68.review_body[i] = re.sub('</p>','',str(df68.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1360')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df69 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df69)):
    df69.author[i] = re.sub('<meta content="','',str(df69.author[i]))
    df69.author[i] = re.sub('" itemprop="author"/>','',str(df69.author[i]))
    df69.date[i] = re.sub('<meta content="','',str(df69.date[i]))
    df69.date[i] = re.sub('" itemprop="datePublished"/>','',str(df69.date[i]))
    df69.stars[i] = re.sub('<meta content="','',str(df69.stars[i]))
    df69.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df69.stars[i]))
    df69.review_body[i] = re.sub('<p itemprop="description">','',str(df69.review_body[i]))
    df69.review_body[i] = re.sub('</p>','',str(df69.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1380')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df70 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df70)):
    df70.author[i] = re.sub('<meta content="','',str(df70.author[i]))
    df70.author[i] = re.sub('" itemprop="author"/>','',str(df70.author[i]))
    df70.date[i] = re.sub('<meta content="','',str(df70.date[i]))
    df70.date[i] = re.sub('" itemprop="datePublished"/>','',str(df70.date[i]))
    df70.stars[i] = re.sub('<meta content="','',str(df70.stars[i]))
    df70.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df70.stars[i]))
    df70.review_body[i] = re.sub('<p itemprop="description">','',str(df70.review_body[i]))
    df70.review_body[i] = re.sub('</p>','',str(df70.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1400')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df71 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df71)):
    df71.author[i] = re.sub('<meta content="','',str(df71.author[i]))
    df71.author[i] = re.sub('" itemprop="author"/>','',str(df71.author[i]))
    df71.date[i] = re.sub('<meta content="','',str(df71.date[i]))
    df71.date[i] = re.sub('" itemprop="datePublished"/>','',str(df71.date[i]))
    df71.stars[i] = re.sub('<meta content="','',str(df71.stars[i]))
    df71.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df71.stars[i]))
    df71.review_body[i] = re.sub('<p itemprop="description">','',str(df71.review_body[i]))
    df71.review_body[i] = re.sub('</p>','',str(df71.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1420')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df72 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df72)):
    df72.author[i] = re.sub('<meta content="','',str(df72.author[i]))
    df72.author[i] = re.sub('" itemprop="author"/>','',str(df72.author[i]))
    df72.date[i] = re.sub('<meta content="','',str(df72.date[i]))
    df72.date[i] = re.sub('" itemprop="datePublished"/>','',str(df72.date[i]))
    df72.stars[i] = re.sub('<meta content="','',str(df72.stars[i]))
    df72.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df72.stars[i]))
    df72.review_body[i] = re.sub('<p itemprop="description">','',str(df72.review_body[i]))
    df72.review_body[i] = re.sub('</p>','',str(df72.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1440')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df73 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df73)):
    df73.author[i] = re.sub('<meta content="','',str(df73.author[i]))
    df73.author[i] = re.sub('" itemprop="author"/>','',str(df73.author[i]))
    df73.date[i] = re.sub('<meta content="','',str(df73.date[i]))
    df73.date[i] = re.sub('" itemprop="datePublished"/>','',str(df73.date[i]))
    df73.stars[i] = re.sub('<meta content="','',str(df73.stars[i]))
    df73.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df73.stars[i]))
    df73.review_body[i] = re.sub('<p itemprop="description">','',str(df73.review_body[i]))
    df73.review_body[i] = re.sub('</p>','',str(df73.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1460')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df74 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df74)):
    df74.author[i] = re.sub('<meta content="','',str(df74.author[i]))
    df74.author[i] = re.sub('" itemprop="author"/>','',str(df74.author[i]))
    df74.date[i] = re.sub('<meta content="','',str(df74.date[i]))
    df74.date[i] = re.sub('" itemprop="datePublished"/>','',str(df74.date[i]))
    df74.stars[i] = re.sub('<meta content="','',str(df74.stars[i]))
    df74.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df74.stars[i]))
    df74.review_body[i] = re.sub('<p itemprop="description">','',str(df74.review_body[i]))
    df74.review_body[i] = re.sub('</p>','',str(df74.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1480')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df75 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df75)):
    df75.author[i] = re.sub('<meta content="','',str(df75.author[i]))
    df75.author[i] = re.sub('" itemprop="author"/>','',str(df75.author[i]))
    df75.date[i] = re.sub('<meta content="','',str(df75.date[i]))
    df75.date[i] = re.sub('" itemprop="datePublished"/>','',str(df75.date[i]))
    df75.stars[i] = re.sub('<meta content="','',str(df75.stars[i]))
    df75.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df75.stars[i]))
    df75.review_body[i] = re.sub('<p itemprop="description">','',str(df75.review_body[i]))
    df75.review_body[i] = re.sub('</p>','',str(df75.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1500')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df76 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df76)):
    df76.author[i] = re.sub('<meta content="','',str(df76.author[i]))
    df76.author[i] = re.sub('" itemprop="author"/>','',str(df76.author[i]))
    df76.date[i] = re.sub('<meta content="','',str(df76.date[i]))
    df76.date[i] = re.sub('" itemprop="datePublished"/>','',str(df76.date[i]))
    df76.stars[i] = re.sub('<meta content="','',str(df76.stars[i]))
    df76.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df76.stars[i]))
    df76.review_body[i] = re.sub('<p itemprop="description">','',str(df76.review_body[i]))
    df76.review_body[i] = re.sub('</p>','',str(df76.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1520')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df77 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df77)):
    df77.author[i] = re.sub('<meta content="','',str(df77.author[i]))
    df77.author[i] = re.sub('" itemprop="author"/>','',str(df77.author[i]))
    df77.date[i] = re.sub('<meta content="','',str(df77.date[i]))
    df77.date[i] = re.sub('" itemprop="datePublished"/>','',str(df77.date[i]))
    df77.stars[i] = re.sub('<meta content="','',str(df77.stars[i]))
    df77.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df77.stars[i]))
    df77.review_body[i] = re.sub('<p itemprop="description">','',str(df77.review_body[i]))
    df77.review_body[i] = re.sub('</p>','',str(df77.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1540')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df78 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df78)):
    df78.author[i] = re.sub('<meta content="','',str(df78.author[i]))
    df78.author[i] = re.sub('" itemprop="author"/>','',str(df78.author[i]))
    df78.date[i] = re.sub('<meta content="','',str(df78.date[i]))
    df78.date[i] = re.sub('" itemprop="datePublished"/>','',str(df78.date[i]))
    df78.stars[i] = re.sub('<meta content="','',str(df78.stars[i]))
    df78.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df78.stars[i]))
    df78.review_body[i] = re.sub('<p itemprop="description">','',str(df78.review_body[i]))
    df78.review_body[i] = re.sub('</p>','',str(df78.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1560')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df79 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df79)):
    df79.author[i] = re.sub('<meta content="','',str(df79.author[i]))
    df79.author[i] = re.sub('" itemprop="author"/>','',str(df79.author[i]))
    df79.date[i] = re.sub('<meta content="','',str(df79.date[i]))
    df79.date[i] = re.sub('" itemprop="datePublished"/>','',str(df79.date[i]))
    df79.stars[i] = re.sub('<meta content="','',str(df79.stars[i]))
    df79.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df79.stars[i]))
    df79.review_body[i] = re.sub('<p itemprop="description">','',str(df79.review_body[i]))
    df79.review_body[i] = re.sub('</p>','',str(df79.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1580')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df80 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df80)):
    df80.author[i] = re.sub('<meta content="','',str(df80.author[i]))
    df80.author[i] = re.sub('" itemprop="author"/>','',str(df80.author[i]))
    df80.date[i] = re.sub('<meta content="','',str(df80.date[i]))
    df80.date[i] = re.sub('" itemprop="datePublished"/>','',str(df80.date[i]))
    df80.stars[i] = re.sub('<meta content="','',str(df80.stars[i]))
    df80.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df80.stars[i]))
    df80.review_body[i] = re.sub('<p itemprop="description">','',str(df80.review_body[i]))
    df80.review_body[i] = re.sub('</p>','',str(df80.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1600')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df81 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df81)):
    df81.author[i] = re.sub('<meta content="','',str(df81.author[i]))
    df81.author[i] = re.sub('" itemprop="author"/>','',str(df81.author[i]))
    df81.date[i] = re.sub('<meta content="','',str(df81.date[i]))
    df81.date[i] = re.sub('" itemprop="datePublished"/>','',str(df81.date[i]))
    df81.stars[i] = re.sub('<meta content="','',str(df81.stars[i]))
    df81.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df81.stars[i]))
    df81.review_body[i] = re.sub('<p itemprop="description">','',str(df81.review_body[i]))
    df81.review_body[i] = re.sub('</p>','',str(df81.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1620')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df82 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df82)):
    df82.author[i] = re.sub('<meta content="','',str(df82.author[i]))
    df82.author[i] = re.sub('" itemprop="author"/>','',str(df82.author[i]))
    df82.date[i] = re.sub('<meta content="','',str(df82.date[i]))
    df82.date[i] = re.sub('" itemprop="datePublished"/>','',str(df82.date[i]))
    df82.stars[i] = re.sub('<meta content="','',str(df82.stars[i]))
    df82.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df82.stars[i]))
    df82.review_body[i] = re.sub('<p itemprop="description">','',str(df82.review_body[i]))
    df82.review_body[i] = re.sub('</p>','',str(df82.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1640')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df83 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df83)):
    df83.author[i] = re.sub('<meta content="','',str(df83.author[i]))
    df83.author[i] = re.sub('" itemprop="author"/>','',str(df83.author[i]))
    df83.date[i] = re.sub('<meta content="','',str(df83.date[i]))
    df83.date[i] = re.sub('" itemprop="datePublished"/>','',str(df83.date[i]))
    df83.stars[i] = re.sub('<meta content="','',str(df83.stars[i]))
    df83.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df83.stars[i]))
    df83.review_body[i] = re.sub('<p itemprop="description">','',str(df83.review_body[i]))
    df83.review_body[i] = re.sub('</p>','',str(df83.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1660')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df84 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df84)):
    df84.author[i] = re.sub('<meta content="','',str(df84.author[i]))
    df84.author[i] = re.sub('" itemprop="author"/>','',str(df84.author[i]))
    df84.date[i] = re.sub('<meta content="','',str(df84.date[i]))
    df84.date[i] = re.sub('" itemprop="datePublished"/>','',str(df84.date[i]))
    df84.stars[i] = re.sub('<meta content="','',str(df84.stars[i]))
    df84.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df84.stars[i]))
    df84.review_body[i] = re.sub('<p itemprop="description">','',str(df84.review_body[i]))
    df84.review_body[i] = re.sub('</p>','',str(df84.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1680')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df85 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df85)):
    df85.author[i] = re.sub('<meta content="','',str(df85.author[i]))
    df85.author[i] = re.sub('" itemprop="author"/>','',str(df85.author[i]))
    df85.date[i] = re.sub('<meta content="','',str(df85.date[i]))
    df85.date[i] = re.sub('" itemprop="datePublished"/>','',str(df85.date[i]))
    df85.stars[i] = re.sub('<meta content="','',str(df85.stars[i]))
    df85.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df85.stars[i]))
    df85.review_body[i] = re.sub('<p itemprop="description">','',str(df85.review_body[i]))
    df85.review_body[i] = re.sub('</p>','',str(df85.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1700')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df86 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df86)):
    df86.author[i] = re.sub('<meta content="','',str(df86.author[i]))
    df86.author[i] = re.sub('" itemprop="author"/>','',str(df86.author[i]))
    df86.date[i] = re.sub('<meta content="','',str(df86.date[i]))
    df86.date[i] = re.sub('" itemprop="datePublished"/>','',str(df86.date[i]))
    df86.stars[i] = re.sub('<meta content="','',str(df86.stars[i]))
    df86.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df86.stars[i]))
    df86.review_body[i] = re.sub('<p itemprop="description">','',str(df86.review_body[i]))
    df86.review_body[i] = re.sub('</p>','',str(df86.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1720')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df87 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df87)):
    df87.author[i] = re.sub('<meta content="','',str(df87.author[i]))
    df87.author[i] = re.sub('" itemprop="author"/>','',str(df87.author[i]))
    df87.date[i] = re.sub('<meta content="','',str(df87.date[i]))
    df87.date[i] = re.sub('" itemprop="datePublished"/>','',str(df87.date[i]))
    df87.stars[i] = re.sub('<meta content="','',str(df87.stars[i]))
    df87.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df87.stars[i]))
    df87.review_body[i] = re.sub('<p itemprop="description">','',str(df87.review_body[i]))
    df87.review_body[i] = re.sub('</p>','',str(df87.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1740')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df88 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df88)):
    df88.author[i] = re.sub('<meta content="','',str(df88.author[i]))
    df88.author[i] = re.sub('" itemprop="author"/>','',str(df88.author[i]))
    df88.date[i] = re.sub('<meta content="','',str(df88.date[i]))
    df88.date[i] = re.sub('" itemprop="datePublished"/>','',str(df88.date[i]))
    df88.stars[i] = re.sub('<meta content="','',str(df88.stars[i]))
    df88.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df88.stars[i]))
    df88.review_body[i] = re.sub('<p itemprop="description">','',str(df88.review_body[i]))
    df88.review_body[i] = re.sub('</p>','',str(df88.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1760')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df89 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df89)):
    df89.author[i] = re.sub('<meta content="','',str(df89.author[i]))
    df89.author[i] = re.sub('" itemprop="author"/>','',str(df89.author[i]))
    df89.date[i] = re.sub('<meta content="','',str(df89.date[i]))
    df89.date[i] = re.sub('" itemprop="datePublished"/>','',str(df89.date[i]))
    df89.stars[i] = re.sub('<meta content="','',str(df89.stars[i]))
    df89.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df89.stars[i]))
    df89.review_body[i] = re.sub('<p itemprop="description">','',str(df89.review_body[i]))
    df89.review_body[i] = re.sub('</p>','',str(df89.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1780')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df90 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df90)):
    df90.author[i] = re.sub('<meta content="','',str(df90.author[i]))
    df90.author[i] = re.sub('" itemprop="author"/>','',str(df90.author[i]))
    df90.date[i] = re.sub('<meta content="','',str(df90.date[i]))
    df90.date[i] = re.sub('" itemprop="datePublished"/>','',str(df90.date[i]))
    df90.stars[i] = re.sub('<meta content="','',str(df90.stars[i]))
    df90.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df90.stars[i]))
    df90.review_body[i] = re.sub('<p itemprop="description">','',str(df90.review_body[i]))
    df90.review_body[i] = re.sub('</p>','',str(df90.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1800')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df91 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df91)):
    df91.author[i] = re.sub('<meta content="','',str(df91.author[i]))
    df91.author[i] = re.sub('" itemprop="author"/>','',str(df91.author[i]))
    df91.date[i] = re.sub('<meta content="','',str(df91.date[i]))
    df91.date[i] = re.sub('" itemprop="datePublished"/>','',str(df91.date[i]))
    df91.stars[i] = re.sub('<meta content="','',str(df91.stars[i]))
    df91.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df91.stars[i]))
    df91.review_body[i] = re.sub('<p itemprop="description">','',str(df91.review_body[i]))
    df91.review_body[i] = re.sub('</p>','',str(df91.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1820')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df92 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df92)):
    df92.author[i] = re.sub('<meta content="','',str(df92.author[i]))
    df92.author[i] = re.sub('" itemprop="author"/>','',str(df92.author[i]))
    df92.date[i] = re.sub('<meta content="','',str(df92.date[i]))
    df92.date[i] = re.sub('" itemprop="datePublished"/>','',str(df92.date[i]))
    df92.stars[i] = re.sub('<meta content="','',str(df92.stars[i]))
    df92.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df92.stars[i]))
    df92.review_body[i] = re.sub('<p itemprop="description">','',str(df92.review_body[i]))
    df92.review_body[i] = re.sub('</p>','',str(df92.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1840')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df93 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df93)):
    df93.author[i] = re.sub('<meta content="','',str(df93.author[i]))
    df93.author[i] = re.sub('" itemprop="author"/>','',str(df93.author[i]))
    df93.date[i] = re.sub('<meta content="','',str(df93.date[i]))
    df93.date[i] = re.sub('" itemprop="datePublished"/>','',str(df93.date[i]))
    df93.stars[i] = re.sub('<meta content="','',str(df93.stars[i]))
    df93.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df93.stars[i]))
    df93.review_body[i] = re.sub('<p itemprop="description">','',str(df93.review_body[i]))
    df93.review_body[i] = re.sub('</p>','',str(df93.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1860')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df94 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df94)):
    df94.author[i] = re.sub('<meta content="','',str(df94.author[i]))
    df94.author[i] = re.sub('" itemprop="author"/>','',str(df94.author[i]))
    df94.date[i] = re.sub('<meta content="','',str(df94.date[i]))
    df94.date[i] = re.sub('" itemprop="datePublished"/>','',str(df94.date[i]))
    df94.stars[i] = re.sub('<meta content="','',str(df94.stars[i]))
    df94.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df94.stars[i]))
    df94.review_body[i] = re.sub('<p itemprop="description">','',str(df94.review_body[i]))
    df94.review_body[i] = re.sub('</p>','',str(df94.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1880')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df95 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df95)):
    df95.author[i] = re.sub('<meta content="','',str(df95.author[i]))
    df95.author[i] = re.sub('" itemprop="author"/>','',str(df95.author[i]))
    df95.date[i] = re.sub('<meta content="','',str(df95.date[i]))
    df95.date[i] = re.sub('" itemprop="datePublished"/>','',str(df95.date[i]))
    df95.stars[i] = re.sub('<meta content="','',str(df95.stars[i]))
    df95.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df95.stars[i]))
    df95.review_body[i] = re.sub('<p itemprop="description">','',str(df95.review_body[i]))
    df95.review_body[i] = re.sub('</p>','',str(df95.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1900')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df96 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df96)):
    df96.author[i] = re.sub('<meta content="','',str(df96.author[i]))
    df96.author[i] = re.sub('" itemprop="author"/>','',str(df96.author[i]))
    df96.date[i] = re.sub('<meta content="','',str(df96.date[i]))
    df96.date[i] = re.sub('" itemprop="datePublished"/>','',str(df96.date[i]))
    df96.stars[i] = re.sub('<meta content="','',str(df96.stars[i]))
    df96.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df96.stars[i]))
    df96.review_body[i] = re.sub('<p itemprop="description">','',str(df96.review_body[i]))
    df96.review_body[i] = re.sub('</p>','',str(df96.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1920')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df97 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df97)):
    df97.author[i] = re.sub('<meta content="','',str(df97.author[i]))
    df97.author[i] = re.sub('" itemprop="author"/>','',str(df97.author[i]))
    df97.date[i] = re.sub('<meta content="','',str(df97.date[i]))
    df97.date[i] = re.sub('" itemprop="datePublished"/>','',str(df97.date[i]))
    df97.stars[i] = re.sub('<meta content="','',str(df97.stars[i]))
    df97.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df97.stars[i]))
    df97.review_body[i] = re.sub('<p itemprop="description">','',str(df97.review_body[i]))
    df97.review_body[i] = re.sub('</p>','',str(df97.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1940')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df98 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df98)):
    df98.author[i] = re.sub('<meta content="','',str(df98.author[i]))
    df98.author[i] = re.sub('" itemprop="author"/>','',str(df98.author[i]))
    df98.date[i] = re.sub('<meta content="','',str(df98.date[i]))
    df98.date[i] = re.sub('" itemprop="datePublished"/>','',str(df98.date[i]))
    df98.stars[i] = re.sub('<meta content="','',str(df98.stars[i]))
    df98.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df98.stars[i]))
    df98.review_body[i] = re.sub('<p itemprop="description">','',str(df98.review_body[i]))
    df98.review_body[i] = re.sub('</p>','',str(df98.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1960')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df99 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df99)):
    df99.author[i] = re.sub('<meta content="','',str(df99.author[i]))
    df99.author[i] = re.sub('" itemprop="author"/>','',str(df99.author[i]))
    df99.date[i] = re.sub('<meta content="','',str(df99.date[i]))
    df99.date[i] = re.sub('" itemprop="datePublished"/>','',str(df99.date[i]))
    df99.stars[i] = re.sub('<meta content="','',str(df99.stars[i]))
    df99.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df99.stars[i]))
    df99.review_body[i] = re.sub('<p itemprop="description">','',str(df99.review_body[i]))
    df99.review_body[i] = re.sub('</p>','',str(df99.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=1980')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df100 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df100)):
    df100.author[i] = re.sub('<meta content="','',str(df100.author[i]))
    df100.author[i] = re.sub('" itemprop="author"/>','',str(df100.author[i]))
    df100.date[i] = re.sub('<meta content="','',str(df100.date[i]))
    df100.date[i] = re.sub('" itemprop="datePublished"/>','',str(df100.date[i]))
    df100.stars[i] = re.sub('<meta content="','',str(df100.stars[i]))
    df100.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df100.stars[i]))
    df100.review_body[i] = re.sub('<p itemprop="description">','',str(df100.review_body[i]))
    df100.review_body[i] = re.sub('</p>','',str(df100.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2000')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df101 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df101)):
    df101.author[i] = re.sub('<meta content="','',str(df101.author[i]))
    df101.author[i] = re.sub('" itemprop="author"/>','',str(df101.author[i]))
    df101.date[i] = re.sub('<meta content="','',str(df101.date[i]))
    df101.date[i] = re.sub('" itemprop="datePublished"/>','',str(df101.date[i]))
    df101.stars[i] = re.sub('<meta content="','',str(df101.stars[i]))
    df101.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df101.stars[i]))
    df101.review_body[i] = re.sub('<p itemprop="description">','',str(df101.review_body[i]))
    df101.review_body[i] = re.sub('</p>','',str(df101.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2020')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df102 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df102)):
    df102.author[i] = re.sub('<meta content="','',str(df102.author[i]))
    df102.author[i] = re.sub('" itemprop="author"/>','',str(df102.author[i]))
    df102.date[i] = re.sub('<meta content="','',str(df102.date[i]))
    df102.date[i] = re.sub('" itemprop="datePublished"/>','',str(df102.date[i]))
    df102.stars[i] = re.sub('<meta content="','',str(df102.stars[i]))
    df102.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df102.stars[i]))
    df102.review_body[i] = re.sub('<p itemprop="description">','',str(df102.review_body[i]))
    df102.review_body[i] = re.sub('</p>','',str(df102.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2040')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df103 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df103)):
    df103.author[i] = re.sub('<meta content="','',str(df103.author[i]))
    df103.author[i] = re.sub('" itemprop="author"/>','',str(df103.author[i]))
    df103.date[i] = re.sub('<meta content="','',str(df103.date[i]))
    df103.date[i] = re.sub('" itemprop="datePublished"/>','',str(df103.date[i]))
    df103.stars[i] = re.sub('<meta content="','',str(df103.stars[i]))
    df103.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df103.stars[i]))
    df103.review_body[i] = re.sub('<p itemprop="description">','',str(df103.review_body[i]))
    df103.review_body[i] = re.sub('</p>','',str(df103.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2060')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df104 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df104)):
    df104.author[i] = re.sub('<meta content="','',str(df104.author[i]))
    df104.author[i] = re.sub('" itemprop="author"/>','',str(df104.author[i]))
    df104.date[i] = re.sub('<meta content="','',str(df104.date[i]))
    df104.date[i] = re.sub('" itemprop="datePublished"/>','',str(df104.date[i]))
    df104.stars[i] = re.sub('<meta content="','',str(df104.stars[i]))
    df104.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df104.stars[i]))
    df104.review_body[i] = re.sub('<p itemprop="description">','',str(df104.review_body[i]))
    df104.review_body[i] = re.sub('</p>','',str(df104.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2080')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df105 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df105)):
    df105.author[i] = re.sub('<meta content="','',str(df105.author[i]))
    df105.author[i] = re.sub('" itemprop="author"/>','',str(df105.author[i]))
    df105.date[i] = re.sub('<meta content="','',str(df105.date[i]))
    df105.date[i] = re.sub('" itemprop="datePublished"/>','',str(df105.date[i]))
    df105.stars[i] = re.sub('<meta content="','',str(df105.stars[i]))
    df105.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df105.stars[i]))
    df105.review_body[i] = re.sub('<p itemprop="description">','',str(df105.review_body[i]))
    df105.review_body[i] = re.sub('</p>','',str(df105.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2100')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df106 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df106)):
    df106.author[i] = re.sub('<meta content="','',str(df106.author[i]))
    df106.author[i] = re.sub('" itemprop="author"/>','',str(df106.author[i]))
    df106.date[i] = re.sub('<meta content="','',str(df106.date[i]))
    df106.date[i] = re.sub('" itemprop="datePublished"/>','',str(df106.date[i]))
    df106.stars[i] = re.sub('<meta content="','',str(df106.stars[i]))
    df106.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df106.stars[i]))
    df106.review_body[i] = re.sub('<p itemprop="description">','',str(df106.review_body[i]))
    df106.review_body[i] = re.sub('</p>','',str(df106.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2120')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df107 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df107)):
    df107.author[i] = re.sub('<meta content="','',str(df107.author[i]))
    df107.author[i] = re.sub('" itemprop="author"/>','',str(df107.author[i]))
    df107.date[i] = re.sub('<meta content="','',str(df107.date[i]))
    df107.date[i] = re.sub('" itemprop="datePublished"/>','',str(df107.date[i]))
    df107.stars[i] = re.sub('<meta content="','',str(df107.stars[i]))
    df107.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df107.stars[i]))
    df107.review_body[i] = re.sub('<p itemprop="description">','',str(df107.review_body[i]))
    df107.review_body[i] = re.sub('</p>','',str(df107.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2140')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df108 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df108)):
    df108.author[i] = re.sub('<meta content="','',str(df108.author[i]))
    df108.author[i] = re.sub('" itemprop="author"/>','',str(df108.author[i]))
    df108.date[i] = re.sub('<meta content="','',str(df108.date[i]))
    df108.date[i] = re.sub('" itemprop="datePublished"/>','',str(df108.date[i]))
    df108.stars[i] = re.sub('<meta content="','',str(df108.stars[i]))
    df108.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df108.stars[i]))
    df108.review_body[i] = re.sub('<p itemprop="description">','',str(df108.review_body[i]))
    df108.review_body[i] = re.sub('</p>','',str(df108.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2160')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df109 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df109)):
    df109.author[i] = re.sub('<meta content="','',str(df109.author[i]))
    df109.author[i] = re.sub('" itemprop="author"/>','',str(df109.author[i]))
    df109.date[i] = re.sub('<meta content="','',str(df109.date[i]))
    df109.date[i] = re.sub('" itemprop="datePublished"/>','',str(df109.date[i]))
    df109.stars[i] = re.sub('<meta content="','',str(df109.stars[i]))
    df109.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df109.stars[i]))
    df109.review_body[i] = re.sub('<p itemprop="description">','',str(df109.review_body[i]))
    df109.review_body[i] = re.sub('</p>','',str(df109.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2180')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df110 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df110)):
    df110.author[i] = re.sub('<meta content="','',str(df110.author[i]))
    df110.author[i] = re.sub('" itemprop="author"/>','',str(df110.author[i]))
    df110.date[i] = re.sub('<meta content="','',str(df110.date[i]))
    df110.date[i] = re.sub('" itemprop="datePublished"/>','',str(df110.date[i]))
    df110.stars[i] = re.sub('<meta content="','',str(df110.stars[i]))
    df110.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df110.stars[i]))
    df110.review_body[i] = re.sub('<p itemprop="description">','',str(df110.review_body[i]))
    df110.review_body[i] = re.sub('</p>','',str(df110.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2200')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df111 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df111)):
    df111.author[i] = re.sub('<meta content="','',str(df111.author[i]))
    df111.author[i] = re.sub('" itemprop="author"/>','',str(df111.author[i]))
    df111.date[i] = re.sub('<meta content="','',str(df111.date[i]))
    df111.date[i] = re.sub('" itemprop="datePublished"/>','',str(df111.date[i]))
    df111.stars[i] = re.sub('<meta content="','',str(df111.stars[i]))
    df111.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df111.stars[i]))
    df111.review_body[i] = re.sub('<p itemprop="description">','',str(df111.review_body[i]))
    df111.review_body[i] = re.sub('</p>','',str(df111.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2220')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df112 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df112)):
    df112.author[i] = re.sub('<meta content="','',str(df112.author[i]))
    df112.author[i] = re.sub('" itemprop="author"/>','',str(df112.author[i]))
    df112.date[i] = re.sub('<meta content="','',str(df112.date[i]))
    df112.date[i] = re.sub('" itemprop="datePublished"/>','',str(df112.date[i]))
    df112.stars[i] = re.sub('<meta content="','',str(df112.stars[i]))
    df112.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df112.stars[i]))
    df112.review_body[i] = re.sub('<p itemprop="description">','',str(df112.review_body[i]))
    df112.review_body[i] = re.sub('</p>','',str(df112.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2240')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df113 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df113)):
    df113.author[i] = re.sub('<meta content="','',str(df113.author[i]))
    df113.author[i] = re.sub('" itemprop="author"/>','',str(df113.author[i]))
    df113.date[i] = re.sub('<meta content="','',str(df113.date[i]))
    df113.date[i] = re.sub('" itemprop="datePublished"/>','',str(df113.date[i]))
    df113.stars[i] = re.sub('<meta content="','',str(df113.stars[i]))
    df113.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df113.stars[i]))
    df113.review_body[i] = re.sub('<p itemprop="description">','',str(df113.review_body[i]))
    df113.review_body[i] = re.sub('</p>','',str(df113.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2260')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df114 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df114)):
    df114.author[i] = re.sub('<meta content="','',str(df114.author[i]))
    df114.author[i] = re.sub('" itemprop="author"/>','',str(df114.author[i]))
    df114.date[i] = re.sub('<meta content="','',str(df114.date[i]))
    df114.date[i] = re.sub('" itemprop="datePublished"/>','',str(df114.date[i]))
    df114.stars[i] = re.sub('<meta content="','',str(df114.stars[i]))
    df114.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df114.stars[i]))
    df114.review_body[i] = re.sub('<p itemprop="description">','',str(df114.review_body[i]))
    df114.review_body[i] = re.sub('</p>','',str(df114.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2280')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df115 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df115)):
    df115.author[i] = re.sub('<meta content="','',str(df115.author[i]))
    df115.author[i] = re.sub('" itemprop="author"/>','',str(df115.author[i]))
    df115.date[i] = re.sub('<meta content="','',str(df115.date[i]))
    df115.date[i] = re.sub('" itemprop="datePublished"/>','',str(df115.date[i]))
    df115.stars[i] = re.sub('<meta content="','',str(df115.stars[i]))
    df115.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df115.stars[i]))
    df115.review_body[i] = re.sub('<p itemprop="description">','',str(df115.review_body[i]))
    df115.review_body[i] = re.sub('</p>','',str(df115.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2300')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df116 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df116)):
    df116.author[i] = re.sub('<meta content="','',str(df116.author[i]))
    df116.author[i] = re.sub('" itemprop="author"/>','',str(df116.author[i]))
    df116.date[i] = re.sub('<meta content="','',str(df116.date[i]))
    df116.date[i] = re.sub('" itemprop="datePublished"/>','',str(df116.date[i]))
    df116.stars[i] = re.sub('<meta content="','',str(df116.stars[i]))
    df116.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df116.stars[i]))
    df116.review_body[i] = re.sub('<p itemprop="description">','',str(df116.review_body[i]))
    df116.review_body[i] = re.sub('</p>','',str(df116.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2320')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df117 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df117)):
    df117.author[i] = re.sub('<meta content="','',str(df117.author[i]))
    df117.author[i] = re.sub('" itemprop="author"/>','',str(df117.author[i]))
    df117.date[i] = re.sub('<meta content="','',str(df117.date[i]))
    df117.date[i] = re.sub('" itemprop="datePublished"/>','',str(df117.date[i]))
    df117.stars[i] = re.sub('<meta content="','',str(df117.stars[i]))
    df117.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df117.stars[i]))
    df117.review_body[i] = re.sub('<p itemprop="description">','',str(df117.review_body[i]))
    df117.review_body[i] = re.sub('</p>','',str(df117.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2340')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df118 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df118)):
    df118.author[i] = re.sub('<meta content="','',str(df118.author[i]))
    df118.author[i] = re.sub('" itemprop="author"/>','',str(df118.author[i]))
    df118.date[i] = re.sub('<meta content="','',str(df118.date[i]))
    df118.date[i] = re.sub('" itemprop="datePublished"/>','',str(df118.date[i]))
    df118.stars[i] = re.sub('<meta content="','',str(df118.stars[i]))
    df118.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df118.stars[i]))
    df118.review_body[i] = re.sub('<p itemprop="description">','',str(df118.review_body[i]))
    df118.review_body[i] = re.sub('</p>','',str(df118.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2360')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df119 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df119)):
    df119.author[i] = re.sub('<meta content="','',str(df119.author[i]))
    df119.author[i] = re.sub('" itemprop="author"/>','',str(df119.author[i]))
    df119.date[i] = re.sub('<meta content="','',str(df119.date[i]))
    df119.date[i] = re.sub('" itemprop="datePublished"/>','',str(df119.date[i]))
    df119.stars[i] = re.sub('<meta content="','',str(df119.stars[i]))
    df119.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df119.stars[i]))
    df119.review_body[i] = re.sub('<p itemprop="description">','',str(df119.review_body[i]))
    df119.review_body[i] = re.sub('</p>','',str(df119.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2380')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df120 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df120)):
    df120.author[i] = re.sub('<meta content="','',str(df120.author[i]))
    df120.author[i] = re.sub('" itemprop="author"/>','',str(df120.author[i]))
    df120.date[i] = re.sub('<meta content="','',str(df120.date[i]))
    df120.date[i] = re.sub('" itemprop="datePublished"/>','',str(df120.date[i]))
    df120.stars[i] = re.sub('<meta content="','',str(df120.stars[i]))
    df120.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df120.stars[i]))
    df120.review_body[i] = re.sub('<p itemprop="description">','',str(df120.review_body[i]))
    df120.review_body[i] = re.sub('</p>','',str(df120.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2400')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df121 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df121)):
    df121.author[i] = re.sub('<meta content="','',str(df121.author[i]))
    df121.author[i] = re.sub('" itemprop="author"/>','',str(df121.author[i]))
    df121.date[i] = re.sub('<meta content="','',str(df121.date[i]))
    df121.date[i] = re.sub('" itemprop="datePublished"/>','',str(df121.date[i]))
    df121.stars[i] = re.sub('<meta content="','',str(df121.stars[i]))
    df121.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df121.stars[i]))
    df121.review_body[i] = re.sub('<p itemprop="description">','',str(df121.review_body[i]))
    df121.review_body[i] = re.sub('</p>','',str(df121.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2420')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df122 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df122)):
    df122.author[i] = re.sub('<meta content="','',str(df122.author[i]))
    df122.author[i] = re.sub('" itemprop="author"/>','',str(df122.author[i]))
    df122.date[i] = re.sub('<meta content="','',str(df122.date[i]))
    df122.date[i] = re.sub('" itemprop="datePublished"/>','',str(df122.date[i]))
    df122.stars[i] = re.sub('<meta content="','',str(df122.stars[i]))
    df122.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df122.stars[i]))
    df122.review_body[i] = re.sub('<p itemprop="description">','',str(df122.review_body[i]))
    df122.review_body[i] = re.sub('</p>','',str(df122.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2440')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df123 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df123)):
    df123.author[i] = re.sub('<meta content="','',str(df123.author[i]))
    df123.author[i] = re.sub('" itemprop="author"/>','',str(df123.author[i]))
    df123.date[i] = re.sub('<meta content="','',str(df123.date[i]))
    df123.date[i] = re.sub('" itemprop="datePublished"/>','',str(df123.date[i]))
    df123.stars[i] = re.sub('<meta content="','',str(df123.stars[i]))
    df123.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df123.stars[i]))
    df123.review_body[i] = re.sub('<p itemprop="description">','',str(df123.review_body[i]))
    df123.review_body[i] = re.sub('</p>','',str(df123.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2460')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df124 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df124)):
    df124.author[i] = re.sub('<meta content="','',str(df124.author[i]))
    df124.author[i] = re.sub('" itemprop="author"/>','',str(df124.author[i]))
    df124.date[i] = re.sub('<meta content="','',str(df124.date[i]))
    df124.date[i] = re.sub('" itemprop="datePublished"/>','',str(df124.date[i]))
    df124.stars[i] = re.sub('<meta content="','',str(df124.stars[i]))
    df124.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df124.stars[i]))
    df124.review_body[i] = re.sub('<p itemprop="description">','',str(df124.review_body[i]))
    df124.review_body[i] = re.sub('</p>','',str(df124.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2480')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df125 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df125)):
    df125.author[i] = re.sub('<meta content="','',str(df125.author[i]))
    df125.author[i] = re.sub('" itemprop="author"/>','',str(df125.author[i]))
    df125.date[i] = re.sub('<meta content="','',str(df125.date[i]))
    df125.date[i] = re.sub('" itemprop="datePublished"/>','',str(df125.date[i]))
    df125.stars[i] = re.sub('<meta content="','',str(df125.stars[i]))
    df125.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df125.stars[i]))
    df125.review_body[i] = re.sub('<p itemprop="description">','',str(df125.review_body[i]))
    df125.review_body[i] = re.sub('</p>','',str(df125.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2500')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df126 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df126)):
    df126.author[i] = re.sub('<meta content="','',str(df126.author[i]))
    df126.author[i] = re.sub('" itemprop="author"/>','',str(df126.author[i]))
    df126.date[i] = re.sub('<meta content="','',str(df126.date[i]))
    df126.date[i] = re.sub('" itemprop="datePublished"/>','',str(df126.date[i]))
    df126.stars[i] = re.sub('<meta content="','',str(df126.stars[i]))
    df126.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df126.stars[i]))
    df126.review_body[i] = re.sub('<p itemprop="description">','',str(df126.review_body[i]))
    df126.review_body[i] = re.sub('</p>','',str(df126.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2520')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df127 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df127)):
    df127.author[i] = re.sub('<meta content="','',str(df127.author[i]))
    df127.author[i] = re.sub('" itemprop="author"/>','',str(df127.author[i]))
    df127.date[i] = re.sub('<meta content="','',str(df127.date[i]))
    df127.date[i] = re.sub('" itemprop="datePublished"/>','',str(df127.date[i]))
    df127.stars[i] = re.sub('<meta content="','',str(df127.stars[i]))
    df127.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df127.stars[i]))
    df127.review_body[i] = re.sub('<p itemprop="description">','',str(df127.review_body[i]))
    df127.review_body[i] = re.sub('</p>','',str(df127.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2540')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df128 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df128)):
    df128.author[i] = re.sub('<meta content="','',str(df128.author[i]))
    df128.author[i] = re.sub('" itemprop="author"/>','',str(df128.author[i]))
    df128.date[i] = re.sub('<meta content="','',str(df128.date[i]))
    df128.date[i] = re.sub('" itemprop="datePublished"/>','',str(df128.date[i]))
    df128.stars[i] = re.sub('<meta content="','',str(df128.stars[i]))
    df128.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df128.stars[i]))
    df128.review_body[i] = re.sub('<p itemprop="description">','',str(df128.review_body[i]))
    df128.review_body[i] = re.sub('</p>','',str(df128.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2560')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df129 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df129)):
    df129.author[i] = re.sub('<meta content="','',str(df129.author[i]))
    df129.author[i] = re.sub('" itemprop="author"/>','',str(df129.author[i]))
    df129.date[i] = re.sub('<meta content="','',str(df129.date[i]))
    df129.date[i] = re.sub('" itemprop="datePublished"/>','',str(df129.date[i]))
    df129.stars[i] = re.sub('<meta content="','',str(df129.stars[i]))
    df129.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df129.stars[i]))
    df129.review_body[i] = re.sub('<p itemprop="description">','',str(df129.review_body[i]))
    df129.review_body[i] = re.sub('</p>','',str(df129.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2580')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df130 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df130)):
    df130.author[i] = re.sub('<meta content="','',str(df130.author[i]))
    df130.author[i] = re.sub('" itemprop="author"/>','',str(df130.author[i]))
    df130.date[i] = re.sub('<meta content="','',str(df130.date[i]))
    df130.date[i] = re.sub('" itemprop="datePublished"/>','',str(df130.date[i]))
    df130.stars[i] = re.sub('<meta content="','',str(df130.stars[i]))
    df130.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df130.stars[i]))
    df130.review_body[i] = re.sub('<p itemprop="description">','',str(df130.review_body[i]))
    df130.review_body[i] = re.sub('</p>','',str(df130.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2600')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df131 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df131)):
    df131.author[i] = re.sub('<meta content="','',str(df131.author[i]))
    df131.author[i] = re.sub('" itemprop="author"/>','',str(df131.author[i]))
    df131.date[i] = re.sub('<meta content="','',str(df131.date[i]))
    df131.date[i] = re.sub('" itemprop="datePublished"/>','',str(df131.date[i]))
    df131.stars[i] = re.sub('<meta content="','',str(df131.stars[i]))
    df131.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df131.stars[i]))
    df131.review_body[i] = re.sub('<p itemprop="description">','',str(df131.review_body[i]))
    df131.review_body[i] = re.sub('</p>','',str(df131.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2620')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df132 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df132)):
    df132.author[i] = re.sub('<meta content="','',str(df132.author[i]))
    df132.author[i] = re.sub('" itemprop="author"/>','',str(df132.author[i]))
    df132.date[i] = re.sub('<meta content="','',str(df132.date[i]))
    df132.date[i] = re.sub('" itemprop="datePublished"/>','',str(df132.date[i]))
    df132.stars[i] = re.sub('<meta content="','',str(df132.stars[i]))
    df132.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df132.stars[i]))
    df132.review_body[i] = re.sub('<p itemprop="description">','',str(df132.review_body[i]))
    df132.review_body[i] = re.sub('</p>','',str(df132.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2640')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df133 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df133)):
    df133.author[i] = re.sub('<meta content="','',str(df133.author[i]))
    df133.author[i] = re.sub('" itemprop="author"/>','',str(df133.author[i]))
    df133.date[i] = re.sub('<meta content="','',str(df133.date[i]))
    df133.date[i] = re.sub('" itemprop="datePublished"/>','',str(df133.date[i]))
    df133.stars[i] = re.sub('<meta content="','',str(df133.stars[i]))
    df133.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df133.stars[i]))
    df133.review_body[i] = re.sub('<p itemprop="description">','',str(df133.review_body[i]))
    df133.review_body[i] = re.sub('</p>','',str(df133.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2660')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df134 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df134)):
    df134.author[i] = re.sub('<meta content="','',str(df134.author[i]))
    df134.author[i] = re.sub('" itemprop="author"/>','',str(df134.author[i]))
    df134.date[i] = re.sub('<meta content="','',str(df134.date[i]))
    df134.date[i] = re.sub('" itemprop="datePublished"/>','',str(df134.date[i]))
    df134.stars[i] = re.sub('<meta content="','',str(df134.stars[i]))
    df134.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df134.stars[i]))
    df134.review_body[i] = re.sub('<p itemprop="description">','',str(df134.review_body[i]))
    df134.review_body[i] = re.sub('</p>','',str(df134.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2680')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df135 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df135)):
    df135.author[i] = re.sub('<meta content="','',str(df135.author[i]))
    df135.author[i] = re.sub('" itemprop="author"/>','',str(df135.author[i]))
    df135.date[i] = re.sub('<meta content="','',str(df135.date[i]))
    df135.date[i] = re.sub('" itemprop="datePublished"/>','',str(df135.date[i]))
    df135.stars[i] = re.sub('<meta content="','',str(df135.stars[i]))
    df135.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df135.stars[i]))
    df135.review_body[i] = re.sub('<p itemprop="description">','',str(df135.review_body[i]))
    df135.review_body[i] = re.sub('</p>','',str(df135.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2700')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df136 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df136)):
    df136.author[i] = re.sub('<meta content="','',str(df136.author[i]))
    df136.author[i] = re.sub('" itemprop="author"/>','',str(df136.author[i]))
    df136.date[i] = re.sub('<meta content="','',str(df136.date[i]))
    df136.date[i] = re.sub('" itemprop="datePublished"/>','',str(df136.date[i]))
    df136.stars[i] = re.sub('<meta content="','',str(df136.stars[i]))
    df136.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df136.stars[i]))
    df136.review_body[i] = re.sub('<p itemprop="description">','',str(df136.review_body[i]))
    df136.review_body[i] = re.sub('</p>','',str(df136.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2720')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df137 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df137)):
    df137.author[i] = re.sub('<meta content="','',str(df137.author[i]))
    df137.author[i] = re.sub('" itemprop="author"/>','',str(df137.author[i]))
    df137.date[i] = re.sub('<meta content="','',str(df137.date[i]))
    df137.date[i] = re.sub('" itemprop="datePublished"/>','',str(df137.date[i]))
    df137.stars[i] = re.sub('<meta content="','',str(df137.stars[i]))
    df137.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df137.stars[i]))
    df137.review_body[i] = re.sub('<p itemprop="description">','',str(df137.review_body[i]))
    df137.review_body[i] = re.sub('</p>','',str(df137.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2740')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df138 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df138)):
    df138.author[i] = re.sub('<meta content="','',str(df138.author[i]))
    df138.author[i] = re.sub('" itemprop="author"/>','',str(df138.author[i]))
    df138.date[i] = re.sub('<meta content="','',str(df138.date[i]))
    df138.date[i] = re.sub('" itemprop="datePublished"/>','',str(df138.date[i]))
    df138.stars[i] = re.sub('<meta content="','',str(df138.stars[i]))
    df138.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df138.stars[i]))
    df138.review_body[i] = re.sub('<p itemprop="description">','',str(df138.review_body[i]))
    df138.review_body[i] = re.sub('</p>','',str(df138.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2760')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df139 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df139)):
    df139.author[i] = re.sub('<meta content="','',str(df139.author[i]))
    df139.author[i] = re.sub('" itemprop="author"/>','',str(df139.author[i]))
    df139.date[i] = re.sub('<meta content="','',str(df139.date[i]))
    df139.date[i] = re.sub('" itemprop="datePublished"/>','',str(df139.date[i]))
    df139.stars[i] = re.sub('<meta content="','',str(df139.stars[i]))
    df139.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df139.stars[i]))
    df139.review_body[i] = re.sub('<p itemprop="description">','',str(df139.review_body[i]))
    df139.review_body[i] = re.sub('</p>','',str(df139.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2780')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df140 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df140)):
    df140.author[i] = re.sub('<meta content="','',str(df140.author[i]))
    df140.author[i] = re.sub('" itemprop="author"/>','',str(df140.author[i]))
    df140.date[i] = re.sub('<meta content="','',str(df140.date[i]))
    df140.date[i] = re.sub('" itemprop="datePublished"/>','',str(df140.date[i]))
    df140.stars[i] = re.sub('<meta content="','',str(df140.stars[i]))
    df140.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df140.stars[i]))
    df140.review_body[i] = re.sub('<p itemprop="description">','',str(df140.review_body[i]))
    df140.review_body[i] = re.sub('</p>','',str(df140.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2800')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df141 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df141)):
    df141.author[i] = re.sub('<meta content="','',str(df141.author[i]))
    df141.author[i] = re.sub('" itemprop="author"/>','',str(df141.author[i]))
    df141.date[i] = re.sub('<meta content="','',str(df141.date[i]))
    df141.date[i] = re.sub('" itemprop="datePublished"/>','',str(df141.date[i]))
    df141.stars[i] = re.sub('<meta content="','',str(df141.stars[i]))
    df141.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df141.stars[i]))
    df141.review_body[i] = re.sub('<p itemprop="description">','',str(df141.review_body[i]))
    df141.review_body[i] = re.sub('</p>','',str(df141.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2820')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df142 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df142)):
    df142.author[i] = re.sub('<meta content="','',str(df142.author[i]))
    df142.author[i] = re.sub('" itemprop="author"/>','',str(df142.author[i]))
    df142.date[i] = re.sub('<meta content="','',str(df142.date[i]))
    df142.date[i] = re.sub('" itemprop="datePublished"/>','',str(df142.date[i]))
    df142.stars[i] = re.sub('<meta content="','',str(df142.stars[i]))
    df142.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df142.stars[i]))
    df142.review_body[i] = re.sub('<p itemprop="description">','',str(df142.review_body[i]))
    df142.review_body[i] = re.sub('</p>','',str(df142.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2840')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df143 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df143)):
    df143.author[i] = re.sub('<meta content="','',str(df143.author[i]))
    df143.author[i] = re.sub('" itemprop="author"/>','',str(df143.author[i]))
    df143.date[i] = re.sub('<meta content="','',str(df143.date[i]))
    df143.date[i] = re.sub('" itemprop="datePublished"/>','',str(df143.date[i]))
    df143.stars[i] = re.sub('<meta content="','',str(df143.stars[i]))
    df143.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df143.stars[i]))
    df143.review_body[i] = re.sub('<p itemprop="description">','',str(df143.review_body[i]))
    df143.review_body[i] = re.sub('</p>','',str(df143.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2860')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df144 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df144)):
    df144.author[i] = re.sub('<meta content="','',str(df144.author[i]))
    df144.author[i] = re.sub('" itemprop="author"/>','',str(df144.author[i]))
    df144.date[i] = re.sub('<meta content="','',str(df144.date[i]))
    df144.date[i] = re.sub('" itemprop="datePublished"/>','',str(df144.date[i]))
    df144.stars[i] = re.sub('<meta content="','',str(df144.stars[i]))
    df144.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df144.stars[i]))
    df144.review_body[i] = re.sub('<p itemprop="description">','',str(df144.review_body[i]))
    df144.review_body[i] = re.sub('</p>','',str(df144.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2880')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df145 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df145)):
    df145.author[i] = re.sub('<meta content="','',str(df145.author[i]))
    df145.author[i] = re.sub('" itemprop="author"/>','',str(df145.author[i]))
    df145.date[i] = re.sub('<meta content="','',str(df145.date[i]))
    df145.date[i] = re.sub('" itemprop="datePublished"/>','',str(df145.date[i]))
    df145.stars[i] = re.sub('<meta content="','',str(df145.stars[i]))
    df145.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df145.stars[i]))
    df145.review_body[i] = re.sub('<p itemprop="description">','',str(df145.review_body[i]))
    df145.review_body[i] = re.sub('</p>','',str(df145.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2900')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df146 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df146)):
    df146.author[i] = re.sub('<meta content="','',str(df146.author[i]))
    df146.author[i] = re.sub('" itemprop="author"/>','',str(df146.author[i]))
    df146.date[i] = re.sub('<meta content="','',str(df146.date[i]))
    df146.date[i] = re.sub('" itemprop="datePublished"/>','',str(df146.date[i]))
    df146.stars[i] = re.sub('<meta content="','',str(df146.stars[i]))
    df146.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df146.stars[i]))
    df146.review_body[i] = re.sub('<p itemprop="description">','',str(df146.review_body[i]))
    df146.review_body[i] = re.sub('</p>','',str(df146.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2920')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df147 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df147)):
    df147.author[i] = re.sub('<meta content="','',str(df147.author[i]))
    df147.author[i] = re.sub('" itemprop="author"/>','',str(df147.author[i]))
    df147.date[i] = re.sub('<meta content="','',str(df147.date[i]))
    df147.date[i] = re.sub('" itemprop="datePublished"/>','',str(df147.date[i]))
    df147.stars[i] = re.sub('<meta content="','',str(df147.stars[i]))
    df147.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df147.stars[i]))
    df147.review_body[i] = re.sub('<p itemprop="description">','',str(df147.review_body[i]))
    df147.review_body[i] = re.sub('</p>','',str(df147.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2940')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df148 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df148)):
    df148.author[i] = re.sub('<meta content="','',str(df148.author[i]))
    df148.author[i] = re.sub('" itemprop="author"/>','',str(df148.author[i]))
    df148.date[i] = re.sub('<meta content="','',str(df148.date[i]))
    df148.date[i] = re.sub('" itemprop="datePublished"/>','',str(df148.date[i]))
    df148.stars[i] = re.sub('<meta content="','',str(df148.stars[i]))
    df148.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df148.stars[i]))
    df148.review_body[i] = re.sub('<p itemprop="description">','',str(df148.review_body[i]))
    df148.review_body[i] = re.sub('</p>','',str(df148.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2960')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df149 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df149)):
    df149.author[i] = re.sub('<meta content="','',str(df149.author[i]))
    df149.author[i] = re.sub('" itemprop="author"/>','',str(df149.author[i]))
    df149.date[i] = re.sub('<meta content="','',str(df149.date[i]))
    df149.date[i] = re.sub('" itemprop="datePublished"/>','',str(df149.date[i]))
    df149.stars[i] = re.sub('<meta content="','',str(df149.stars[i]))
    df149.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df149.stars[i]))
    df149.review_body[i] = re.sub('<p itemprop="description">','',str(df149.review_body[i]))
    df149.review_body[i] = re.sub('</p>','',str(df149.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=2980')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df150 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df150)):
    df150.author[i] = re.sub('<meta content="','',str(df150.author[i]))
    df150.author[i] = re.sub('" itemprop="author"/>','',str(df150.author[i]))
    df150.date[i] = re.sub('<meta content="','',str(df150.date[i]))
    df150.date[i] = re.sub('" itemprop="datePublished"/>','',str(df150.date[i]))
    df150.stars[i] = re.sub('<meta content="','',str(df150.stars[i]))
    df150.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df150.stars[i]))
    df150.review_body[i] = re.sub('<p itemprop="description">','',str(df150.review_body[i]))
    df150.review_body[i] = re.sub('</p>','',str(df150.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3000')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df151 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df151)):
    df151.author[i] = re.sub('<meta content="','',str(df151.author[i]))
    df151.author[i] = re.sub('" itemprop="author"/>','',str(df151.author[i]))
    df151.date[i] = re.sub('<meta content="','',str(df151.date[i]))
    df151.date[i] = re.sub('" itemprop="datePublished"/>','',str(df151.date[i]))
    df151.stars[i] = re.sub('<meta content="','',str(df151.stars[i]))
    df151.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df151.stars[i]))
    df151.review_body[i] = re.sub('<p itemprop="description">','',str(df151.review_body[i]))
    df151.review_body[i] = re.sub('</p>','',str(df151.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3020')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df152 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df152)):
    df152.author[i] = re.sub('<meta content="','',str(df152.author[i]))
    df152.author[i] = re.sub('" itemprop="author"/>','',str(df152.author[i]))
    df152.date[i] = re.sub('<meta content="','',str(df152.date[i]))
    df152.date[i] = re.sub('" itemprop="datePublished"/>','',str(df152.date[i]))
    df152.stars[i] = re.sub('<meta content="','',str(df152.stars[i]))
    df152.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df152.stars[i]))
    df152.review_body[i] = re.sub('<p itemprop="description">','',str(df152.review_body[i]))
    df152.review_body[i] = re.sub('</p>','',str(df152.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3040')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df153 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df153)):
    df153.author[i] = re.sub('<meta content="','',str(df153.author[i]))
    df153.author[i] = re.sub('" itemprop="author"/>','',str(df153.author[i]))
    df153.date[i] = re.sub('<meta content="','',str(df153.date[i]))
    df153.date[i] = re.sub('" itemprop="datePublished"/>','',str(df153.date[i]))
    df153.stars[i] = re.sub('<meta content="','',str(df153.stars[i]))
    df153.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df153.stars[i]))
    df153.review_body[i] = re.sub('<p itemprop="description">','',str(df153.review_body[i]))
    df153.review_body[i] = re.sub('</p>','',str(df153.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3060')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df154 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df154)):
    df154.author[i] = re.sub('<meta content="','',str(df154.author[i]))
    df154.author[i] = re.sub('" itemprop="author"/>','',str(df154.author[i]))
    df154.date[i] = re.sub('<meta content="','',str(df154.date[i]))
    df154.date[i] = re.sub('" itemprop="datePublished"/>','',str(df154.date[i]))
    df154.stars[i] = re.sub('<meta content="','',str(df154.stars[i]))
    df154.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df154.stars[i]))
    df154.review_body[i] = re.sub('<p itemprop="description">','',str(df154.review_body[i]))
    df154.review_body[i] = re.sub('</p>','',str(df154.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3080')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df155 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df155)):
    df155.author[i] = re.sub('<meta content="','',str(df155.author[i]))
    df155.author[i] = re.sub('" itemprop="author"/>','',str(df155.author[i]))
    df155.date[i] = re.sub('<meta content="','',str(df155.date[i]))
    df155.date[i] = re.sub('" itemprop="datePublished"/>','',str(df155.date[i]))
    df155.stars[i] = re.sub('<meta content="','',str(df155.stars[i]))
    df155.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df155.stars[i]))
    df155.review_body[i] = re.sub('<p itemprop="description">','',str(df155.review_body[i]))
    df155.review_body[i] = re.sub('</p>','',str(df155.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3100')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df156 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df156)):
    df156.author[i] = re.sub('<meta content="','',str(df156.author[i]))
    df156.author[i] = re.sub('" itemprop="author"/>','',str(df156.author[i]))
    df156.date[i] = re.sub('<meta content="','',str(df156.date[i]))
    df156.date[i] = re.sub('" itemprop="datePublished"/>','',str(df156.date[i]))
    df156.stars[i] = re.sub('<meta content="','',str(df156.stars[i]))
    df156.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df156.stars[i]))
    df156.review_body[i] = re.sub('<p itemprop="description">','',str(df156.review_body[i]))
    df156.review_body[i] = re.sub('</p>','',str(df156.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3120')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df157 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df157)):
    df157.author[i] = re.sub('<meta content="','',str(df157.author[i]))
    df157.author[i] = re.sub('" itemprop="author"/>','',str(df157.author[i]))
    df157.date[i] = re.sub('<meta content="','',str(df157.date[i]))
    df157.date[i] = re.sub('" itemprop="datePublished"/>','',str(df157.date[i]))
    df157.stars[i] = re.sub('<meta content="','',str(df157.stars[i]))
    df157.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df157.stars[i]))
    df157.review_body[i] = re.sub('<p itemprop="description">','',str(df157.review_body[i]))
    df157.review_body[i] = re.sub('</p>','',str(df157.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3140')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df158 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df158)):
    df158.author[i] = re.sub('<meta content="','',str(df158.author[i]))
    df158.author[i] = re.sub('" itemprop="author"/>','',str(df158.author[i]))
    df158.date[i] = re.sub('<meta content="','',str(df158.date[i]))
    df158.date[i] = re.sub('" itemprop="datePublished"/>','',str(df158.date[i]))
    df158.stars[i] = re.sub('<meta content="','',str(df158.stars[i]))
    df158.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df158.stars[i]))
    df158.review_body[i] = re.sub('<p itemprop="description">','',str(df158.review_body[i]))
    df158.review_body[i] = re.sub('</p>','',str(df158.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3160')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df159 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df159)):
    df159.author[i] = re.sub('<meta content="','',str(df159.author[i]))
    df159.author[i] = re.sub('" itemprop="author"/>','',str(df159.author[i]))
    df159.date[i] = re.sub('<meta content="','',str(df159.date[i]))
    df159.date[i] = re.sub('" itemprop="datePublished"/>','',str(df159.date[i]))
    df159.stars[i] = re.sub('<meta content="','',str(df159.stars[i]))
    df159.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df159.stars[i]))
    df159.review_body[i] = re.sub('<p itemprop="description">','',str(df159.review_body[i]))
    df159.review_body[i] = re.sub('</p>','',str(df159.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3180')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df160 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df160)):
    df160.author[i] = re.sub('<meta content="','',str(df160.author[i]))
    df160.author[i] = re.sub('" itemprop="author"/>','',str(df160.author[i]))
    df160.date[i] = re.sub('<meta content="','',str(df160.date[i]))
    df160.date[i] = re.sub('" itemprop="datePublished"/>','',str(df160.date[i]))
    df160.stars[i] = re.sub('<meta content="','',str(df160.stars[i]))
    df160.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df160.stars[i]))
    df160.review_body[i] = re.sub('<p itemprop="description">','',str(df160.review_body[i]))
    df160.review_body[i] = re.sub('</p>','',str(df160.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3200')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df161 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df161)):
    df161.author[i] = re.sub('<meta content="','',str(df161.author[i]))
    df161.author[i] = re.sub('" itemprop="author"/>','',str(df161.author[i]))
    df161.date[i] = re.sub('<meta content="','',str(df161.date[i]))
    df161.date[i] = re.sub('" itemprop="datePublished"/>','',str(df161.date[i]))
    df161.stars[i] = re.sub('<meta content="','',str(df161.stars[i]))
    df161.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df161.stars[i]))
    df161.review_body[i] = re.sub('<p itemprop="description">','',str(df161.review_body[i]))
    df161.review_body[i] = re.sub('</p>','',str(df161.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3220')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df162 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df162)):
    df162.author[i] = re.sub('<meta content="','',str(df162.author[i]))
    df162.author[i] = re.sub('" itemprop="author"/>','',str(df162.author[i]))
    df162.date[i] = re.sub('<meta content="','',str(df162.date[i]))
    df162.date[i] = re.sub('" itemprop="datePublished"/>','',str(df162.date[i]))
    df162.stars[i] = re.sub('<meta content="','',str(df162.stars[i]))
    df162.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df162.stars[i]))
    df162.review_body[i] = re.sub('<p itemprop="description">','',str(df162.review_body[i]))
    df162.review_body[i] = re.sub('</p>','',str(df162.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3240')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df163 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df163)):
    df163.author[i] = re.sub('<meta content="','',str(df163.author[i]))
    df163.author[i] = re.sub('" itemprop="author"/>','',str(df163.author[i]))
    df163.date[i] = re.sub('<meta content="','',str(df163.date[i]))
    df163.date[i] = re.sub('" itemprop="datePublished"/>','',str(df163.date[i]))
    df163.stars[i] = re.sub('<meta content="','',str(df163.stars[i]))
    df163.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df163.stars[i]))
    df163.review_body[i] = re.sub('<p itemprop="description">','',str(df163.review_body[i]))
    df163.review_body[i] = re.sub('</p>','',str(df163.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3260')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df164 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df164)):
    df164.author[i] = re.sub('<meta content="','',str(df164.author[i]))
    df164.author[i] = re.sub('" itemprop="author"/>','',str(df164.author[i]))
    df164.date[i] = re.sub('<meta content="','',str(df164.date[i]))
    df164.date[i] = re.sub('" itemprop="datePublished"/>','',str(df164.date[i]))
    df164.stars[i] = re.sub('<meta content="','',str(df164.stars[i]))
    df164.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df164.stars[i]))
    df164.review_body[i] = re.sub('<p itemprop="description">','',str(df164.review_body[i]))
    df164.review_body[i] = re.sub('</p>','',str(df164.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3280')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df165 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df165)):
    df165.author[i] = re.sub('<meta content="','',str(df165.author[i]))
    df165.author[i] = re.sub('" itemprop="author"/>','',str(df165.author[i]))
    df165.date[i] = re.sub('<meta content="','',str(df165.date[i]))
    df165.date[i] = re.sub('" itemprop="datePublished"/>','',str(df165.date[i]))
    df165.stars[i] = re.sub('<meta content="','',str(df165.stars[i]))
    df165.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df165.stars[i]))
    df165.review_body[i] = re.sub('<p itemprop="description">','',str(df165.review_body[i]))
    df165.review_body[i] = re.sub('</p>','',str(df165.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3300')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df166 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df166)):
    df166.author[i] = re.sub('<meta content="','',str(df166.author[i]))
    df166.author[i] = re.sub('" itemprop="author"/>','',str(df166.author[i]))
    df166.date[i] = re.sub('<meta content="','',str(df166.date[i]))
    df166.date[i] = re.sub('" itemprop="datePublished"/>','',str(df166.date[i]))
    df166.stars[i] = re.sub('<meta content="','',str(df166.stars[i]))
    df166.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df166.stars[i]))
    df166.review_body[i] = re.sub('<p itemprop="description">','',str(df166.review_body[i]))
    df166.review_body[i] = re.sub('</p>','',str(df166.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3320')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df167 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df167)):
    df167.author[i] = re.sub('<meta content="','',str(df167.author[i]))
    df167.author[i] = re.sub('" itemprop="author"/>','',str(df167.author[i]))
    df167.date[i] = re.sub('<meta content="','',str(df167.date[i]))
    df167.date[i] = re.sub('" itemprop="datePublished"/>','',str(df167.date[i]))
    df167.stars[i] = re.sub('<meta content="','',str(df167.stars[i]))
    df167.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df167.stars[i]))
    df167.review_body[i] = re.sub('<p itemprop="description">','',str(df167.review_body[i]))
    df167.review_body[i] = re.sub('</p>','',str(df167.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3340')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df168 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df168)):
    df168.author[i] = re.sub('<meta content="','',str(df168.author[i]))
    df168.author[i] = re.sub('" itemprop="author"/>','',str(df168.author[i]))
    df168.date[i] = re.sub('<meta content="','',str(df168.date[i]))
    df168.date[i] = re.sub('" itemprop="datePublished"/>','',str(df168.date[i]))
    df168.stars[i] = re.sub('<meta content="','',str(df168.stars[i]))
    df168.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df168.stars[i]))
    df168.review_body[i] = re.sub('<p itemprop="description">','',str(df168.review_body[i]))
    df168.review_body[i] = re.sub('</p>','',str(df168.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3360')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df169 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df169)):
    df169.author[i] = re.sub('<meta content="','',str(df169.author[i]))
    df169.author[i] = re.sub('" itemprop="author"/>','',str(df169.author[i]))
    df169.date[i] = re.sub('<meta content="','',str(df169.date[i]))
    df169.date[i] = re.sub('" itemprop="datePublished"/>','',str(df169.date[i]))
    df169.stars[i] = re.sub('<meta content="','',str(df169.stars[i]))
    df169.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df169.stars[i]))
    df169.review_body[i] = re.sub('<p itemprop="description">','',str(df169.review_body[i]))
    df169.review_body[i] = re.sub('</p>','',str(df169.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3380')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df170 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df170)):
    df170.author[i] = re.sub('<meta content="','',str(df170.author[i]))
    df170.author[i] = re.sub('" itemprop="author"/>','',str(df170.author[i]))
    df170.date[i] = re.sub('<meta content="','',str(df170.date[i]))
    df170.date[i] = re.sub('" itemprop="datePublished"/>','',str(df170.date[i]))
    df170.stars[i] = re.sub('<meta content="','',str(df170.stars[i]))
    df170.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df170.stars[i]))
    df170.review_body[i] = re.sub('<p itemprop="description">','',str(df170.review_body[i]))
    df170.review_body[i] = re.sub('</p>','',str(df170.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3400')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df171 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df171)):
    df171.author[i] = re.sub('<meta content="','',str(df171.author[i]))
    df171.author[i] = re.sub('" itemprop="author"/>','',str(df171.author[i]))
    df171.date[i] = re.sub('<meta content="','',str(df171.date[i]))
    df171.date[i] = re.sub('" itemprop="datePublished"/>','',str(df171.date[i]))
    df171.stars[i] = re.sub('<meta content="','',str(df171.stars[i]))
    df171.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df171.stars[i]))
    df171.review_body[i] = re.sub('<p itemprop="description">','',str(df171.review_body[i]))
    df171.review_body[i] = re.sub('</p>','',str(df171.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3420')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df172 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df172)):
    df172.author[i] = re.sub('<meta content="','',str(df172.author[i]))
    df172.author[i] = re.sub('" itemprop="author"/>','',str(df172.author[i]))
    df172.date[i] = re.sub('<meta content="','',str(df172.date[i]))
    df172.date[i] = re.sub('" itemprop="datePublished"/>','',str(df172.date[i]))
    df172.stars[i] = re.sub('<meta content="','',str(df172.stars[i]))
    df172.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df172.stars[i]))
    df172.review_body[i] = re.sub('<p itemprop="description">','',str(df172.review_body[i]))
    df172.review_body[i] = re.sub('</p>','',str(df172.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3440')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df173 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df173)):
    df173.author[i] = re.sub('<meta content="','',str(df173.author[i]))
    df173.author[i] = re.sub('" itemprop="author"/>','',str(df173.author[i]))
    df173.date[i] = re.sub('<meta content="','',str(df173.date[i]))
    df173.date[i] = re.sub('" itemprop="datePublished"/>','',str(df173.date[i]))
    df173.stars[i] = re.sub('<meta content="','',str(df173.stars[i]))
    df173.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df173.stars[i]))
    df173.review_body[i] = re.sub('<p itemprop="description">','',str(df173.review_body[i]))
    df173.review_body[i] = re.sub('</p>','',str(df173.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3460')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df174 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df174)):
    df174.author[i] = re.sub('<meta content="','',str(df174.author[i]))
    df174.author[i] = re.sub('" itemprop="author"/>','',str(df174.author[i]))
    df174.date[i] = re.sub('<meta content="','',str(df174.date[i]))
    df174.date[i] = re.sub('" itemprop="datePublished"/>','',str(df174.date[i]))
    df174.stars[i] = re.sub('<meta content="','',str(df174.stars[i]))
    df174.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df174.stars[i]))
    df174.review_body[i] = re.sub('<p itemprop="description">','',str(df174.review_body[i]))
    df174.review_body[i] = re.sub('</p>','',str(df174.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3480')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df175 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df175)):
    df175.author[i] = re.sub('<meta content="','',str(df175.author[i]))
    df175.author[i] = re.sub('" itemprop="author"/>','',str(df175.author[i]))
    df175.date[i] = re.sub('<meta content="','',str(df175.date[i]))
    df175.date[i] = re.sub('" itemprop="datePublished"/>','',str(df175.date[i]))
    df175.stars[i] = re.sub('<meta content="','',str(df175.stars[i]))
    df175.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df175.stars[i]))
    df175.review_body[i] = re.sub('<p itemprop="description">','',str(df175.review_body[i]))
    df175.review_body[i] = re.sub('</p>','',str(df175.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3500')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df176 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df176)):
    df176.author[i] = re.sub('<meta content="','',str(df176.author[i]))
    df176.author[i] = re.sub('" itemprop="author"/>','',str(df176.author[i]))
    df176.date[i] = re.sub('<meta content="','',str(df176.date[i]))
    df176.date[i] = re.sub('" itemprop="datePublished"/>','',str(df176.date[i]))
    df176.stars[i] = re.sub('<meta content="','',str(df176.stars[i]))
    df176.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df176.stars[i]))
    df176.review_body[i] = re.sub('<p itemprop="description">','',str(df176.review_body[i]))
    df176.review_body[i] = re.sub('</p>','',str(df176.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3520')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df177 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df177)):
    df177.author[i] = re.sub('<meta content="','',str(df177.author[i]))
    df177.author[i] = re.sub('" itemprop="author"/>','',str(df177.author[i]))
    df177.date[i] = re.sub('<meta content="','',str(df177.date[i]))
    df177.date[i] = re.sub('" itemprop="datePublished"/>','',str(df177.date[i]))
    df177.stars[i] = re.sub('<meta content="','',str(df177.stars[i]))
    df177.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df177.stars[i]))
    df177.review_body[i] = re.sub('<p itemprop="description">','',str(df177.review_body[i]))
    df177.review_body[i] = re.sub('</p>','',str(df177.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3540')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df178 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df178)):
    df178.author[i] = re.sub('<meta content="','',str(df178.author[i]))
    df178.author[i] = re.sub('" itemprop="author"/>','',str(df178.author[i]))
    df178.date[i] = re.sub('<meta content="','',str(df178.date[i]))
    df178.date[i] = re.sub('" itemprop="datePublished"/>','',str(df178.date[i]))
    df178.stars[i] = re.sub('<meta content="','',str(df178.stars[i]))
    df178.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df178.stars[i]))
    df178.review_body[i] = re.sub('<p itemprop="description">','',str(df178.review_body[i]))
    df178.review_body[i] = re.sub('</p>','',str(df178.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3560')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df179 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df179)):
    df179.author[i] = re.sub('<meta content="','',str(df179.author[i]))
    df179.author[i] = re.sub('" itemprop="author"/>','',str(df179.author[i]))
    df179.date[i] = re.sub('<meta content="','',str(df179.date[i]))
    df179.date[i] = re.sub('" itemprop="datePublished"/>','',str(df179.date[i]))
    df179.stars[i] = re.sub('<meta content="','',str(df179.stars[i]))
    df179.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df179.stars[i]))
    df179.review_body[i] = re.sub('<p itemprop="description">','',str(df179.review_body[i]))
    df179.review_body[i] = re.sub('</p>','',str(df179.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3580')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df180 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df180)):
    df180.author[i] = re.sub('<meta content="','',str(df180.author[i]))
    df180.author[i] = re.sub('" itemprop="author"/>','',str(df180.author[i]))
    df180.date[i] = re.sub('<meta content="','',str(df180.date[i]))
    df180.date[i] = re.sub('" itemprop="datePublished"/>','',str(df180.date[i]))
    df180.stars[i] = re.sub('<meta content="','',str(df180.stars[i]))
    df180.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df180.stars[i]))
    df180.review_body[i] = re.sub('<p itemprop="description">','',str(df180.review_body[i]))
    df180.review_body[i] = re.sub('</p>','',str(df180.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3600')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df181 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df181)):
    df181.author[i] = re.sub('<meta content="','',str(df181.author[i]))
    df181.author[i] = re.sub('" itemprop="author"/>','',str(df181.author[i]))
    df181.date[i] = re.sub('<meta content="','',str(df181.date[i]))
    df181.date[i] = re.sub('" itemprop="datePublished"/>','',str(df181.date[i]))
    df181.stars[i] = re.sub('<meta content="','',str(df181.stars[i]))
    df181.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df181.stars[i]))
    df181.review_body[i] = re.sub('<p itemprop="description">','',str(df181.review_body[i]))
    df181.review_body[i] = re.sub('</p>','',str(df181.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3620')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df182 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df182)):
    df182.author[i] = re.sub('<meta content="','',str(df182.author[i]))
    df182.author[i] = re.sub('" itemprop="author"/>','',str(df182.author[i]))
    df182.date[i] = re.sub('<meta content="','',str(df182.date[i]))
    df182.date[i] = re.sub('" itemprop="datePublished"/>','',str(df182.date[i]))
    df182.stars[i] = re.sub('<meta content="','',str(df182.stars[i]))
    df182.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df182.stars[i]))
    df182.review_body[i] = re.sub('<p itemprop="description">','',str(df182.review_body[i]))
    df182.review_body[i] = re.sub('</p>','',str(df182.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3640')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df183 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df183)):
    df183.author[i] = re.sub('<meta content="','',str(df183.author[i]))
    df183.author[i] = re.sub('" itemprop="author"/>','',str(df183.author[i]))
    df183.date[i] = re.sub('<meta content="','',str(df183.date[i]))
    df183.date[i] = re.sub('" itemprop="datePublished"/>','',str(df183.date[i]))
    df183.stars[i] = re.sub('<meta content="','',str(df183.stars[i]))
    df183.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df183.stars[i]))
    df183.review_body[i] = re.sub('<p itemprop="description">','',str(df183.review_body[i]))
    df183.review_body[i] = re.sub('</p>','',str(df183.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3660')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df184 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df184)):
    df184.author[i] = re.sub('<meta content="','',str(df184.author[i]))
    df184.author[i] = re.sub('" itemprop="author"/>','',str(df184.author[i]))
    df184.date[i] = re.sub('<meta content="','',str(df184.date[i]))
    df184.date[i] = re.sub('" itemprop="datePublished"/>','',str(df184.date[i]))
    df184.stars[i] = re.sub('<meta content="','',str(df184.stars[i]))
    df184.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df184.stars[i]))
    df184.review_body[i] = re.sub('<p itemprop="description">','',str(df184.review_body[i]))
    df184.review_body[i] = re.sub('</p>','',str(df184.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3680')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df185 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df185)):
    df185.author[i] = re.sub('<meta content="','',str(df185.author[i]))
    df185.author[i] = re.sub('" itemprop="author"/>','',str(df185.author[i]))
    df185.date[i] = re.sub('<meta content="','',str(df185.date[i]))
    df185.date[i] = re.sub('" itemprop="datePublished"/>','',str(df185.date[i]))
    df185.stars[i] = re.sub('<meta content="','',str(df185.stars[i]))
    df185.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df185.stars[i]))
    df185.review_body[i] = re.sub('<p itemprop="description">','',str(df185.review_body[i]))
    df185.review_body[i] = re.sub('</p>','',str(df185.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3700')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df186 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df186)):
    df186.author[i] = re.sub('<meta content="','',str(df186.author[i]))
    df186.author[i] = re.sub('" itemprop="author"/>','',str(df186.author[i]))
    df186.date[i] = re.sub('<meta content="','',str(df186.date[i]))
    df186.date[i] = re.sub('" itemprop="datePublished"/>','',str(df186.date[i]))
    df186.stars[i] = re.sub('<meta content="','',str(df186.stars[i]))
    df186.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df186.stars[i]))
    df186.review_body[i] = re.sub('<p itemprop="description">','',str(df186.review_body[i]))
    df186.review_body[i] = re.sub('</p>','',str(df186.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3720')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df187 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df187)):
    df187.author[i] = re.sub('<meta content="','',str(df187.author[i]))
    df187.author[i] = re.sub('" itemprop="author"/>','',str(df187.author[i]))
    df187.date[i] = re.sub('<meta content="','',str(df187.date[i]))
    df187.date[i] = re.sub('" itemprop="datePublished"/>','',str(df187.date[i]))
    df187.stars[i] = re.sub('<meta content="','',str(df187.stars[i]))
    df187.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df187.stars[i]))
    df187.review_body[i] = re.sub('<p itemprop="description">','',str(df187.review_body[i]))
    df187.review_body[i] = re.sub('</p>','',str(df187.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3740')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df188 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df188)):
    df188.author[i] = re.sub('<meta content="','',str(df188.author[i]))
    df188.author[i] = re.sub('" itemprop="author"/>','',str(df188.author[i]))
    df188.date[i] = re.sub('<meta content="','',str(df188.date[i]))
    df188.date[i] = re.sub('" itemprop="datePublished"/>','',str(df188.date[i]))
    df188.stars[i] = re.sub('<meta content="','',str(df188.stars[i]))
    df188.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df188.stars[i]))
    df188.review_body[i] = re.sub('<p itemprop="description">','',str(df188.review_body[i]))
    df188.review_body[i] = re.sub('</p>','',str(df188.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3760')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df189 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df189)):
    df189.author[i] = re.sub('<meta content="','',str(df189.author[i]))
    df189.author[i] = re.sub('" itemprop="author"/>','',str(df189.author[i]))
    df189.date[i] = re.sub('<meta content="','',str(df189.date[i]))
    df189.date[i] = re.sub('" itemprop="datePublished"/>','',str(df189.date[i]))
    df189.stars[i] = re.sub('<meta content="','',str(df189.stars[i]))
    df189.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df189.stars[i]))
    df189.review_body[i] = re.sub('<p itemprop="description">','',str(df189.review_body[i]))
    df189.review_body[i] = re.sub('</p>','',str(df189.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3780')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df190 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df190)):
    df190.author[i] = re.sub('<meta content="','',str(df190.author[i]))
    df190.author[i] = re.sub('" itemprop="author"/>','',str(df190.author[i]))
    df190.date[i] = re.sub('<meta content="','',str(df190.date[i]))
    df190.date[i] = re.sub('" itemprop="datePublished"/>','',str(df190.date[i]))
    df190.stars[i] = re.sub('<meta content="','',str(df190.stars[i]))
    df190.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df190.stars[i]))
    df190.review_body[i] = re.sub('<p itemprop="description">','',str(df190.review_body[i]))
    df190.review_body[i] = re.sub('</p>','',str(df190.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3800')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df191 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df191)):
    df191.author[i] = re.sub('<meta content="','',str(df191.author[i]))
    df191.author[i] = re.sub('" itemprop="author"/>','',str(df191.author[i]))
    df191.date[i] = re.sub('<meta content="','',str(df191.date[i]))
    df191.date[i] = re.sub('" itemprop="datePublished"/>','',str(df191.date[i]))
    df191.stars[i] = re.sub('<meta content="','',str(df191.stars[i]))
    df191.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df191.stars[i]))
    df191.review_body[i] = re.sub('<p itemprop="description">','',str(df191.review_body[i]))
    df191.review_body[i] = re.sub('</p>','',str(df191.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3820')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df192 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df192)):
    df192.author[i] = re.sub('<meta content="','',str(df192.author[i]))
    df192.author[i] = re.sub('" itemprop="author"/>','',str(df192.author[i]))
    df192.date[i] = re.sub('<meta content="','',str(df192.date[i]))
    df192.date[i] = re.sub('" itemprop="datePublished"/>','',str(df192.date[i]))
    df192.stars[i] = re.sub('<meta content="','',str(df192.stars[i]))
    df192.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df192.stars[i]))
    df192.review_body[i] = re.sub('<p itemprop="description">','',str(df192.review_body[i]))
    df192.review_body[i] = re.sub('</p>','',str(df192.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3840')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df193 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df193)):
    df193.author[i] = re.sub('<meta content="','',str(df193.author[i]))
    df193.author[i] = re.sub('" itemprop="author"/>','',str(df193.author[i]))
    df193.date[i] = re.sub('<meta content="','',str(df193.date[i]))
    df193.date[i] = re.sub('" itemprop="datePublished"/>','',str(df193.date[i]))
    df193.stars[i] = re.sub('<meta content="','',str(df193.stars[i]))
    df193.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df193.stars[i]))
    df193.review_body[i] = re.sub('<p itemprop="description">','',str(df193.review_body[i]))
    df193.review_body[i] = re.sub('</p>','',str(df193.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3860')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df194 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df194)):
    df194.author[i] = re.sub('<meta content="','',str(df194.author[i]))
    df194.author[i] = re.sub('" itemprop="author"/>','',str(df194.author[i]))
    df194.date[i] = re.sub('<meta content="','',str(df194.date[i]))
    df194.date[i] = re.sub('" itemprop="datePublished"/>','',str(df194.date[i]))
    df194.stars[i] = re.sub('<meta content="','',str(df194.stars[i]))
    df194.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df194.stars[i]))
    df194.review_body[i] = re.sub('<p itemprop="description">','',str(df194.review_body[i]))
    df194.review_body[i] = re.sub('</p>','',str(df194.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3880')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df195 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df195)):
    df195.author[i] = re.sub('<meta content="','',str(df195.author[i]))
    df195.author[i] = re.sub('" itemprop="author"/>','',str(df195.author[i]))
    df195.date[i] = re.sub('<meta content="','',str(df195.date[i]))
    df195.date[i] = re.sub('" itemprop="datePublished"/>','',str(df195.date[i]))
    df195.stars[i] = re.sub('<meta content="','',str(df195.stars[i]))
    df195.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df195.stars[i]))
    df195.review_body[i] = re.sub('<p itemprop="description">','',str(df195.review_body[i]))
    df195.review_body[i] = re.sub('</p>','',str(df195.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3900')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df196 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df196)):
    df196.author[i] = re.sub('<meta content="','',str(df196.author[i]))
    df196.author[i] = re.sub('" itemprop="author"/>','',str(df196.author[i]))
    df196.date[i] = re.sub('<meta content="','',str(df196.date[i]))
    df196.date[i] = re.sub('" itemprop="datePublished"/>','',str(df196.date[i]))
    df196.stars[i] = re.sub('<meta content="','',str(df196.stars[i]))
    df196.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df196.stars[i]))
    df196.review_body[i] = re.sub('<p itemprop="description">','',str(df196.review_body[i]))
    df196.review_body[i] = re.sub('</p>','',str(df196.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3920')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df197 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df197)):
    df197.author[i] = re.sub('<meta content="','',str(df197.author[i]))
    df197.author[i] = re.sub('" itemprop="author"/>','',str(df197.author[i]))
    df197.date[i] = re.sub('<meta content="','',str(df197.date[i]))
    df197.date[i] = re.sub('" itemprop="datePublished"/>','',str(df197.date[i]))
    df197.stars[i] = re.sub('<meta content="','',str(df197.stars[i]))
    df197.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df197.stars[i]))
    df197.review_body[i] = re.sub('<p itemprop="description">','',str(df197.review_body[i]))
    df197.review_body[i] = re.sub('</p>','',str(df197.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3940')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df198 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df198)):
    df198.author[i] = re.sub('<meta content="','',str(df198.author[i]))
    df198.author[i] = re.sub('" itemprop="author"/>','',str(df198.author[i]))
    df198.date[i] = re.sub('<meta content="','',str(df198.date[i]))
    df198.date[i] = re.sub('" itemprop="datePublished"/>','',str(df198.date[i]))
    df198.stars[i] = re.sub('<meta content="','',str(df198.stars[i]))
    df198.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df198.stars[i]))
    df198.review_body[i] = re.sub('<p itemprop="description">','',str(df198.review_body[i]))
    df198.review_body[i] = re.sub('</p>','',str(df198.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3960')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df199 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df199)):
    df199.author[i] = re.sub('<meta content="','',str(df199.author[i]))
    df199.author[i] = re.sub('" itemprop="author"/>','',str(df199.author[i]))
    df199.date[i] = re.sub('<meta content="','',str(df199.date[i]))
    df199.date[i] = re.sub('" itemprop="datePublished"/>','',str(df199.date[i]))
    df199.stars[i] = re.sub('<meta content="','',str(df199.stars[i]))
    df199.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df199.stars[i]))
    df199.review_body[i] = re.sub('<p itemprop="description">','',str(df199.review_body[i]))
    df199.review_body[i] = re.sub('</p>','',str(df199.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=3980')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df200 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df200)):
    df200.author[i] = re.sub('<meta content="','',str(df200.author[i]))
    df200.author[i] = re.sub('" itemprop="author"/>','',str(df200.author[i]))
    df200.date[i] = re.sub('<meta content="','',str(df200.date[i]))
    df200.date[i] = re.sub('" itemprop="datePublished"/>','',str(df200.date[i]))
    df200.stars[i] = re.sub('<meta content="','',str(df200.stars[i]))
    df200.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df200.stars[i]))
    df200.review_body[i] = re.sub('<p itemprop="description">','',str(df200.review_body[i]))
    df200.review_body[i] = re.sub('</p>','',str(df200.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4000')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df201 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df201)):
    df201.author[i] = re.sub('<meta content="','',str(df201.author[i]))
    df201.author[i] = re.sub('" itemprop="author"/>','',str(df201.author[i]))
    df201.date[i] = re.sub('<meta content="','',str(df201.date[i]))
    df201.date[i] = re.sub('" itemprop="datePublished"/>','',str(df201.date[i]))
    df201.stars[i] = re.sub('<meta content="','',str(df201.stars[i]))
    df201.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df201.stars[i]))
    df201.review_body[i] = re.sub('<p itemprop="description">','',str(df201.review_body[i]))
    df201.review_body[i] = re.sub('</p>','',str(df201.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4020')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df202 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df202)):
    df202.author[i] = re.sub('<meta content="','',str(df202.author[i]))
    df202.author[i] = re.sub('" itemprop="author"/>','',str(df202.author[i]))
    df202.date[i] = re.sub('<meta content="','',str(df202.date[i]))
    df202.date[i] = re.sub('" itemprop="datePublished"/>','',str(df202.date[i]))
    df202.stars[i] = re.sub('<meta content="','',str(df202.stars[i]))
    df202.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df202.stars[i]))
    df202.review_body[i] = re.sub('<p itemprop="description">','',str(df202.review_body[i]))
    df202.review_body[i] = re.sub('</p>','',str(df202.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4040')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df203 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df203)):
    df203.author[i] = re.sub('<meta content="','',str(df203.author[i]))
    df203.author[i] = re.sub('" itemprop="author"/>','',str(df203.author[i]))
    df203.date[i] = re.sub('<meta content="','',str(df203.date[i]))
    df203.date[i] = re.sub('" itemprop="datePublished"/>','',str(df203.date[i]))
    df203.stars[i] = re.sub('<meta content="','',str(df203.stars[i]))
    df203.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df203.stars[i]))
    df203.review_body[i] = re.sub('<p itemprop="description">','',str(df203.review_body[i]))
    df203.review_body[i] = re.sub('</p>','',str(df203.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4060')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df204 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df204)):
    df204.author[i] = re.sub('<meta content="','',str(df204.author[i]))
    df204.author[i] = re.sub('" itemprop="author"/>','',str(df204.author[i]))
    df204.date[i] = re.sub('<meta content="','',str(df204.date[i]))
    df204.date[i] = re.sub('" itemprop="datePublished"/>','',str(df204.date[i]))
    df204.stars[i] = re.sub('<meta content="','',str(df204.stars[i]))
    df204.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df204.stars[i]))
    df204.review_body[i] = re.sub('<p itemprop="description">','',str(df204.review_body[i]))
    df204.review_body[i] = re.sub('</p>','',str(df204.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4080')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df205 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df205)):
    df205.author[i] = re.sub('<meta content="','',str(df205.author[i]))
    df205.author[i] = re.sub('" itemprop="author"/>','',str(df205.author[i]))
    df205.date[i] = re.sub('<meta content="','',str(df205.date[i]))
    df205.date[i] = re.sub('" itemprop="datePublished"/>','',str(df205.date[i]))
    df205.stars[i] = re.sub('<meta content="','',str(df205.stars[i]))
    df205.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df205.stars[i]))
    df205.review_body[i] = re.sub('<p itemprop="description">','',str(df205.review_body[i]))
    df205.review_body[i] = re.sub('</p>','',str(df205.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4100')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df206 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df206)):
    df206.author[i] = re.sub('<meta content="','',str(df206.author[i]))
    df206.author[i] = re.sub('" itemprop="author"/>','',str(df206.author[i]))
    df206.date[i] = re.sub('<meta content="','',str(df206.date[i]))
    df206.date[i] = re.sub('" itemprop="datePublished"/>','',str(df206.date[i]))
    df206.stars[i] = re.sub('<meta content="','',str(df206.stars[i]))
    df206.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df206.stars[i]))
    df206.review_body[i] = re.sub('<p itemprop="description">','',str(df206.review_body[i]))
    df206.review_body[i] = re.sub('</p>','',str(df206.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4120')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df207 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df207)):
    df207.author[i] = re.sub('<meta content="','',str(df207.author[i]))
    df207.author[i] = re.sub('" itemprop="author"/>','',str(df207.author[i]))
    df207.date[i] = re.sub('<meta content="','',str(df207.date[i]))
    df207.date[i] = re.sub('" itemprop="datePublished"/>','',str(df207.date[i]))
    df207.stars[i] = re.sub('<meta content="','',str(df207.stars[i]))
    df207.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df207.stars[i]))
    df207.review_body[i] = re.sub('<p itemprop="description">','',str(df207.review_body[i]))
    df207.review_body[i] = re.sub('</p>','',str(df207.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4140')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df208 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df208)):
    df208.author[i] = re.sub('<meta content="','',str(df208.author[i]))
    df208.author[i] = re.sub('" itemprop="author"/>','',str(df208.author[i]))
    df208.date[i] = re.sub('<meta content="','',str(df208.date[i]))
    df208.date[i] = re.sub('" itemprop="datePublished"/>','',str(df208.date[i]))
    df208.stars[i] = re.sub('<meta content="','',str(df208.stars[i]))
    df208.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df208.stars[i]))
    df208.review_body[i] = re.sub('<p itemprop="description">','',str(df208.review_body[i]))
    df208.review_body[i] = re.sub('</p>','',str(df208.review_body[i]))

# %%
r = requests.get('https://www.yelp.com/biz/zazie-san-francisco?start=4160')
html = r.text
soup = BeautifulSoup(html, "html5lib")
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')
df209 = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})

for i in range(len(df209)):
    df209.author[i] = re.sub('<meta content="','',str(df209.author[i]))
    df209.author[i] = re.sub('" itemprop="author"/>','',str(df209.author[i]))
    df209.date[i] = re.sub('<meta content="','',str(df209.date[i]))
    df209.date[i] = re.sub('" itemprop="datePublished"/>','',str(df209.date[i]))
    df209.stars[i] = re.sub('<meta content="','',str(df209.stars[i]))
    df209.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(df209.stars[i]))
    df209.review_body[i] = re.sub('<p itemprop="description">','',str(df209.review_body[i]))
    df209.review_body[i] = re.sub('</p>','',str(df209.review_body[i]))

# %%
df209.head()
# Out:
# Empty DataFrame
# Columns: [author, date, stars, review_body]
# Index: []

# %%
for i in dfs:
    print (len(i))
print(len(dfs))
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# ...

# %%
dfs = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,
       df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,
       df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,
       df47,df48,df49,df50,df51,df52,df53,df54,df55,df56,df57,df58,df59,df60,df61,
       df62,df63,df64,df65,df66,df67,df68,df69,df70,df71,df72,df73,df74,df75,df76,
       df77,df78,df79,df80,df81,df82,df83,df84,df85,df86,df87,df88,df89,df90,df91,
       df92,df93,df94,df95,df96,df97,df98,df99,df100,df101,df102,df103,df104,df105,
      df106,df107,df108,df109,df110,df111,df112,df113,df114,df115,df116,df117,df118,
      df119,df120,df121,df122,df123,df124,df125,df126,df127,df128,df129,df130,df131,
      df132,df133,df134,df135,df136,df137,df138,df139,df140,df141,df142,df143,df144,
      df145,df146,df147,df148,df149,df150,df151,df152,df153,df154,df155,df156,df157,
      df158,df159,df160,df161,df162,df163,df164,df165,df166,df167,df168,df169,df170,
      df171,df172,df173,df174,df175,df176,df177,df178,df179,df180,df181,df182,df183,
      df184,df185,df186,df187,df188,df189,df190,df191,df192,df193,df194,df195,df196,
      df197,df198,df199,df200,df201,df202,df203,df204,df205,df206,df207,df208]

DF = df209
for i in dfs:
    DF = DF.append(i, ignore_index=True)
    
print(DF.shape)
DF
# Out:
# (4156, 4)
#              author        date stars  \
# 0            Bob U.  2019-03-04   5.0
# 1          Carol H.  2019-03-08   4.0
# 2          Jamie P.  2019-03-02   4.0
# 3         Eileen W.  2019-02-24   5.0
# 4          Donna T.  2019-02-14   5.0
# 5         Elvira D.  2019-03-02   5.0
# 6          Eddie W.  2019-02-27   3.0
# 7          JoAnn C.  2019-02-03   4.0
# 8         Nicole A.  2019-02-10   5.0
# 9        Hayoung P.  2019-02-25   1.0
# 10       Felicia A.  2019-03-02   5.0
# 11         Amiee C.  2019-01-15   4.0
# 12        Maggie R.  2019-01-31   5.0
# 13         David B.  2019-01-24   4.0
# 14          Sara O.  2019-01-21   3.0
# 15     Christine B.  2019-02-20   5.0
# 16    Shirley M. J.  2018-12-04   2.0
# 17           Ken L.  2018-11-15   5.0
# 18      Michelle Z.  2019-02-25   1.0
# 19             G G.  2019-02-08   5.0
# 20        Marina C.  2018-11-22   5.0
# 21       Chelsey C.  2019-02-07   5.0
# 22         Laksh M.  2018-11-20   4.0
# ...

# %%
DF.to_csv('/home/cynthiaorourke/Desktop/Yelp_Zazie/reviews_included.csv')

# %% [markdown]
# ### Tags that identify interesting content on each html page (ignore all escape backslashes)
# - to pull the rating value for each review:
# \ <meta itemprop="ratingValue" content=
# - to pull the review date for each review:
# \ <meta itemprop="datePublished" content=
# - to pull the user for each review (also denotes start of each review):
# \ <meta itemprop="author" content=
# - to pull the review text for each review:
# \ <p \itemprop="description">

# %%
soup.find_all(itemprop="ratingValue")
# Out:
# [<meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="3.0" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
#  <meta content="3.0" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
#  <meta content="4.0" itemprop="ratingValue"/>,
#  <meta content="5.0" itemprop="ratingValue"/>,
# ...

# %%
soup.find_all(itemprop="datePublished")
# Out:
# [<meta content="2014-12-01" itemprop="datePublished"/>,
#  <meta content="2012-07-21" itemprop="datePublished"/>,
#  <meta content="2017-05-12" itemprop="datePublished"/>,
#  <meta content="2017-03-11" itemprop="datePublished"/>,
#  <meta content="2014-08-05" itemprop="datePublished"/>,
#  <meta content="2014-03-23" itemprop="datePublished"/>,
#  <meta content="2015-10-31" itemprop="datePublished"/>,
#  <meta content="2014-07-14" itemprop="datePublished"/>,
#  <meta content="2017-01-22" itemprop="datePublished"/>,
#  <meta content="2015-12-28" itemprop="datePublished"/>,
#  <meta content="2014-03-23" itemprop="datePublished"/>,
#  <meta content="2014-03-11" itemprop="datePublished"/>,
#  <meta content="2016-03-27" itemprop="datePublished"/>,
#  <meta content="2016-05-16" itemprop="datePublished"/>,
#  <meta content="2016-03-26" itemprop="datePublished"/>,
#  <meta content="2014-06-22" itemprop="datePublished"/>,
#  <meta content="2017-05-07" itemprop="datePublished"/>,
# ...

# %%
soup.find_all(itemprop="author")
# Out:
# [<meta content="Gaby E." itemprop="author"/>,
#  <meta content="Samantha L." itemprop="author"/>,
#  <meta content="george p." itemprop="author"/>,
#  <meta content="Amanda S." itemprop="author"/>,
#  <meta content="Heidi Q." itemprop="author"/>,
#  <meta content="Saminda W." itemprop="author"/>,
#  <meta content="Michael S." itemprop="author"/>,
#  <meta content="Steven V." itemprop="author"/>,
#  <meta content="Erika D." itemprop="author"/>,
#  <meta content="Leslie S." itemprop="author"/>,
#  <meta content="Alysha F." itemprop="author"/>,
#  <meta content="Patrick T." itemprop="author"/>,
#  <meta content="Angelica C." itemprop="author"/>,
#  <meta content="Lawrence K." itemprop="author"/>,
#  <meta content="Stephanie R." itemprop="author"/>,
#  <meta content="Sharon R." itemprop="author"/>,
#  <meta content="Hannah Y." itemprop="author"/>,
#  <meta content="Kiki C." itemprop="author"/>,
#  <meta content="Yomna N." itemprop="author"/>,
# ...

# %%
author = soup.find_all(itemprop = 'author')
date = soup.find_all(itemprop = 'datePublished')
stars = soup.find_all(itemprop = 'ratingValue')
review_body = soup.find_all(itemprop = 'description')

# %%
print(len(author))
print(len(date))
print(len(stars))
print(len(stars[1:]))
print(len(review_body))
# Out:
# 20
# 20
# 21
# 20
# 20

# %%
df = pd.DataFrame({'author':author,'date':date,'stars':stars[1:],'review_body':review_body})
print(df.dtypes)
df.head()
# Out:
# author         object
# date           object
# stars          object
# review_body    object
# dtype: object
#                                             author  \
# 0      <meta content="Gaby E." itemprop="author"/>
# 1  <meta content="Samantha L." itemprop="author"/>
# 2    <meta content="george p." itemprop="author"/>
# 3    <meta content="Amanda S." itemprop="author"/>
# 4     <meta content="Heidi Q." itemprop="author"/>
#
#                                                 date  \
# 0  <meta content="2014-12-01" itemprop="datePubli...
# 1  <meta content="2012-07-21" itemprop="datePubli...
# 2  <meta content="2017-05-12" itemprop="datePubli...
# 3  <meta content="2017-03-11" itemprop="datePubli...
# 4  <meta content="2014-08-05" itemprop="datePubli...
#
#                                           stars  \
# 0  <meta content="5.0" itemprop="ratingValue"/>
# 1  <meta content="4.0" itemprop="ratingValue"/>
# 2  <meta content="5.0" itemprop="ratingValue"/>
# ...

# %%
play = df
print(len(play))

for i in range(len(play)):
    play.author[i] = re.sub('<meta content="','',str(play.author[i]))
    play.author[i] = re.sub('" itemprop="author"/>','',str(play.author[i]))
    play.date[i] = re.sub('<meta content="','',str(play.date[i]))
    play.date[i] = re.sub('" itemprop="datePublished"/>','',str(play.date[i]))
    play.stars[i] = re.sub('<meta content="','',str(play.stars[i]))
    play.stars[i] = re.sub('" itemprop="ratingValue"/>','',str(play.stars[i]))
    play.review_body[i] = re.sub('<p itemprop="description">','',str(play.review_body[i]))
    play.review_body[i] = re.sub('</p>','',str(play.review_body[i]))

print(len(play))
play.head()
# Out:
# 20
# 20
#         author        date stars  \
# 0      Gaby E.  2014-12-01   5.0
# 1  Samantha L.  2012-07-21   4.0
# 2    george p.  2017-05-12   5.0
# 3    Amanda S.  2017-03-11   5.0
# 4     Heidi Q.  2014-08-05   5.0
#
#                                          review_body
# 0  Went for brunch on a weekday: food was amazing...
# 1  I try to stay away from popular brunch restaur...
# 2  We have been going there off and on for 10 yea...
# 3  This place definitely lives up the hype. I hav...
# 4  This has been one of my favorite brunch spots ...

# %%
print(play.review_body[1])
# Out:
# I try to stay away from popular brunch restaurants that don't allow reservations. However, if i do plan on going to one, i make sure to beat the line and not wait around for hours. Zazie opens at 9am on the weekends. I wasn't exactly sure where it was located on Cole St but i saw the line and knew i should scout for a parking spot asap. Note that i got there 20 minutes prior to opening time!
#
# I'll have to agree with the bulk of yelpers here and recommend...
#
# La Mer, Eggs Benedicts: They make a perfect poached egg here at Zazie's. I get so much joy breaking one and watching the egg run to create one delicious mess of everything. They top it with a respectable amount of crab meat. I ordered two eggs and had a side of ...
#
# Gingerbread pancakes: It smells and tastes like Christmas! 5 stars for one of the best pancakes i've had. It's unusual and they top it with butter, a poached pear slice, and lemon curd. (Dab a little of their raspberry jam to it as well)
#
# ...
